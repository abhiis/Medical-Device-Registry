# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\IT'
os.chdir(source)
file = "elenco_dm_tutti_csv_formato_opendata_UltimaVersione.csv"
delimiter = ';'

# %%
payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
payload.shape
# Out:
# C:\Users\AbhishekSrivastava\AppData\Local\Temp\ipykernel_16236\2915228804.py:1: DtypeWarning: Columns (9,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
# (1902028, 16)

# %%
cols = payload.columns
cols_en = [translate_to_en(x) for x in cols]
cols_en
# Out:
# ['TYPE',
#  'PROGRESSIVE_DM_ASS',
#  'FIRST_PUBLICATION_DATE',
#  'DM_REFERENCE',
#  'SIMILAR_DM_GROUP',
#  'REPERTORY REGISTRATION',
#  'START_VALIDITY',
#  'END_VALIDITY',
#  'MANUFACTURER ASSEMBLER',
#  'TAX ID CODE',
#  'PARTITA_IVA_VATNUMBER',
#  'CODE_CATALOGUE_FABBR_ASS',
#  'TRADING NAME',
#  'CND CLASSIFICATION',
#  'DESCRIPTION CND',
#  'TRADE_END DATE']

# %%
payload.columns = cols_en

# %%
grill = payload.sample(10)
grill
# Out:
#          TYPE  PROGRESSIVE_DM_ASS FIRST_PUBLICATION_DATE  DM_REFERENCE  \
# 1896651     2              134733             2022-03-17           NaN
# 1412919     1             2029472             2020-11-13           NaN
# 1125930     1             1720768             2018-07-07           NaN
# 82892       1               96888             2009-01-17           NaN
# 979149      1             1568330             2017-06-15           NaN
# 1051202     1             1642136             2017-11-28           NaN
# 41403       1               51777             2008-11-01           NaN
# 561350      1             1082171             2014-02-06           NaN
# 1463805     1             2086537             2021-03-30           NaN
# 46399       1               57281             2008-12-13           NaN
#
#          SIMILAR_DM_GROUP REPERTORY REGISTRATION START_VALIDITY END_VALIDITY  \
# 1896651               NaN                      S     2022-03-17   9999-12-31
# 1412919               NaN                      S     2020-11-13   9999-12-31
# 1125930          129353.0                      S     2021-04-22   9999-12-31
# 82892              5028.0                      S     2009-01-17   9999-12-31
# 979149           100583.0                      S     2018-07-13   9999-12-31
# 1051202               NaN                      S     2017-11-28   9999-12-31
# 41403                 NaN                      S     2008-11-01   9999-12-31
# 561350                NaN                      N     2014-02-06   9999-12-31
# 1463805          128632.0                      N     2021-03-31   9999-12-31
# 46399                 NaN                      S     2008-12-13   9999-12-31
#
#                                  MANUFACTURER ASSEMBLER  TAX ID CODE  \
# 1896651                                  MICERIUM S.P.A  01199870104
# 1412919                           TECNO INSTRUMENTS LTD          NaN
# 1125930                                MEDGAL SP. ZO.O.          NaN
# 82892                          TATTI NON TESSUTO S,P,A,  01335220479
# 979149                                ZEST ANCHORS, LLC          NaN
# 1051202                                       FRANCEMED          NaN
# 41403                          OPPO MEDICAL CORPORATION          NaN
# 561350                         WILSON-COOK MEDICAL INC.          NaN
# 1463805                               TECH PRINT S.R.L.  02302860974
# 46399    LOHMANN & RAUSCHER INTERNATIONAL GMBH & CO. KG          NaN
#
#         PARTITA_IVA_VATNUMBER       CODE_CATALOGUE_FABBR_ASS  \
# 1896651           01199870104                       BZ2RK10H
# 1412919                   NaN                     110-815-18
# 1125930            5423227877                     4-06-54-28
# 82892                     NaN                    TT 02 0002T
# 979149                    NaN                          02702
# 1051202           14322982000                      56.502.00
# 41403                     NaN              OPPO CUSHION FOOT
# 561350                    NaN             ERCP-1, ERCP-1-ANG
# 1463805           02302860974                   FANTASY ROSA
# 46399             DE814998819  20460,20461,20462,20463,20464
#
#                                               TRADING NAME CND CLASSIFICATION  \
# 1896651   ZEPHYR ROTH .022 1 CASO 5/5 SUP. 10 PZ. + H SU 3                NaN
# 1412919                     PINZA BIPOLARE SCISSORS (18CM)            L180401
# 1125930                 Vite di Schanz  Ø 4,0 mm L =280 mm          P09120699
# 82892                       TELO STANDARD IN TRIACCOPPIATO            T020199
# 979149   LOCATOR Abutment for 3.3mm Conico, Biosafin x ...            P010299
# 1051202                HALO - PERNI IN ACCIAIO NON STERILI          P09120604
# 41403                                    OPPO CUSHION FOOT              V0803
# 561350   CATETERI PER ERCP CON PUNTA PRECURVATA - RIUTI...        G0304010101
# 1463805              TM PRINT TIPO II SMALL MY MASK PRO II            T020601
# 46399                      SUPRASORB F MEDICAZIONE IN FILM          M04040601
#
#                                            DESCRIPTION CND TRADE_END DATE
# 1896651                                                NaN            NaN
# 1412919  PINZE PLURIUSO PER ELETTROCHIRURGIA A CIELO AP...            NaN
# 1125930  VITI PER OSTEOSINTESI E SINTESI TENDINEO-LEGAM...            NaN
# 82892                              TELI CHIRURGICI - ALTRI     2010-06-23
# 979149                      PROTESI ODONTOIATRICHE - ALTRE            NaN
# 1051202                       CHIODI-VITE PER OSTEOSINTESI            NaN
# 41403              CUSCINI PER PAZIENTI (non antidecubito)            NaN
# 561350          CANNULE PER ERCP MONOLUME A PUNTA STANDARD            NaN
# 1463805                    MASCHERINE CHIRURGICHE STANDARD            NaN
# 46399                      MEDICAZIONI IN POLIURETANO PURO            NaN

# %%
cols_i_want = ['START_VALIDITY',
'TRADE_END DATE',
 'MANUFACTURER ASSEMBLER','TRADING NAME','DESCRIPTION CND']

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#         START_VALIDITY TRADE_END DATE  \
# 0           2013-06-25            NaN
# 1           2007-07-06     2010-03-16
# 2           2021-12-31            NaN
# 3           2007-09-14            NaN
# 6           2021-12-31            NaN
# ...                ...            ...
# 1902023     2024-01-27            NaN
# 1902024     2024-01-27            NaN
# 1902025     2024-01-27            NaN
# 1902026     2024-01-27            NaN
# 1902027     2024-01-27            NaN
#
#                            MANUFACTURER ASSEMBLER  \
# 0                                    ID&CO S.R.L.
# 1        JOHNSON & JOHNSON MEDICAL HOLDING S.P.A.
# 2                                 BUERKI INNO MED
# 3                                     ACTIMEX SRL
# 6                                 BUERKI INNO MED
# ...                                           ...
# 1902023                          PAUL HARTMANN AG
# 1902024                          PAUL HARTMANN AG
# 1902025                          PAUL HARTMANN AG
# 1902026                       TAUMEDIPLAST S.R.L.
# 1902027                       TAUMEDIPLAST S.R.L.
#
#                                               TRADING NAME  \
# 0                                  PENNARELLI DERMOGRAFICI
# 1                                                VACUDRAIN
# 2        CANNULE IRRIGAZIONE/ASPIRAZIONE PER TECNICA BI...
# 3                                RINOCICLINA SPRAY  NASALE
# 6        CANNULE IRRIGAZIONE ASPIRAZIONE COASSIALI PLUR...
# ...                                                    ...
# 1902023                            COMBISET PER RADIOLOGIA
# 1902024                              COMBISET PER UROLOGIA
# 1902025                   COMBISET PER CHIRURGIA VASCOLARE
# 1902026  I-WASH STAT 250, STAZIONE PER LAVAGGIO OCULARE...
# 1902027  EWS, EYE WASH STATION IN ORANGE ABS BOX COMBISTAR
#
#                                            DESCRIPTION CND
# 0                                     MATITE DERMOGRAFICHE
# 1                  SISTEMI DI DRENAGGIO PERCUTANEO - ALTRI
# 2        CANNULE MONOUSO PER ASPIRAZIONE/IRRIGAZIONE IN...
# 3                         DISPOSITIVI NASOFARINGEI - ALTRI
# 6                    STRUMENTARIO PER OFTALMOLOGIA - ALTRO
# ...                                                    ...
# 1902023                                                NaN
# 1902024                                                NaN
# 1902025                                                NaN
# 1902026                                                NaN
# 1902027                                                NaN
#
# [1433017 rows x 5 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (1433017, 5)

# %%
len(grill['MANUFACTURER ASSEMBLER'].unique())
# Out:
# 22407

# %%
len(grill['TRADING NAME'].unique())
# Out:
# 1236200

# %%
len(grill['DESCRIPTION CND'].unique())
# Out:
# 6910

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text
def prep_translate(df, col):
    cached_en = {}
    unique_vals = df[col].unique()
    print("API Calls: ", len(unique_vals))
    return unique_vals


def update_cache(val):
    translation = translate_to_en(val)
    cached_en[val] = translation
    return val, translation

# %%
unique_vals = prep_translate(grill, 'MANUFACTURER ASSEMBLER')
cached_en = {}
num_threads = 16

# Using ThreadPoolExecutor to parallelize the translation
with ThreadPoolExecutor(max_workers=num_threads) as executor:
    # Submit all the tasks and create a future object for each
    futures = [executor.submit(update_cache, val) for val in unique_vals]
    
    # Iterate over the futures as they complete (as_completed yields futures as they complete)
    for future in tqdm(as_completed(futures), total=len(unique_vals), desc="Translating"):
        val, translation = future.result()
# Out:
# API Calls:  22407
# Translating:   0%|                                                                  | 33/22407 [00:02<27:14, 13.69it/s]

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 chunks = split_dataframe(grill, 1000)
#
# NameError: name 'split_dataframe' is not defined

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
