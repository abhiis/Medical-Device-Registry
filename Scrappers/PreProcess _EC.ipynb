# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\EC'
file = "\Base de datos-Catastro de Emisión de Dispositivos Médicos-VUE-11-01-2024.xlsx"

# %%
payload = pd.read_excel(source+file)
payload.shape
# Out:
# (236023, 33)

# %%
cols = payload.columns
cols_en = [translate_to_en(x) for x in cols]
cols_en
# Out:
# ['application',
#  'document_name',
#  'ruc_applicant',
#  'social_reason_applicant',
#  'requesting_address',
#  'applicant_phone',
#  'product_holder',
#  'country_holder_product',
#  'applicant_legal_representative',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'manufacturer_city',
#  'health register',
#  'certificate_issue_date',
#  'certificate_valid_date',
#  'generic_product_name',
#  'product_name',
#  'usos',
#  'tariff item',
#  'primary_package_description',
#  'secondary_package_description',
#  'product_brand',
#  'risk_level_detail',
#  'medical_device_class_name',
#  'product_group_name',
#  'description_modification',
#  'group',
#  'sterilization_method',
#  'conditioner_name',
#  'country_packer',
#  'city \u200b\u200bconditioner',
#  'conditioner direction']

# %%
payload.columns = cols_en

# %%
cols_i_want = ['product_brand','product_holder',
 'country_holder_product','manufacturer_name',
 'manufacturer_country',
 'manufacturer_address','certificate_issue_date',
 'certificate_valid_date','generic_product_name','usos',]

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#             product_brand                                  product_holder  \
# 0           APOGEE SYSTEM                    American Medical Systems Inc
# 4                 MONARC                     American Medical Systems Inc
# 8                 PERIGEE                    American Medical Systems Inc
# 11          BIOMET TRAUMA                                   BIOMET TRAUMA
# 12             Karl Storz                          KARL STORZ SE & CO. KG
# ...                   ...                                             ...
# 236009           MAGNETOM        SIEMENS SHENZHEN MAGNETIC RESONANCE LTD.
# 236013  MULTIX FUSION MAX  SIEMENS SHANGHAI MEDICAL EQUIPMENT LTD. (SSME)
# 236014                  .  SIEMENS SHANGHAI MEDICAL EQUIPMENT LTD. (SSME)
# 236015            SIEMENS                         SIEMENS HEALTHCARE GMBH
# 236019            SIEMENS                         SIEMENS HEALTHCARE GMBH
#
#        country_holder_product  \
# 0          [US] UNITED STATES
#
#                                                      usos
# 0       Reparacion de la cupulavaginal y del prolapso ...
# 4                                  Incontinencia urinaria
# 8                  Sistema de reparación del piso pélvico
# 11      TRATAMIENTO DE LA DISFUNCION ERECTIL MASCULINO...
# 12      BOMBA DE RODILLOS DE USO INTERDISCIPLINARIO PA...
# ...                                                   ...
# 236009  OBTENCION DE IMAGENES DE DIAGNOSTICO POR RESON...
# 236013                 SISTEMA DE RADIOGRAFÌA DE RAYOS  X
# 236014  SISTEMA DE DIAGNOSTICO POR IMAGENES DE RAYOS X...
# 236015  SISTEMA DE DIAGNOSTICO POR IMAGENES DE RAYOS X...
# 236019  SISTEMA DE DIAGNOSTICO POR IMAGENES (BRAZO EN ...
#
# [44560 rows x 10 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (44560, 10)

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# Created 45 chunks.

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
