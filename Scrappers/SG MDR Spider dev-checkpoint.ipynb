# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://eservice.hsa.gov.sg/medics/md/mdEnquiry.do?action=getAllDevices&pageno=4")

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text)

# %%
table = soup.find_all('table',{"class": "fmTbl"})
devices = [t.find_all('a') for t in table]
hrefs = [h.get('href').split('"')[-2] for h in devices[0]]
hrefs
# Out:
# ['C5024C3B4B-23',
#  'C5024512375C-23',
#  'C5021F413032-20',
#  'C5022141514D-20',
#  'C40A633A5E-i14',
#  'C50219092E5D-19',
#  'C403352249-i11',
#  'C502375A0911-21',
#  'C40D285B60-i16',
#  'C404374004-i11']

# %%
['C40624225A-i12',
 'C3060814-i05',
 'C306081E-i05',
 'C406242A23-i12',
 'C30B1E4A-i06',
 'C30B0D61-i06',
 'C30B0D54-i06',
 'C30B0D5B-i06',
 'C30B1F02-i06',
 'C30F4609-i08']
# Out:
# ['C40624225A-i12',
#  'C3060814-i05',
#  'C306081E-i05',
#  'C406242A23-i12',
#  'C30B1E4A-i06',
#  'C30B0D61-i06',
#  'C30B0D54-i06',
#  'C30B0D5B-i06',
#  'C30B1F02-i06',
#  'C30F4609-i08']

# %%
import requests
holder = []

total = 5000
for i in range(0,total, 10):
    print(i, end="\t")
    cookies = {
        'dis-request-id': 'e1059b3a35173fc26b9401bae49ac1de',
        'dis-timestamp': '2023-04-04T00:17:29-07:00',
        'dis-remote-addr': '103.87.59.203',
        '_ga': 'GA1.3.1498323092.1680592585',
        '_gid': 'GA1.3.652060471.1680592585',
        '_sp_id.d852': 'f7e63b79-5276-40ad-bd4e-b7ab157b8b30.1680592585.1.1680592588.1680592585.c2890bab-7550-4c88-9cc2-80bce15a519a',
        'Cookie': '!5VFZ3iTFwyPi3bLapQqKkLgqNluWVMw8NDNm3a7gHk+lceoeCuFAu+tlIWzuGyweAaru5ILOvrrS2x4=',
        'JSESSIONID': '7gZMHn8plJP6mC3LQU8D-In8vt65PtLHrm4q9w07GfRICvyeZdmi!-1249897684!1215967715',
    }

    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'Accept-Language': 'en-US,en;q=0.9',
        'Cache-Control': 'max-age=0',
        'Connection': 'keep-alive',
        'Content-Type': 'application/x-www-form-urlencoded',
        # 'Cookie': 'dis-request-id=e1059b3a35173fc26b9401bae49ac1de; dis-timestamp=2023-04-04T00:17:29-07:00; dis-remote-addr=103.87.59.203; _ga=GA1.3.1498323092.1680592585; _gid=GA1.3.652060471.1680592585; _sp_id.d852=f7e63b79-5276-40ad-bd4e-b7ab157b8b30.1680592585.1.1680592588.1680592585.c2890bab-7550-4c88-9cc2-80bce15a519a; Cookie=!5VFZ3iTFwyPi3bLapQqKkLgqNluWVMw8NDNm3a7gHk+lceoeCuFAu+tlIWzuGyweAaru5ILOvrrS2x4=; JSESSIONID=7gZMHn8plJP6mC3LQU8D-In8vt65PtLHrm4q9w07GfRICvyeZdmi!-1249897684!1215967715',
        'Origin': 'null',
        'Sec-Fetch-Dest': 'document',
        'Sec-Fetch-Mode': 'navigate',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-User': '?1',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
        'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    data = {
        'action': 'getAllDevices',
        'devId': '',
        'linkName': 'MED',
        'topPageNo': 2000,
        'pageNo': str(i),
        'startsWith': '',
    }

    response = requests.post('https://eservice.hsa.gov.sg/medics/md/mdEnquiry.do', cookies=cookies, headers=headers, data=data)
    soup = BeautifulSoup(response.text)
    table = soup.find_all('table',{"class": "fmTbl"})
    devices = [t.find_all('a') for t in table]
    hrefs = [h.get('href').split('"')[-2] for h in devices[0]]
    [holder.append(x) for x in hrefs]
    print(len(hrefs))
# Out:
# 0	0
# 10	10
# 20	10
# 30	10
# 40	10
# 50	10
# 60	10
# 70	10
# 80	10
# 90	10
# 100	10
# 110	10
# 120	10
# 130	10
# 140	10
# 150	10
# 160	10
# 170	10
# 180	10
# 190	10
# 200	10
# 210	10
# 220	10
# 230	10
# 240	10
# 250	10
# 260	10
# 270	10
# 280	10
# 290	10
# 300	10
# 310	10
# 320	10
# 330	10
# 340	10
# 350	10
# 360	10
# 370	10
# 380	10
# 390	10
# 400	10
# 410	10
# 420	10
# 430	10
# 440	10
# 450	10
# 460	10
# 470	10
# 480	10
# 490	10
# 500	10
# 510	10
# 520	10
# 530	10
# 540	10
# 550	10
# 560	10
# 570	10
# 580	10
# 590	10
# 600	10
# 610	10
# 620	10
# 630	10
# 640	10
# 650	10
# 660	10
# 670	10
# 680	10
# 690	10
# 700	10
# 710	10
# 720	10
# 730	10
# 740	10
# 750	10
# 760	10
# 770	10
# 780	10
# 790	10
# 800	10
# 810	10
# 820	10
# 830	10
# 840	10
# 850	10
# 860	10
# 870	10
# 880	10
# 890	10
# 900	10
# 910	10
# 920	10
# 930	10
# 940	10
# 950	10
# 960	10
# 970	10
# 980	10
# 990	10
# 1000	10
# 1010	10
# 1020	10
# 1030	10
# 1040	10
# 1050	10
# 1060	10
# 1070	10
# 1080	10
# 1090	10
# 1100	10
# 1110	10
# 1120	10
# 1130	10
# 1140	10
# 1150	10
# 1160	10
# 1170	10
# 1180	10
# 1190	10
# 1200	10
# 1210	10
# 1220	10
# 1230	10
# 1240	10
# 1250	10
# 1260	10
# 1270	10
# 1280	10
# 1290	10
# 1300	10
# 1310	10
# 1320	10
# 1330	10
# 1340	10
# 1350	10
# 1360	10
# 1370	10
# 1380	10
# 1390	10
# 1400	10
# 1410	10
# 1420	10
# 1430	10
# 1440	10
# 1450	10
# 1460	10
# 1470	10
# 1480	10
# 1490	10
# 1500	10
# 1510	10
# 1520	10
# 1530	10
# 1540	10
# 1550	10
# 1560	10
# 1570	10
# 1580	10
# 1590	10
# 1600	10
# 1610	10
# 1620	10
# 1630	10
# 1640	10
# 1650	10
# 1660	10
# 1670	10
# 1680	10
# 1690	10
# 1700	10
# 1710	10
# 1720	10
# 1730	10
# 1740	10
# 1750	10
# 1760	10
# 1770	10
# 1780	10
# 1790	10
# 1800	10
# 1810	10
# 1820	10
# 1830	10
# 1840	10
# 1850	10
# 1860	10
# 1870	10
# 1880	10
# 1890	10
# 1900	10
# 1910	10
# 1920	10
# 1930	10
# 1940	10
# 1950	10
# 1960	10
# 1970	10
# 1980	10
# 1990	10
# 2000	10
# 2010	10
# 2020	10
# 2030	10
# 2040	10
# 2050	10
# 2060	10
# 2070	10
# 2080	10
# 2090	10
# 2100	10
# 2110	10
# 2120	10
# 2130	10
# 2140	10
# 2150	10
# 2160	10
# 2170	10
# 2180	10
# 2190	10
# 2200	10
# 2210	10
# 2220	10
# 2230	10
# 2240	10
# 2250	10
# 2260	10
# 2270	10
# 2280	10
# 2290	10
# 2300	10
# 2310	10
# 2320	10
# 2330	10
# 2340	10
# 2350	10
# 2360	10
# 2370	10
# 2380	10
# 2390	10
# 2400	10
# 2410	10
# 2420	10
# 2430	10
# 2440	10
# 2450	10
# 2460	10
# 2470	10
# 2480	10
# 2490	10
# 2500	10
# 2510	10
# 2520	10
# 2530	10
# 2540	10
# 2550	10
# 2560	10
# 2570	10
# 2580	10
# 2590	10
# 2600	10
# 2610	10
# 2620	10
# 2630	10
# 2640	10
# 2650	10
# 2660	10
# 2670	10
# 2680	10
# 2690	10
# 2700	10
# 2710	10
# 2720	10
# 2730	10
# 2740	10
# 2750	10
# 2760	10
# 2770	10
# 2780	10
# 2790	10
# 2800	10
# 2810	10
# 2820	10
# 2830	10
# 2840	10
# 2850	10
# 2860	10
# 2870	10
# 2880	10
# 2890	10
# 2900	10
# 2910	10
# 2920	10
# 2930	10
# 2940	10
# 2950	10
# 2960	10
# 2970	10
# 2980	10
# 2990	10
# 3000	10
# 3010	10
# 3020	10
# 3030	10
# 3040	10
# 3050	10
# 3060	10
# 3070	10
# 3080	10
# 3090	10
# 3100	10
# 3110	10
# 3120	10
# 3130	10
# 3140	10
# 3150	10
# 3160	10
# 3170	10
# 3180	10
# 3190	10
# 3200	10
# 3210	10
# 3220	10
# 3230	10
# 3240	10
# 3250	10
# 3260	10
# 3270	10
# 3280	10
# 3290	10
# 3300	10
# 3310	10
# 3320	10
# 3330	10
# 3340	10
# 3350	10
# 3360	10
# 3370	10
# 3380	10
# 3390	10
# 3400	10
# 3410	10
# 3420	10
# 3430	10
# 3440	10
# 3450	10
# 3460	10
# 3470	10
# 3480	10
# 3490	10
# 3500	10
# 3510	10
# 3520	10
# 3530	10
# 3540	10
# 3550	10
# 3560	10
# 3570	10
# 3580	10
# 3590	10
# 3600	10
# 3610	10
# 3620	10
# 3630	10
# 3640	10
# 3650	10
# 3660	10
# 3670	10
# 3680	10
# 3690	10
# 3700	10
# 3710	10
# 3720	10
# 3730	10
# 3740	10
# 3750	10
# 3760	10
# 3770	10
# 3780	10
# 3790	10
# 3800	10
# 3810	10
# 3820	10
# 3830	10
# 3840	10
# 3850	10
# 3860	10
# 3870	10
# 3880	10
# 3890	10
# 3900	10
# 3910	10
# 3920	10
# 3930	10
# 3940	10
# 3950	10
# 3960	10
# 3970	10
# 3980	10
# 3990	10
# 4000	10
# 4010	10
# 4020	10
# 4030	10
# 4040	10
# 4050	10
# 4060	10
# 4070	10
# 4080	10
# 4090	10
# 4100	10
# 4110	10
# 4120	10
# 4130	10
# 4140	10
# 4150	10
# 4160	10
# 4170	10
# 4180	10
# 4190	10
# 4200	10
# 4210	10
# 4220	10
# 4230	10
# 4240	10
# 4250	10
# 4260	10
# 4270	10
# 4280	10
# 4290	10
# 4300	10
# 4310	10
# 4320	10
# 4330	10
# 4340	10
# 4350	10
# 4360	10
# 4370	10
# 4380	10
# 4390	10
# 4400	10
# 4410	10
# 4420	10
# 4430	10
# 4440	10
# 4450	10
# 4460	10
# 4470	10
# 4480	10
# 4490	10
# 4500	10
# 4510	10
# 4520	10
# 4530	10
# 4540	10
# 4550	10
# 4560	10
# 4570	10
# 4580	10
# 4590	10
# 4600	10
# 4610	10
# 4620	10
# 4630	10
# 4640	10
# 4650	10
# 4660	10
# 4670	10
# 4680	10
# 4690	10
# 4700	10
# 4710	10
# 4720	10
# 4730	10
# 4740	10
# 4750	10
# 4760	10
# 4770	10
# 4780	10
# 4790	10
# 4800	10
# 4810	10
# 4820	10
# 4830	10
# 4840	10
# 4850	10
# 4860	10
# 4870	10
# 4880	10
# 4890	10
# 4900	10
# 4910	10
# 4920	10
# 4930	10
# 4940	10
# 4950	10
# 4960	10
# 4970	10
# 4980	10
# 4990	10

# %%
holder
# Out:
# ['C404374004-i11',
#  'C40B033F28-i14',
#  'C40C4A2F1F-i15',
#  'C3045C4B-i05',
#  'C308045D-i05',
#  'C3045C62-i05',
#  'C3124009-i09',
#  'C4062D4F64-i12',
#  'C40632283B-i12',
#  'C30B1E36-i06',
#  'C40C2C5020-12',
#  'C406242022-i12',
#  'C40624225A-i12',
#  'C3060814-i05',
#  'C306081E-i05',
#  'C406242A23-i12',
#  'C30B1E4A-i06',
#  'C30B0D61-i06',
#  'C30B0D54-i06',
#  'C30B0D5B-i06',
#  'C30B1F02-i06',
#  'C30F4609-i08',
#  'C30F4604-i08',
#  'C3045D06-i05',
#  'C30A4E0F-i06',
#  'C30A4D4E-i06',
#  'C3122143-i09',
#  'C30F4613-i08',
#  'C30F460E-i08',
#  'C40664061C-i12',
#  'C30B0D3E-i06',
#  'C3080703-i05',
#  'C4043B4B0A-i11',
#  'C4043B4A38-i11',
#  'C3080443-i05',
#  'C405103550-i12',
#  'C406302C55-i12',
#  'C3060B14-i05',
#  'C3180D12-i10',
#  'C3060B0E-i05',
#  'C3060B19-i05',
#  'C30B1E59-i06',
#  'C30B1E52-i06',
#  'C405103613-i12',
#  'C408210629-i13',
#  'C3080462-i05',
#  'C40629480A-i12',
#  'C30B0D34-i06',
#  'C406294732-i12',
#  'C40629482A-i12',
#  'C3081A21-i05',
#  'C3062952-i05',
#  'C404285F13-i11',
#  'C306082E-i05',
#  'C4084A212C-i13',
#  'C4063F544C-i12',
#  'C405565D40-i12',
#  'C4100E4E51-i17',
#  'C402382D1E-i10',
#  'C4063E464B-i12',
#  'C44A0B5D5C-17',
#  'C34C5D4F-i10',
#  'C405190652-i12',
#  'C404595C36-i12',
#  'C406303550-i12',
#  'C4043D060D-i11',
#  'C404593802-i12',
#  'C40627213A-i12',
#  'C4043D0F3D-i11',
#  'C4043D0F24-i11',
#  'C4043C313F-i11',
#  'C4063F5541-i12',
#  'C45F235B5E-18',
#  'C3074232-i05',
#  'C4564D4E25-17',
#  'C40D5C1D1D-i16',
#  'C30F2D3A-i08',
#  'C311362F-i08',
#  'C42B59260E-15',
#  'C407175006-i12',
#  'C410371120-i17',
#  'C3160C38-i10',
#  'C4061C432D-i12',
#  'C307420C-i05',
#  'C3074224-i05',
#  'C40D154D4A-i16',
#  'C5024E23623E-23',
#  'C5024E232259-23',
#  'C30F461E-i08',
#  'C30F4618-i08',
#  'C3156203-i10',
#  'C5024C393F0D-23',
#  'C4063E443E-i12',
#  'C40C361748-12',
#  'C3545E1E-i10',
#  'C40C361719-12',
#  'C5024C390913-23',
#  'C407564334-i13',
#  'C40A072711-i14',
#  'C3160C18-i10',
#  'C4043B4942-i11',
#  'C4043B4A03-i11',
#  'C4063B41-i12',
#  'C30F2D2E-i08',
#  'C45F602F0B-18',
#  'C5022F314021-21',
#  'C40C0E1A4D-i15',
#  'C502231E143D-20',
#  'C50233224811-21',
#  'C50233224754-21',
#  'C5023128101A-21',
#  'C5023455281B-21',
#  'C5021E19512B-19',
#  'C40D2A4A46-i16',
#  'C406342C34-i12',
#  'C40D2F580E-i16',
#  'C40F4F375A-i17',
#  'C40805361D-i13',
#  'C406183512-i12',
#  'C40F3D5D04-i17',
#  'C40C2C5B42-i15',
#  'C50235465E02-21',
#  'C5023521024F-21',
#  'C410190B31-13',
#  'C40A020844-i14',
#  'C4042D5529-i11',
#  'C3055E0D-i05',
#  'C3055E08-i05',
#  'C405072E-i12',
#  'C405084F25-i12',
#  'C405371F40-i12',
#  'C407164E56-i12',
#  'C5024D455234-23',
#  'C45B134D04-18',
#  'C45B134D38-18',
#  'C45B134C34-18',
#  'C4473C452E-17',
#  'C5025216445D-23',
#  'C408361030-i13',
#  'C45D59474B-18',
#  'C45C593945-18',
#  'C45D594650-18',
#  'C458295835-17',
#  'C50238192216-21',
#  'C45D5A012B-18',
#  'C5022F3E4A0C-21',
#  'C45E53124F-18',
#  'C5022F3E4B02-21',
#  'C45D250D04-18',
#  'C5023A43210B-22',
#  'C45D594A27-18',
#  'C5022F194564-21',
#  'C463343B16-18',
#  'C463343B43-18',
#  'C45C45114F-18',
#  'C50238192149-21',
#  'C45D594942-18',
#  'C45D250F30-18',
#  'C45D250D4A-18',
#  'C5022F3E4B32-21',
#  'C4630F2B4F-18',
#  'C4630F2B24-18',
#  'C45C5F032D-18',
#  'C45C5F024D-18',
#  'C502381D0308-21',
#  'C45D595B0C-18',
#  'C45C5F0464-18',
#  'C50238056146-21',
#  'C46004504A-18',
#  'C4630F533C-18',
#  'C4630C6402-18',
#  'C45D236054-18',
#  'C463140B03-18',
#  'C463140B57-18',
#  'C463140B2D-18',
#  'C5023E01330A-22',
#  'C45D594B06-18',
#  'C5023D3E0516-22',
#  'C5024F332A4F-23',
#  'C46004560D-18',
#  'C462591350-18',
#  'C45C5F0412-18',
#  'C50251095D0B-23',
#  'C4630F5311-18',
#  'C45C451116-18',
#  'C50214565F1F-19',
#  'C5023A421D14-22',
#  'C5022F3E4A39-21',
#  'C45E352646-18',
#  'C45D594B5F-18',
#  'C50235262430-21',
#  'C45D2B5C23-18',
#  'C45D5D063B-18',
#  'C502322F1532-21',
#  'C45D14612F-18',
#  'C5022F252602-21',
#  'C45D146428-18',
#  'C5022129222A-20',
#  'C5024359125E-22',
#  'C4522C5318-17',
#  'C45F645521-18',
#  'C50216032553-19',
#  'C456355D2B-17',
#  'C463274D40-18',
#  'C454574E04-17',
#  'C462161202-18',
#  'C451554D31-17',
#  'C46421182D-18',
#  'C4571A1C54-17',
#  'C461024F1E-18',
#  'C461020C21-18',
#  'C4645B1A08-18',
#  'C46004544F-18',
#  'C502185F545B-19',
#  'C46331582E-18',
#  'C5020240031C-18',
#  'C45F615E50-18',
#  'C4605E1212-18',
#  'C458295916-17',
#  'C45F645336-18',
#  'C45F645040-18',
#  'C5020734352F-18',
#  'C45D250C22-18',
#  'C5022E09464C-21',
#  'C502073B0908-18',
#  'C5020112062C-18',
#  'C502031E3562-18',
#  'C50207363212-18',
#  'C5020A1C3E61-19',
#  'C4595B5E33-18',
#  'C4514C2D0C-17',
#  'C463416334-18',
#  'C460045960-18',
#  'C459396342-18',
#  'C45B575240-18',
#  'C463391C64-18',
#  'C50221523741-20',
#  'C410442222-i17',
#  'C4571A1226-17',
#  'C456356119-17',
#  'C45F615A03-18',
#  'C45F615C12-18',
#  'C460290809-18',
#  'C45A612F43-18',
#  'C45A613023-18',
#  'C464031B62-18',
#  'C4103C2D31-i17',
#  'C463524D30-18',
#  'C50248545552-23',
#  'C5024A440243-23',
#  'C463151A52-18',
#  'C460045245-18',
#  'C463395709-18',
#  'C502154C3B5A-19',
#  'C50241015B30-22',
#  'C5020D112243-19',
#  'C5020D112214-19',
#  'C502202C430C-20',
#  'C45F512C55-18',
#  'C463402B0B-18',
#  'C5020B331619-19',
#  'C4514C2E10-17',
#  'C45F574A30-18',
#  'C4514C3056-17',
#  'C4513D3E1B-17',
#  'C50238180804-21',
#  'C50236021F40-21',
#  'C502425C3C41-22',
#  'C5021E624F50-19',
#  'C463281A51-18',
#  'C502250D3546-20',
#  'C5022C1E6264-20',
#  'C45F615D62-18',
#  'C5024322470E-22',
#  'C50220520707-20',
#  'C45A3E2849-18',
#  'C4605E1262-18',
#  'C502244B161E-20',
#  'C50253103D40-24',
#  'C502320E4C08-21',
#  'C460045C26-18',
#  'C459523803-18',
#  'C459523A54-18',
#  'C45457414A-17',
#  'C41034275B-i17',
#  'C410442121-i17',
#  'C410342A35-i17',
#  'C5023B0A092A-22',
#  'C456242252-17',
#  'C46340445C-18',
#  'C5022C0D1941-20',
#  'C5022D0F282B-21',
#  'C5022D395350-21',
#  'C5023E5B4E12-22',
#  'C5024A3B3328-23',
#  'C5022C194806-20',
#  'C5022C0D1921-20',
#  'C45E53120A-18',
#  'C45F0D5F17-18',
#  'C5023A090C5E-22',
#  'C4612A5114-18',
#  'C4644B3944-18',
#  'C502022E0919-18',
#  'C459523C55-18',
#  'C45E565927-18',
#  'C50234330956-21',
#  'C459523C1E-18',
#  'C34F1005-i10',
#  'C40D1F464B-i16',
#  'C406194006-i12',
#  'C403565037-i11',
#  'C4071A3E1E-i13',
#  'C5025216514A-23',
#  'C4083C2256-i13',
#  'C30F150A-i08',
#  'C5023819411A-21',
#  'C5022A2E113D-20',
#  'C5022D124D22-21',
#  'C403564A24-i11',
#  'C5023A432D2B-22',
#  'C5022B421F62-20',
#  'C406271759-i12',
#  'C3053953-i05',
#  'C40A073E42-i14',
#  'C40A074926-i14',
#  'C3053B5A-i05',
#  'C502241C1E14-20',
#  'C40A074150-i14',
#  'C40341432F-i11',
#  'C403414558-i11',
#  'C40342273E-i11',
#  'C5023819404D-21',
#  'C410371231-i17',
#  'C403430605-i11',
#  'C403430E1D-i11',
#  'C406271605-i12',
#  'C317145C-i10',
#  'C3171514-i10',
#  'C30F1513-i08',
#  'C403446448-i11',
#  'C403453361-i11',
#  'C5022A2E1164-20',
#  'C46456260D-18',
#  'C4062B0931-i12',
#  'C4062B0A64-i12',
#  'C3560742-i10',
#  'C317161A-i10',
#  'C3171527-i10',
#  'C403450A5B-i11',
#  'C403450843-i11',
#  'C40627171E-i12',
#  'C5022D5F180A-21',
#  'C502314D584A-21',
#  'C35609-i10',
#  'C408155352-i13',
#  'C403414A4D-i11',
#  'C4094C1B25-i14',
#  'C40341402F-i11',
#  'C40342645F-i11',
#  'C40343032B-i11',
#  'C403413413-i11',
#  'C40342134D-i11',
#  'C40342090E-i11',
#  'C40B0C0934-i14',
#  'C50238065053-21',
#  'C403450207-i11',
#  'C4065D471D-i12',
#  'C305384F-i05',
#  'C40D323A4F-i16',
#  'C40A074031-i14',
#  'C5022434471B-20',
#  'C5022339453D-20',
#  'C40619512D-i12',
#  'C35B5E54-i10',
#  'C402341A5C-i10',
#  'C3053C21-i05',
#  'C40730424E-i13',
#  'C5024854562E-23',
#  'C5024B40031C-23',
#  'C4082B5758-i13',
#  'C35B5E13-i10',
#  'C4082B092A-i13',
#  'C5020243113C-18',
#  'C403423F2D-i11',
#  'C403423A0F-i11',
#  'C403423557-i11',
#  'C40342594B-i11',
#  'C5023E013407-22',
#  'C4083F050C-i13',
#  'C4071B3A2F-i13',
#  'C4084E374E-i13',
#  'C5023D3E1A57-22',
#  'C5024F332812-23',
#  'C403431527-i11',
#  'C4061E1204-i12',
#  'C502152A1439-19',
#  'C40C0C2416-i15',
#  'C4034C5713-i11',
#  'C50241015C07-22',
#  'C40C535505-i15',
#  'C50251095F35-23',
#  'C40E025F37-i16',
#  'C403415012-i11',
#  'C356081E-i10',
#  'C403415312-i11',
#  'C402341C3E-i10',
#  'C403453210-i11',
#  'C3171530-i10',
#  'C50238180862-21',
#  'C50236022021-21',
#  'C50238284662-21',
#  'C4041E3608-i11',
#  'C403414824-i11',
#  'C34D302C-i10',
#  'C408623D5C-i13',
#  'C317143D-i10',
#  'C3171448-i10',
#  'C409361139-i13',
#  'C403413E0D-i11',
#  'C34D2A55-i10',
#  'C403414D12-i11',
#  'C502140E4F23-19',
#  'C403415612-i11',
#  'C4515E5D07-17',
#  'C5023A431A0E-22',
#  'C5022A2E1116-20',
#  'C403413B39-i11',
#  'C403421D11-i11',
#  'C404496145-i11',
#  'C35607-i10',
#  'C402341B3D-i10',
#  'C5023B0A0A33-22',
#  'C403492959-i11',
#  'C5023527433C-21',
#  'C403421A11-i11',
#  'C4034C2D0B-i11',
#  'C5022A2E1030-20',
#  'C5022E1C213D-21',
#  'C406200215-i12',
#  'C40A073F07-i14',
#  'C403426209-i11',
#  'C403430B25-i11',
#  'C403430861-i11',
#  'C3171434-i10',
#  'C3054541-i05',
#  'C405112108-i12',
#  'C408602D0C-i13',
#  'C4084A5253-i13',
#  'C40E44021D-i16',
#  'C34F1037-i10',
#  'C34D263D-i10',
#  'C34D2619-i10',
#  'C502514F640F-23',
#  'C403565664-i11',
#  'C403565240-i11',
#  'C403564C33-i11',
#  'C403492439-i11',
#  'C40348634D-i11',
#  'C40356474A-i11',
#  'C403422952-i11',
#  'C40356453E-i11',
#  'C403490504-i11',
#  'C40342252B-i11',
#  'C403485703-i11',
#  'C403564337-i11',
#  'C4042F5340-i11',
#  'C40348491B-i11',
#  'C403485C1E-i11',
#  'C403564023-i11',
#  'C403492F1B-i11',
#  'C40342302A-i11',
#  'C403580E43-i11',
#  'C403563B1A-i11',
#  'C403491527-i11',
#  'C403493A62-i11',
#  'C40345062B-i11',
#  'C40349350F-i11',
#  'C403491E5F-i11',
#  'C403483F43-i11',
#  'C4034C2A25-i11',
#  'C4034C3003-i11',
#  'C4034C3B03-i11',
#  'C408242F4C-i13',
#  'C5023C490F2C-22',
#  'C5023C555C02-22',
#  'C5023C57542D-22',
#  'C5023C555B28-22',
#  'C5023C490E5B-22',
#  'C5023C490E2A-22',
#  'C5023C641E45-22',
#  'C5023D1F5939-22',
#  'C5023C490D5E-22',
#  'C5023D373055-22',
#  'C5023C491103-22',
#  'C5023C490D20-22',
#  'C5023D37341F-22',
#  'C5023D1F5857-22',
#  'C5023D1F5736-22',
#  'C5023C490C54-22',
#  'C5023D5D250D-22',
#  'C403073C4D-i11',
#  'C40932543E-i13',
#  'C4035C2A3F-i11',
#  'C4035C4223-i11',
#  'C4035C4262-i11',
#  'C40835454F-i13',
#  'C5023C490F5C-22',
#  'C5023C49102E-22',
#  'C5023C575507-22',
#  'C5023C641F1C-22',
#  'C5023D3E1E48-22',
#  'C5023D1E1F3A-22',
#  'C5023D1E1E5C-22',
#  'C5023C491131-22',
#  'C41033160C-i17',
#  'C5023B5F5E0A-22',
#  'C410441D59-i17',
#  'C4065B150F-i12',
#  'C4065B1427-i12',
#  'C4100F4A53-i17',
#  'C5020A092A62-19',
#  'C405310E35-i12',
#  'C4095D1324-i14',
#  'C4095F4B5F-i14',
#  'C409361562-i13',
#  'C40B0B3732-i14',
#  'C407083D33-i12',
#  'C407083D13-i12',
#  'C408062161-i13',
#  'C408501408-i13',
#  'C3071E3E-i05',
#  'C50233221823-21',
#  'C40401081D-i11',
#  'C4042A3F07-i11',
#  'C404553D1B-i12',
#  'C404564E11-i12',
#  'C404565030-i12',
#  'C404564F53-i12',
#  'C404564F2B-i12',
#  'C404564E5B-i12',
#  'C4051E0D18-i12',
#  'C407301735-i13',
#  'C5023235215F-21',
#  'C502132C393B-19',
#  'C50225033961-20',
#  'C5021C303723-19',
#  'C312413C-i09',
#  'C30F5B4A-i08',
#  'C4025E6129-i11',
#  'C3161238-i10',
#  'C5022D2D3C64-21',
#  'C3124061-i09',
#  'C312405C-i09',
#  'C502455A5637-23',
#  'C404224235-i11',
#  'C3553603-i10',
#  'C5022F1C0D2A-21',
#  'C3124137-i09',
#  'C403214909-i11',
#  'C404331702-i11',
#  'C502533D3B36-24',
#  'C30C1F4F-i06',
#  'C3100F62-i08',
#  'C3123302-i09',
#  'C50213082F05-19',
#  'C502481E021C-23',
#  'C5024F520F2C-23',
#  'C3180E54-i10',
#  'C3180D3D-i10',
#  'C4030A033A-i11',
#  'C4030A0410-i11',
#  'C40F584052-i17',
#  'C40E1D3113-i16',
#  'C40E1D3048-i16',
#  'C3161F48-i10',
#  'C40511114D-i12',
#  'C35C1F4F-i10',
#  'C403021913-i11',
#  'C307182E-i05',
#  'C40A08541B-i14',
#  'C50238584740-22',
#  'C5023E5E5920-22',
#  'C5024E282B30-23',
#  'C5020A190E4D-19',
#  'C5020A191006-19',
#  'C30F1B46-i08',
#  'C45B064E23-18',
#  'C502294B4B4B-20',
#  'C40F3B5A1E-i17',
#  'C40F3B5952-i17',
#  'C30C1F57-i06',
#  'C502132C4306-19',
#  'C502533E104F-24',
#  'C30C2817-i06',
#  'C40F3B5922-i17',
#  'C3123F56-i09',
#  'C50226314C3F-20',
#  'C502040A5B-18',
#  'C50251065327-23',
#  'C40A25133E-i14',
#  'C5022D4D0647-21',
#  'C405200928-i12',
#  'C4071C0F61-i13',
#  'C34D2628-i10',
#  'C403083A3F-i11',
#  'C404126210-i11',
#  'C404125B45-i11',
#  'C4041311-i11',
#  'C404125A1C-i11',
#  'C404125E3C-i11',
#  'C404126035-i11',
#  'C404125C61-i11',
#  'C45E353C48-18',
#  'C40E363D62-i16',
#  'C403242A0E-i11',
#  'C5023C3C5B-22',
#  'C5024B372964-23',
#  'C5024B121C08-23',
#  'C4064D611E-i12',
#  'C40252551C-i10',
#  'C50223445A34-20',
#  'C35024-i10',
#  'C4030E2F59-i11',
#  'C4030E3852-i11',
#  'C40828551B-i13',
#  'C40661490E-i12',
#  'C3560943-i10',
#  'C5024D201402-23',
#  'C403143732-i11',
#  'C4025F31-i11',
#  'C34D1F4B-i10',
#  'C4375D3005-16',
#  'C403105729-i11',
#  'C403105630-i11',
#  'C40D56540B-i16',
#  'C35C0B44-i10',
#  'C45A030144-18',
#  'C459251D09-17',
#  'C3071D2A-i05',
#  'C405381826-i12',
#  'C40B033443-i14',
#  'C408494819-i13',
#  'C404010845-i11',
#  'C5022F286048-21',
#  'C405070E15-i12',
#  'C4064D6202-i12',
#  'C45A2E521A-18',
#  'C4090C4718-i13',
#  'C4084E4035-i13',
#  'C4083F151A-i13',
#  'C4080F4717-i13',
#  'C4083F1722-i13',
#  'C4083F162C-i13',
#  'C408125F04-i13',
#  'C408510709-i13',
#  'C40427485C-i11',
#  'C40C195E4F-i15',
#  'C502515D594A-23',
#  'C502515D5A3E-23',
#  'C502515D5A12-23',
#  'C5021804395B-19',
#  'C50218043C2F-19',
#  'C50218043B19-19',
#  'C5023E52424A-22',
#  'C5023C490930-22',
#  'C5023C49095A-22',
#  'C5023C490A1C-22',
#  'C5023C490A4C-22',
#  'C5023C490B15-22',
#  'C4075B042E-i13',
#  'C4075A3451-i13',
#  'C50249064250-23',
#  'C5024D201447-23',
#  'C5023C1D1D4D-22',
#  'C5024460081A-23',
#  'C50216011D31-19',
#  'C408144F0B-i13',
#  'C4042B5526-i11',
#  'C502031E3423-18',
#  'C404332832-i11',
#  'C404332853-i11',
#  'C5020D3C2761-19',
#  'C5020625255D-18',
#  'C50226032F23-20',
#  'C50229120D29-20',
#  'C50205524313-18',
#  'C463390919-18',
#  'C40634364C-i12',
#  'C4103E353C-i17',
#  'C4435C2608-16',
#  'C4435C275E-16',
#  'C45C453734-18',
#  'C45F1122-18',
#  'C45E4E050B-18',
#  'C40F245118-i16',
#  'C5024D2E2C58-23',
#  'C40A110832-i14',
#  'C5021A2F6057-19',
#  'C40D300706-i16',
#  'C40F646163-i17',
#  'C502020C1542-18',
#  'C45455203C-17',
#  'C459325146-18',
#  'C50205060425-18',
#  'C45B0F2836-18',
#  'C454552135-17',
#  'C50236021E64-21',
#  'C50249624E40-23',
#  'C40D394321-i16',
#  'C40D39410C-i16',
#  'C5023E152E5C-22',
#  'C5023E10450D-22',
#  'C5023F0A2F4B-22',
#  'C5023F3C0B-22',
#  'C5023D37300E-22',
#  'C5024D141925-23',
#  'C405101417-i12',
#  'C50213640345-19',
#  'C5020734365B-18',
#  'C406624D06-i12',
#  'C5020D244405-19',
#  'C40E115738-i16',
#  'C435601263-16',
#  'C4355F4E2E-16',
#  'C50225181726-20',
#  'C40B195A5E-i14',
#  'C40B0A1859-i14',
#  'C5024854551D-23',
#  'C5024854543E-23',
#  'C5022E5B0727-21',
#  'C4075B1838-i13',
#  'C50251174452-23',
#  'C50253023204-24',
#  'C5024F0C5A22-23',
#  'C406244B11-i12',
#  'C5024412365B-22',
#  'C502434D3424-22',
#  'C502435E630C-22',
#  'C5024934391E-23',
#  'C50243213663-22',
#  'C454574810-17',
#  'C502334C5D24-21',
#  'C4091C2952-i13',
#  'C40B4D2016-i15',
#  'C50248474B5C-23',
#  'C4091C3427-i13',
#  'C4103C551D-i17',
#  'C5022209385E-20',
#  'C40C19493A-i15',
#  'C50215634936-19',
#  'C40F3B293B-i17',
#  'C40F3B2910-i17',
#  'C40F3B281E-i17',
#  'C40F3B2849-i17',
#  'C40D1E3D04-i16',
#  'C50225403158-20',
#  'C50209473535-19',
#  'C40535612A-i12',
#  'C50220080D4C-20',
#  'C502352C1C4C-21',
#  'C34C1C34-i10',
#  'C34C1C41-i10',
#  'C50232053C56-21',
#  'C405562A2D-i12',
#  'C405562A0D-i12',
#  'C5023413395E-21',
#  'C5023B5A2205-22',
#  'C502332E1D09-21',
#  'C4083F145D-i13',
#  'C3044F54-i05',
#  'C50220131E31-20',
#  'C4103E3718-i17',
#  'C50224263242-20',
#  'C50209033532-19',
#  'C5021F4F5F3B-20',
#  'C4052E1D5F-i12',
#  'C50220211B25-20',
#  'C50237374A0B-21',
#  'C40E373B1B-i16',
#  'C407140824-i12',
#  'C40539155D-i12',
#  'C40714083F-i12',
#  'C4084C4F50-i13',
#  'C408362A54-i13',
#  'C408362B32-i13',
#  'C4084F1320-i13',
#  'C4083D351B-i13',
#  'C408445706-i13',
#  'C50222573309-20',
#  'C40F5A0148-i17',
#  'C40F5A0112-i17',
#  'C3502525-i10',
#  'C3502464-i10',
#  'C45D543F57-18',
#  'C45D543E1A-18',
#  'C5021F222448-20',
#  'C5021E525224-19',
#  'C40427245B-i11',
#  'C405102B3D-i12',
#  'C40510290E-i12',
#  'C405102A23-i12',
#  'C5022F0C633A-21',
#  'C5022F0C640A-21',
#  'C5022E26534B-21',
#  'C4074B2327-i13',
#  'C4074B163A-i13',
#  'C408492547-i13',
#  'C4061E010F-i12',
#  'C3053262-i05',
#  'C4043A1611-i11',
#  'C405103006-i12',
#  'C4074B445A-i13',
#  'C404272511-i11',
#  'C40A61145E-i14',
#  'C4061D0728-i12',
#  'C309131D-i06',
#  'C3072E56-i05',
#  'C4074B2C52-i13',
#  'C4052D5F4E-i12',
#  'C40F40533A-i17',
#  'C40427254A-i11',
#  'C40232462F-i10',
#  'C40624425F-i12',
#  'C3072A5C-i05',
#  'C4042A3E46-i11',
#  'C5020B514514-19',
#  'C404180C0C-i11',
#  'C406172437-i12',
#  'C405065731-i12',
#  'C405065E3D-i12',
#  'C40E025602-i16',
#  'C405103037-i12',
#  'C404280A21-i11',
#  'C4045C481F-i12',
#  'C406275049-i12',
#  'C406275438-i12',
#  'C3072B06-i05',
#  'C4061D0A23-i12',
#  'C406294003-i12',
#  'C408464D02-i13',
#  'C4061F542B-i12',
#  'C406335424-i12',
#  'C40A34072F-i14',
#  'C4063E472E-i12',
#  'C4061D264E-i12',
#  'C502071F5247-18',
#  'C406275A27-i12',
#  'C406455A5C-i12',
#  'C406453818-i12',
#  'C406244910-i12',
#  'C40432613B-i11',
#  'C40432631A-i11',
#  'C4062C5E07-i12',
#  'C4061D2417-i12',
#  'C309134D-i06',
#  'C404272532-i11',
#  'C40432625E-i11',
#  'C403212D2C-i11',
#  'C40708484B-i12',
#  'C3053342-i05',
#  'C405103214-i12',
#  'C40510155D-i12',
#  'C409040814-i13',
#  'C45A3E2345-18',
#  'C406244A0C-i12',
#  'C40626192D-i12',
#  'C406600D16-i12',
#  'C4061D0E0A-i12',
#  'C4061D0861-i12',
#  'C40861143F-i13',
#  'C407220344-i13',
#  'C406293C12-i12',
#  'C4061D0A39-i12',
#  'C406330334-i12',
#  'C4061D0A0D-i12',
#  'C4061D0A60-i12',
#  'C406330C-i12',
#  'C405112656-i12',
#  'C42E4B4612-15',
#  'C405112739-i12',
#  'C40D042954-i15',
#  'C4051128-i12',
#  'C4025E6140-i11',
#  'C3091D2F-i06',
#  'C3091D3C-i06',
#  'C3091E55-i06',
#  'C309130B-i06',
#  'C3072B12-i05',
#  'C45127134A-17',
#  'C3091D14-i06',
#  'C3113C12-i08',
#  'C50217382631-19',
#  'C5022D0B3A20-21',
#  'C50246562C2E-23',
#  'C502380E3E02-21',
#  'C50248243A64-23',
#  'C40C1A2102-i15',
#  'C40C065462-i15',
#  'C40E130239-i16',
#  'C40D38295E-i16',
#  'C40E4B2344-i16',
#  'C40B463930-i15',
#  'C40A3A3B4B-i14',
#  'C409541F1E-i14',
#  'C4092C5202-i13',
#  'C4094B1510-i14',
#  'C40C076327-i15',
#  'C40C074E02-i15',
#  'C40C075703-i15',
#  'C40C074C33-i15',
#  'C40C074D49-i15',
#  'C50217383319-19',
#  'C5021738324A-19',
#  'C40901612E-i13',
#  'C40901614F-i13',
#  'C40C074902-i15',
#  'C40C07614F-i15',
#  'C40C074653-i15',
#  'C40C074802-i15',
#  'C40C07512F-i15',
#  'C40C075115-i15',
#  'C4094A054D-i14',
#  'C408421C0E-i13',
#  'C408421A61-i13',
#  'C40C07620F-i15',
#  'C40C07622E-i15',
#  'C40C075212-i15',
#  'C40C07514F-i15',
#  'C4094B1455-i14',
#  'C40F2E2D27-i17',
#  'C5023B34325D-22',
#  'C40C075253-i15',
#  'C40C075003-i15',
#  'C50231403231-21',
#  'C4101E204C-i17',
#  'C410225E1F-i17',
#  'C5022B1B2436-20',
#  'C40B103E3B-i14',
#  'C4592D540E-17',
#  'C4592D5339-17',
#  'C5021E1E4C51-19',
#  'C5021E1E4C22-19',
#  'C40C521247-i15',
#  'C403410939-i11',
#  'C403410A15-i11',
#  'C403410964-i11',
#  'C403410A29-i11',
#  'C405582450-i12',
#  'C403410951-i11',
#  'C403410A3D-i11',
#  'C40A615C4D-i14',
#  'C40A615D12-i14',
#  'C502500C5316-23',
#  'C457145E22-17',
#  'C5020B52072D-19',
#  'C40808163F-i13',
#  'C460592F51-18',
#  'C4103C253E-i17',
#  'C4103C250C-i17',
#  'C4103C2525-i17',
#  'C5020B520749-19',
#  'C40C48503D-i15',
#  'C40662220D-i12',
#  'C502311E4D4E-21',
#  'C5024010511E-22',
#  'C50240105061-22',
#  'C40C550807-12',
#  'C409600D4D-i14',
#  'C409600E1F-i14',
#  'C5024A074632-23',
#  'C454552552-17',
#  'C406262038-i12',
#  'C406261F43-i12',
#  'C406261A47-i12',
#  'C406261C02-i12',
#  'C406261D43-i12',
#  'C406261E4C-i12',
#  'C41023175E-i17',
#  'C502343A4652-21',
#  'C4084A4616-i13',
#  'C5021E180A5F-19',
#  'C45202271E-17',
#  'C5023E396147-22',
#  'C5023E3D4645-22',
#  'C5023E5E5A0C-22',
#  'C461043744-18',
#  'C40C111945-i15',
#  'C4590C1B64-17',
#  'C40C2C5B05-i15',
#  'C40C024D47-i15',
#  'C40C024E15-i15',
#  'C40C195433-i15',
#  'C408261038-i13',
#  'C50223391E42-20',
#  'C3071E19-i05',
#  'C3135929-i09',
#  'C3071E25-i05',
#  'C5020449381B-18',
#  'C409200B48-i13',
#  'C502401D425F-22',
#  ...]

# %%
holder[0]
# Out:
# 'C404374004-i11'

# %%
import pandas as pd
import re
def clean_str(string):
    clean_s = re.sub(r'[\xa0\r\n]+', ' ', string).strip()
    clean_s = re.sub(r'\s+', ' ', clean_s)
    return clean_s

# %%
holder.to_csv("SG MDR.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 holder.to_csv("SG MDR.csv")
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
response = requests.get('https://eservice.hsa.gov.sg/medics/md/mdEnquiry.do?action=getDeviceInfo&devId='+holder[0])
soup = BeautifulSoup(response.text)

# %%
tables = soup.find_all('table', {'class':'fmTbl'})
device_info = pd.read_html(str(tables[0]))[0]
device_info = device_info.transpose()
device_info.columns = device_info.iloc[0]
device_info = device_info[1:]
model_flag = False
product_owner = ''
registrant = ''
for i, table in enumerate(tables[1:]):
    print(i)
    print(table.text)
    
    if 'Product Owner' in table.text:
        product_owner = clean_str(tables[i+2].text)
        
    if 'Registrant' in table.text:
        registrant = clean_str(tables[i+2].text.strip())
 
    if 'Models'in table.text:
        model_flag = True
        models = table.find_next_sibling('table')
        models = pd.read_html(str(models))[0]
        models.columns = models.iloc[0]
        models = models[1:]
          
            
            
            
if model_flag:
    data = device_info.join(models)
            
data['Product Owner'] = product_owner
data['Registrant'] = registrant
data['href'] = href
# Out:
# 0
#
#
#
#
# Product Owner
#
#
#
#
# 1
#
#
# 1.  3M Deutschland GmbH
#        [3M Deutschland GmbH] Health Care Business, Carl-Schurz-Straβe-1, 41453 Neuss, GERMANY
#
#
#
# 2
#
#
#
#
# Registrant
#
#
#
#
# 3
#
#
# 1.  3M TECHNOLOGIES (S) PTE. LTD.
#
#       10 ANG MO KIO STREET 65, TECHPOINT,  #01-01, SINGAPORE 569059
#
#
#
# 4
#
#
#
#
# Models
#
#
#
#
# 5
#
#
#
# Close
#
#
# 6
#
#
#
#
#
#
#
#
# Note: All device listings on the Singapore Medical Device Register (SMDR) are active. Class A medical devices are not registered in the SMDR. To retrieve Class A medical devices, please visit Class A Medical Device Database.

# %%
device_info
# Out:
# 0                                       Device Name:  \
# 1  3M ADAPTIC* Non-Adhering Dressing [3M Deutschl...
#
# 0                                       Description: Medical Specialty Area:  \
# 1  ADAPTIC* Non-Adhering Dressing is applied dire...        General Hospital
#
# 0   Medical Device Class: Device Registration No: Registration Date:  \
# 1  Class C medical device               DE0007928         17/11/2011
#
# 0 Change Notification Approval Date:  NaN
# 1                         26/10/2022  NaN

# %%
models
# Out:
# 0 No.                      Model Name Identifier UDI-DI DM-DI  \
# 1   1  ADAPTIC* Non-Adhering Dressing       2012    NaN   NaN
# 2   2  ADAPTIC* Non-Adhering Dressing       2013    NaN   NaN
# 3   3  ADAPTIC* Non-Adhering Dressing       2014    NaN   NaN
# 4   4  ADAPTIC* Non-Adhering Dressing       2015    NaN   NaN
# 5   5  ADAPTIC* Non-Adhering Dressing       2018    NaN   NaN
# 6   6  ADAPTIC* Non-Adhering Dressing       2019    NaN   NaN
#
# 0 Place of Manufacture
# 1       UNITED KINGDOM
# 2       UNITED KINGDOM
# 3       UNITED KINGDOM
# 4       UNITED KINGDOM
# 5       UNITED KINGDOM
# 6       UNITED KINGDOM

# %%
data
# Out:
# 0                                       Device Name:  \
# 1  3M ADAPTIC* Non-Adhering Dressing [3M Deutschl...
#
# 0                                       Description: Medical Specialty Area:  \
# 1  ADAPTIC* Non-Adhering Dressing is applied dire...        General Hospital
#
# 0   Medical Device Class: Device Registration No: Registration Date:  \
# 1  Class C medical device               DE0007928         17/11/2011
#
# 0 Change Notification Approval Date:  NaN No.                      Model Name  \
# 1                         26/10/2022  NaN   1  ADAPTIC* Non-Adhering Dressing
#
# 0 Identifier UDI-DI DM-DI Place of Manufacture  \
# 1       2012    NaN   NaN       UNITED KINGDOM
#
# 0                                      Product Owner  \
# 1  1. 3M Deutschland GmbH [3M Deutschland GmbH] H...
#
# 0                                         Registrant
# 1  1. 3M TECHNOLOGIES (S) PTE. LTD. 10 ANG MO KIO...
