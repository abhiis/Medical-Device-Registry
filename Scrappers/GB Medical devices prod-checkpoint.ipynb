# %%
## So we can send an search request using manufacturer names
## Let's use gateway players

# %%
import pandas as pd
major_players = pd.read_csv('IVD_gateway_major_players_actual.csv')
major_players
# Out:
#      production_cycle  study_year player_code                player_name
# 0                2023        2022      PY0196                      Roche
# 1                2023        2022      PY0006                     Abbott
# 2                2023        2022      PY0064  Danaher - Beckman Coulter
# 3                2023        2022      PY0065          Danaher - Cepheid
# 4                2023        2022      PY0066            Danaher - Leica
# ..                ...         ...         ...                        ...
# 327              2023        2022      PY9995          Boule Diagnostics
# 328              2023        2022      PY0375           Fokus Diagnostic
# 329              2023        2022      PY0397         Bioptik Technology
# 330              2023        2022      PY0338                     Inbios
# 331              2023        2022      PY0398                 Access Bio
#
# [332 rows x 4 columns]

# %%
players = major_players.player_name.values.tolist()
players = [x.lower() for x in players]
## Split out company names delimited by '-'
## Split out company names delimited by '-'
keywords = []
for name in players:
    if '-' in name:
        spread_names = name.split('-')
        for i in spread_names:
            keywords.append(i.strip())
    else:
        keywords.append(name)
print(len(set(keywords)))
keywords = list(set(keywords))
# Out:
# 345

# %%
import requests

def create_search(keyword: str):
    cookies = {
        'ai_user': 'qDSrt7CzZfzSCEycvMP+zT|2024-01-29T20:03:58.212Z',
        'ai_session': '/HXDRDIhT9HiqX48fFXqUQ|1706558638935|1706558703583',
    }

    headers = {
        'authority': 'pard.mhra.gov.uk',
        'accept': 'application/json, text/plain, */*',
        'accept-language': 'en-US,en;q=0.9',
        'content-type': 'application/json',
        # 'cookie': 'ai_user=qDSrt7CzZfzSCEycvMP+zT|2024-01-29T20:03:58.212Z; ai_session=/HXDRDIhT9HiqX48fFXqUQ|1706558638935|1706558703583',
        'origin': 'https://pard.mhra.gov.uk',
        'request-id': '|6cc42aa779a34365ba3f2d7470b2b32e.8efbfdbe8c9c45d1',
        'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'traceparent': '00-6cc42aa779a34365ba3f2d7470b2b32e-8efbfdbe8c9c45d1-01',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    }

    json_data = {
        'searchTerm': {
            'manufacturerName': keyword,
            'referenceNumber': '',
            'deviceName': '',
            'deviceType': '',
            'gmdnCode': '',
        },
    }

    response = requests.post('https://pard.mhra.gov.uk/searchDevicesAdvanced', json=json_data)
    return keyword, response

# %%
keyword, response = create_search("roche")

# %%
data = response.json()
data
# Out:
# [{'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66324,
#   'GMDN_CODE': 63262,
#   'GMDN_TERM_NAME': 'Ambulatory insulin infusion administration set',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66323,
#   'GMDN_CODE': 63810,
#   'GMDN_TERM_NAME': 'Ambulatory insulin infusion administration set/reservoir kit',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66327,
#   'GMDN_CODE': 63261,
#   'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump remote control/blood glucose analyser',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66322,
#   'GMDN_CODE': 35838,
#   'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump reservoir',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67568,
#   'GMDN_CODE': 64889,
#   'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump, electronic, non-software-dosing',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67569,
#   'GMDN_CODE': 51083,
#   'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump/blood glucose analyser system',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135746,
#   'GMDN_CODE': 61305,
#   'GMDN_TERM_NAME': 'Assay adhesive sealing/fixation film IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135747,
#   'GMDN_CODE': 62225,
#   'GMDN_TERM_NAME': 'Assay container IVD, single-use',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112983,
#   'GMDN_CODE': 58586,
#   'GMDN_TERM_NAME': 'Basic/simple nutrient broth culture medium IVD',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135728,
#   'GMDN_CODE': 51716,
#   'GMDN_TERM_NAME': 'Beta-haemolytic Group A Streptococcus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'Class B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112979,
#   'GMDN_CODE': 51716,
#   'GMDN_TERM_NAME': 'Beta-haemolytic Group A Streptococcus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135727,
#   'GMDN_CODE': 51714,
#   'GMDN_TERM_NAME': 'Beta-haemolytic Group A Streptococcus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112978,
#   'GMDN_CODE': 51714,
#   'GMDN_TERM_NAME': 'Beta-haemolytic Group A Streptococcus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135724,
#   'GMDN_CODE': 49849,
#   'GMDN_TERM_NAME': 'BK virus (BKV) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112974,
#   'GMDN_CODE': 49849,
#   'GMDN_TERM_NAME': 'BK virus (BKV) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66318,
#   'GMDN_CODE': 45142,
#   'GMDN_TERM_NAME': 'Blood lancing device tip',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135745,
#   'GMDN_CODE': 58237,
#   'GMDN_TERM_NAME': 'Buffered sample diluent IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 113001,
#   'GMDN_CODE': 58208,
#   'GMDN_TERM_NAME': 'Buffered sample diluent IVD, manual',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135744,
#   'GMDN_CODE': 58236,
#   'GMDN_TERM_NAME': 'Buffered wash solution IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 87982,
#   'GMDN_CODE': 47320,
#   'GMDN_TERM_NAME': 'Chlamydia trachomatis nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:51.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135736,
#   'GMDN_CODE': 50836,
#   'GMDN_TERM_NAME': 'Clostridium difficile nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112977,
#   'GMDN_CODE': 50836,
#   'GMDN_TERM_NAME': 'Clostridium difficile nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135737,
#   'GMDN_CODE': 30798,
#   'GMDN_TERM_NAME': 'Cytomegalovirus (CMV) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 87981,
#   'GMDN_CODE': 30798,
#   'GMDN_TERM_NAME': 'Cytomegalovirus (CMV) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:51.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 114388,
#   'GMDN_CODE': 45407,
#   'GMDN_TERM_NAME': 'Dental abrasive powder',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:03:52.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 114387,
#   'GMDN_CODE': 11168,
#   'GMDN_TERM_NAME': 'Dentifrice',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:03:52.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66320,
#   'GMDN_CODE': 35833,
#   'GMDN_TERM_NAME': 'Electric infusion pump administration set, single-use',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66319,
#   'GMDN_CODE': 35833,
#   'GMDN_TERM_NAME': 'Electric infusion pump administration set, single-use',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135722,
#   'GMDN_CODE': 49653,
#   'GMDN_TERM_NAME': 'Epstein-Barr virus (EBV) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112973,
#   'GMDN_CODE': 49653,
#   'GMDN_TERM_NAME': 'Epstein-Barr virus (EBV) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135741,
#   'GMDN_CODE': 57898,
#   'GMDN_TERM_NAME': 'Evacuated blood collection tube IVD, nucleic acid stabilizer',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135743,
#   'GMDN_CODE': 60094,
#   'GMDN_TERM_NAME': 'Exogenous DNA/RNA internal control IVD, kit',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112985,
#   'GMDN_CODE': 60094,
#   'GMDN_TERM_NAME': 'Exogenous DNA/RNA internal control IVD, kit',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135720,
#   'GMDN_CODE': 62773,
#   'GMDN_TERM_NAME': 'General specimen collection kit IVD, clinical',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112989,
#   'GMDN_CODE': 62773,
#   'GMDN_TERM_NAME': 'General specimen collection kit IVD, clinical',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135716,
#   'GMDN_CODE': 63232,
#   'GMDN_TERM_NAME': 'General specimen container IVD, additive/medium',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112991,
#   'GMDN_CODE': 63232,
#   'GMDN_TERM_NAME': 'General specimen container IVD, additive/medium',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 148465,
#   'GMDN_CODE': 47775,
#   'GMDN_TERM_NAME': 'General specimen container IVD, no additive/medium',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112969,
#   'GMDN_CODE': 47775,
#   'GMDN_TERM_NAME': 'General specimen container IVD, no additive/medium',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66328,
#   'GMDN_CODE': 41819,
#   'GMDN_TERM_NAME': 'Glucose IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66325,
#   'GMDN_CODE': 53307,
#   'GMDN_TERM_NAME': 'Glucose IVD, reagent',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66326,
#   'GMDN_CODE': 62537,
#   'GMDN_TERM_NAME': 'Glucose monitoring system IVD, home-use',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75123,
#   'GMDN_CODE': 48307,
#   'GMDN_TERM_NAME': 'Hepatitis B virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-11-18T02:32:04.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75121,
#   'GMDN_CODE': 48374,
#   'GMDN_TERM_NAME': 'Hepatitis C virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:12.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 180290,
#   'GMDN_CODE': 48414,
#   'GMDN_TERM_NAME': 'Hepatitis E virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class D',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135732,
#   'GMDN_CODE': 49539,
#   'GMDN_TERM_NAME': 'Herpes simplex virus 1 & 2 (HSV1 & 2) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112972,
#   'GMDN_CODE': 49539,
#   'GMDN_TERM_NAME': 'Herpes simplex virus 1 & 2 (HSV1 & 2) nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75117,
#   'GMDN_CODE': 30768,
#   'GMDN_TERM_NAME': 'HIV1 nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:12.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75122,
#   'GMDN_CODE': 48218,
#   'GMDN_TERM_NAME': 'HIV1/Hepatitis C virus/Hepatitis B virus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:12.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 168975,
#   'GMDN_CODE': 48216,
#   'GMDN_TERM_NAME': 'HIV1/Hepatitis C virus/Hepatitis B virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-10-14T03:31:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75118,
#   'GMDN_CODE': 48446,
#   'GMDN_TERM_NAME': 'HIV1/HIV2 antigen/antibody IVD, kit, chemiluminescent immunoassay',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:12.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75119,
#   'GMDN_CODE': 48443,
#   'GMDN_TERM_NAME': 'HIV1/HIV2 nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:12.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67571,
#   'GMDN_CODE': 18118,
#   'GMDN_TERM_NAME': 'Home healthcare information system',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67570,
#   'GMDN_CODE': 44081,
#   'GMDN_TERM_NAME': 'Home healthcare information system application software',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67572,
#   'GMDN_CODE': 44081,
#   'GMDN_TERM_NAME': 'Home healthcare information system application software',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 41239,
#   'DEVICE_ID': 95026,
#   'GMDN_CODE': 61777,
#   'GMDN_TERM_NAME': 'Human genomic analysis interpretive software',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112998,
#   'GMDN_CODE': 61777,
#   'GMDN_TERM_NAME': 'Human genomic analysis interpretive software',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135717,
#   'GMDN_CODE': 49997,
#   'GMDN_TERM_NAME': 'Human papillomavirus (HPV) high risk strain nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112975,
#   'GMDN_CODE': 49997,
#   'GMDN_TERM_NAME': 'Human papillomavirus (HPV) high risk strain nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112995,
#   'GMDN_CODE': 52768,
#   'GMDN_TERM_NAME': 'Human papillomavirus (HPV) nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 103453,
#   'DEVICE_ID': 162195,
#   'GMDN_CODE': 44294,
#   'GMDN_TERM_NAME': 'Infant sleep positioner',
#   'DEVICE_SUB_TYPE_DESC': 'Custom-made',
#   'IS_CUSTOM_MADE': 'Yes',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:09:02.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112968,
#   'GMDN_CODE': 47277,
#   'GMDN_TERM_NAME': 'Influenza A/B virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135735,
#   'GMDN_CODE': 59586,
#   'GMDN_TERM_NAME': 'Inherited thrombophilia IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112984,
#   'GMDN_CODE': 59586,
#   'GMDN_TERM_NAME': 'Inherited thrombophilia IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135721,
#   'GMDN_CODE': 62011,
#   'GMDN_TERM_NAME': 'Instrument/analyser specimen/reagent container carrier IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66321,
#   'GMDN_CODE': 60415,
#   'GMDN_TERM_NAME': 'Insulin infusion cannula introducer',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 122241,
#   'GMDN_CODE': 58025,
#   'GMDN_TERM_NAME': 'Laboratory container/microscope slide robotic transfer system IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135725,
#   'GMDN_CODE': 43472,
#   'GMDN_TERM_NAME': 'Laboratory instrument/analyser application software IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67574,
#   'GMDN_CODE': 37243,
#   'GMDN_TERM_NAME': 'Manual blood lancing device, reusable',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66316,
#   'GMDN_CODE': 37243,
#   'GMDN_TERM_NAME': 'Manual blood lancing device, reusable',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 92126,
#   'GMDN_CODE': 61578,
#   'GMDN_TERM_NAME': 'Manual blood lancing device, single-use',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 114389,
#   'GMDN_CODE': 63385,
#   'GMDN_TERM_NAME': 'Medical device cleaning agent',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-08-29T03:31:25.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 114390,
#   'GMDN_CODE': 58077,
#   'GMDN_TERM_NAME': 'Medical device cleaning/disinfection wipe',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:03:52.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 94419,
#   'GMDN_CODE': 58077,
#   'GMDN_TERM_NAME': 'Medical device cleaning/disinfection wipe',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 94421,
#   'GMDN_CODE': 58077,
#   'GMDN_TERM_NAME': 'Medical device cleaning/disinfection wipe',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 94420,
#   'GMDN_CODE': 47631,
#   'GMDN_TERM_NAME': 'Medical device disinfection agent',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 94422,
#   'GMDN_CODE': 47631,
#   'GMDN_TERM_NAME': 'Medical device disinfection agent',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 122240,
#   'GMDN_CODE': 61296,
#   'GMDN_TERM_NAME': 'Microplate IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 180292,
#   'GMDN_CODE': 62690,
#   'GMDN_TERM_NAME': 'Molecular grade procedure oil IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112992,
#   'GMDN_CODE': 64569,
#   'GMDN_TERM_NAME': 'MRSA phenotype detection IVD, kit, bioassay',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135734,
#   'GMDN_CODE': 62774,
#   'GMDN_TERM_NAME': 'MRSA/MSSA nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112990,
#   'GMDN_CODE': 62774,
#   'GMDN_TERM_NAME': 'MRSA/MSSA nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135733,
#   'GMDN_CODE': 60864,
#   'GMDN_TERM_NAME': 'MRSA/MSSA nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112987,
#   'GMDN_CODE': 60864,
#   'GMDN_TERM_NAME': 'MRSA/MSSA nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 122244,
#   'GMDN_CODE': 59947,
#   'GMDN_TERM_NAME': 'Multiple congenital aneuploidy screening IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135726,
#   'GMDN_CODE': 59947,
#   'GMDN_TERM_NAME': 'Multiple congenital aneuploidy screening IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 41239,
#   'DEVICE_ID': 95027,
#   'GMDN_CODE': 59947,
#   'GMDN_TERM_NAME': 'Multiple congenital aneuploidy screening IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:01:05.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 153537,
#   'GMDN_CODE': 63334,
#   'GMDN_TERM_NAME': 'Multiple human parainfluenza virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:07:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135723,
#   'GMDN_CODE': 61351,
#   'GMDN_TERM_NAME': 'Multiple immunocompromised host infection-associated virus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112988,
#   'GMDN_CODE': 61351,
#   'GMDN_TERM_NAME': 'Multiple immunocompromised host infection-associated virus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112970,
#   'GMDN_CODE': 47920,
#   'GMDN_TERM_NAME': 'Multiple respiratory virus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112971,
#   'GMDN_CODE': 47922,
#   'GMDN_TERM_NAME': 'Multiple respiratory virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-09-23T03:31:45.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 153538,
#   'GMDN_CODE': 47923,
#   'GMDN_TERM_NAME': 'Multiple respiratory virus nucleic acid IVD, reagent',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:07:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135730,
#   'GMDN_CODE': 47920,
#   'GMDN_TERM_NAME': 'Multiple-genus respiratory virus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'Class B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135729,
#   'GMDN_CODE': 47922,
#   'GMDN_TERM_NAME': 'Multiple-genus respiratory virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135731,
#   'GMDN_CODE': 50409,
#   'GMDN_TERM_NAME': 'Multiple-type sexually transmitted pathogen nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class C',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 87983,
#   'GMDN_CODE': 50409,
#   'GMDN_TERM_NAME': 'Multiple-type sexually transmitted pathogen nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List B',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:51.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112976,
#   'GMDN_CODE': 50409,
#   'GMDN_TERM_NAME': 'Multiple-type sexually transmitted pathogen nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135749,
#   'GMDN_CODE': 46023,
#   'GMDN_TERM_NAME': 'Non-evacuated urine specimen container IVD, no additive',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112967,
#   'GMDN_CODE': 46023,
#   'GMDN_TERM_NAME': 'Non-evacuated urine specimen container IVD, no additive',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135740,
#   'GMDN_CODE': 60091,
#   'GMDN_TERM_NAME': 'Nucleic acid amplification mastermix kit IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135742,
#   'GMDN_CODE': 52521,
#   'GMDN_TERM_NAME': 'Nucleic acid extraction/isolation kit IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112966,
#   'GMDN_CODE': 30623,
#   'GMDN_TERM_NAME': 'Nucleic acid hybridization detection IVD, kit',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135719,
#   'GMDN_CODE': 60736,
#   'GMDN_TERM_NAME': 'Nucleic acid sample preparation instrument IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112986,
#   'GMDN_CODE': 60737,
#   'GMDN_TERM_NAME': 'Nucleic acid sample preparation instrument IVD, semi-automated',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112981,
#   'GMDN_CODE': 58048,
#   'GMDN_TERM_NAME': 'Optical laboratory instrument performance standard calibrator/control IVD, single-use',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 66317,
#   'GMDN_CODE': 61484,
#   'GMDN_TERM_NAME': 'Partially-implantable abdominal port/catheter',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112997,
#   'GMDN_CODE': 61304,
#   'GMDN_TERM_NAME': 'PCR/NAT negative control IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 75120,
#   'GMDN_CODE': 61304,
#   'GMDN_TERM_NAME': 'PCR/NAT negative control IVD',
#   'DEVICE_SUB_TYPE_DESC': 'IVD Annex II List A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:59:12.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 148466,
#   'GMDN_CODE': 63337,
#   'GMDN_TERM_NAME': 'Pipette tip IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112994,
#   'GMDN_CODE': 64748,
#   'GMDN_TERM_NAME': 'SARS-CoV-2 nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112993,
#   'GMDN_CODE': 64747,
#   'GMDN_TERM_NAME': 'SARS-CoV-2 nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67575,
#   'GMDN_CODE': 58884,
#   'GMDN_TERM_NAME': 'Self-care monitoring/reporting software',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-06-30T03:31:56.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 113000,
#   'GMDN_CODE': 58884,
#   'GMDN_TERM_NAME': 'Self-care monitoring/reporting software',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIa',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 29703,
#   'DEVICE_ID': 67573,
#   'GMDN_CODE': 58884,
#   'GMDN_TERM_NAME': 'Self-care monitoring/reporting software',
#   'DEVICE_SUB_TYPE_DESC': 'Class IIb',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135738,
#   'GMDN_CODE': 62866,
#   'GMDN_TERM_NAME': 'Slide-mounted-tissue dissection system IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112996,
#   'GMDN_CODE': 62866,
#   'GMDN_TERM_NAME': 'Slide-mounted-tissue dissection system IVD',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135739,
#   'GMDN_CODE': 57871,
#   'GMDN_TERM_NAME': 'Specimen processing instrument IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112980,
#   'GMDN_CODE': 57871,
#   'GMDN_TERM_NAME': 'Specimen processing instrument IVD',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135748,
#   'GMDN_CODE': 66068,
#   'GMDN_TERM_NAME': 'Test tube/reservoir cap IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 122242,
#   'GMDN_CODE': 48031,
#   'GMDN_TERM_NAME': 'Thermal cycler nucleic acid amplification analyser IVD, laboratory',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 122243,
#   'GMDN_CODE': 48031,
#   'GMDN_TERM_NAME': 'Thermal cycler nucleic acid amplification analyser IVD, laboratory',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:04:39.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 135718,
#   'GMDN_CODE': 58177,
#   'GMDN_TERM_NAME': 'Urine specimen collection kit IVD',
#   'DEVICE_SUB_TYPE_DESC': 'Class A',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 112982,
#   'GMDN_CODE': 58177,
#   'GMDN_TERM_NAME': 'Urine specimen collection kit IVD',
#   'DEVICE_SUB_TYPE_DESC': 'IVD General',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 182881,
#   'GMDN_CODE': 49047,
#   'GMDN_TERM_NAME': 'West Nile virus nucleic acid IVD, control',
#   'DEVICE_SUB_TYPE_DESC': 'Class D',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 33548,
#   'DEVICE_ID': 182880,
#   'GMDN_CODE': 49045,
#   'GMDN_TERM_NAME': 'West Nile virus nucleic acid IVD, kit, nucleic acid technique (NAT)',
#   'DEVICE_SUB_TYPE_DESC': 'Class D',
#   'IS_CUSTOM_MADE': '',
#   'IS_PERFORMANCE_STUDIES': 'No',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device',
#   'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'},
#  {'MAN_ORGANISATION_ID': 41006,
#   'DEVICE_ID': 114391,
#   'GMDN_CODE': 41009,
#   'GMDN_TERM_NAME': 'X-ray film processing chemical, automatic',
#   'DEVICE_SUB_TYPE_DESC': 'Class I',
#   'IS_CUSTOM_MADE': 'No',
#   'IS_PERFORMANCE_STUDIES': '',
#   'DEVICE_REG_STATUS_CODE': 'DREGIY',
#   'DEVICE_TYPE_NAME': 'General Medical Device',
#   'LAST_UPDATED_DATE': '2023-05-17T09:03:52.000Z'}]

# %%
import json
import concurrent.futures
from requests.adapters import HTTPAdapter, Retry
from tqdm import tqdm
import os
MAX_RETRIES = 5
RETRY_INTERVAL = 1
current_directory = os.getcwd()
output_directory = os.path.join(current_directory, "Fetched Data")

if not os.path.exists(output_directory):
    os.mkdir(output_directory)

def create_retry_session():
    retry_strategy = Retry(
        total=MAX_RETRIES,
        backoff_factor=RETRY_INTERVAL,
        status_forcelist=[500, 502, 503, 504],  # Retry on these HTTP status codes
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session = requests.Session()
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

def fetch_data_with_retry(session, url):
    retries = 0
    while retries < MAX_RETRIES:
        try:
            response = session.get(url)
            response.raise_for_status()
            return response.text
        except requests.exceptions.RequestException as e:
            print(f"Error fetching data from {url}: {e}. Retrying in {RETRY_INTERVAL} seconds...")
            retries += 1
            time.sleep(RETRY_INTERVAL)

    print(f"Max retries reached. Unable to fetch data from {url}.")
    return None

# %%
collector = {}
def main():
    with concurrent.futures.ThreadPoolExecutor(max_workers = 8) as executor:
        futures = [executor.submit(create_search, player) for player in keywords]

        for future in tqdm(concurrent.futures.as_completed(futures), total=(len(keywords)), 
                           desc = "Searching Medical Devies"):
            player, response = future.result()
            if response.status_code == 200:
                # Parse the JSON content from the response
                data = response.json()
                collector[player] = data

# %%
main()
# Out:
# Searching Medical Devies: 100%|██████████████████████████████████████████████████████| 345/345 [03:16<00:00,  1.75it/s]

# %%
pd.DataFrame(collector['abbott'])
# Out:
#      MAN_ORGANISATION_ID  DEVICE_ID  GMDN_CODE  \
# 0                  30393     175670      59051
# 1                  52980     134458      45793
# 2                  52980     134467      55993
# 3                  31082      81502      57996
# 4                  31978     114709      60079
# ..                   ...        ...        ...
# 701                30393     100206      60779
# 702                30950      91177      59058
# 703                30950      91172      55858
# 704                31978     114717      60058
# 705                38300      88974      52500
#
#                                         GMDN_TERM_NAME DEVICE_SUB_TYPE_DESC  \
# 0            Acetaminophen IVD, kit, spectrophotometry              Class C
# 1           Activated clotting time (ACT) IVD, control          IVD General
# 2     Activated clotting time (ACT) IVD, kit, clotting          IVD General
# 3             Active implantable device control magnet
# 4    Acute myeloid leukaemia (AML) genetic mutation...          IVD General
# ..                                                 ...                  ...
# 701  Vitamin B12 IVD, kit, chemiluminescent immunoa...          IVD General
# 702  Wash/cleaning solution IVD, automated/semi-aut...          IVD General
# 703        White blood cell count IVD, kit, cell count          IVD General
# 704                 William-Beuren syndrome IVD, probe          IVD General
# 705  Wuchereria bancrofti antigen IVD, kit, rapid I...          IVD General
#
#     IS_CUSTOM_MADE IS_PERFORMANCE_STUDIES DEVICE_REG_STATUS_CODE  \
# 0                                      No                 DREGIY
# 1                                      No                 DREGIY
# 2                                      No                 DREGIY
# 3               No                                        DREGIY
# 4                                      No                 DREGIY
# ..             ...                    ...                    ...
# 701                                    No                 DREGIY
# 702                                    No                 DREGIY
# 703                                    No                 DREGIY
# 704                                    No                 DREGIY
# 705                                    No                 DREGIY
#
#                DEVICE_TYPE_NAME         LAST_UPDATED_DATE
# 0    In Vitro Diagnostic Device  2023-12-17T02:31:27.000Z
# 1    In Vitro Diagnostic Device  2023-05-17T09:06:10.000Z
# 2    In Vitro Diagnostic Device  2023-05-17T09:06:10.000Z
# 3     Active Implantable Device  2023-05-17T08:59:12.000Z
# 4    In Vitro Diagnostic Device  2023-05-17T09:03:52.000Z
# ..                          ...                       ...
# 701  In Vitro Diagnostic Device  2023-05-17T09:01:49.000Z
# 702  In Vitro Diagnostic Device  2023-05-17T09:01:05.000Z
# 703  In Vitro Diagnostic Device  2023-05-17T09:01:05.000Z
# 704  In Vitro Diagnostic Device  2023-05-17T09:03:52.000Z
# 705  In Vitro Diagnostic Device  2024-01-10T02:31:31.000Z
#
# [706 rows x 10 columns]

# %%
collector.keys()
# Out:
# dict_keys(['abi', 'palex medical sa', 'general biologicals', 'beijing wantai biological', 'human', 'bgi', 'sino medisite', 'orient gene biotech', 'hough pharma', 'rendu biotechnology', 'mgi tech', 'dako', 'bioneer', 'mispa instruments', 'rightsign covid', 'v', 'amoydx', 'grifols', 'fosun', 'olympus', 'green cross medical science corp', 'horiba', 'yaneng bio', 'sinocare', 'da an', 'denka seiken', 'eco diagnóstica', 'mindray', 'cytognos, s.l.', 'zytovision', 'labtest', 'apexbio', 'kogene biotech', 'hybribio', 'dexcom', 'intec', 'relia', 'wama', 'assure tech. (hangzhou) co., ltd.', 'seegene', 'sekisui', 'nipro', 'randox', 'morphle labs', 'dymind', 'hamamatsu', 'nissui', 'diagnostic biosystems', 'biocartis', 'viet a', 'vivachek biotech (hangzhou) co.,ltd', 'medite', 'bioclin', 'agilent', 'danaher', 'vyttra', 'leica', 'wuhan easy diagnostics', 'natera', 'lsi medience', 'euroimmun', 'becton dickinson', 'yhlo', 'juschek rapid antigen self test', 'solgent', 'hamilton', 'muto', 'panagen', 'visionatics inc', 'biolink', 'biosys', 'nam khoa', 'hipro biotechnology', 'promega', 'bioer', 'biotest biotech', 'biomérieux', 'boule diagnostics', 'pars azmun', 'genova diagnostics', 'dr.chip biotech', 'ibp', 'abbott', 'kyokuto', 'perkinelmer', 'infopia', 'toyobo', 'qiagen', 'bioline', 'pathnsitu', 'bio', 'fujirebio', 'kfbio', 'zhongshan', 'bioaxis', 'biosys kovalent', 'hitachi', 'otsuka', 'boditech', 'zeiss', 'accb biotech', 'meril life', 'a.menarini', 'sysmex', 'edan', 'drg diagnostics', 'cellavision', 'tanbead', 'taidoc', 'rad', 'tulip', 'roche', 'beckman coulter', 'philips', 'acon biotech', 'surescreen', 'nichirei', 'yorco', 'merck', 'kanto', 'horiba abx', 'ab analytica', 'sansure', 'premier medical', 'biosewoom', 'healgen', 'trinity', 'toshiba', 'diagon', 'twist bioscience', 'immucor', 'shino', '77 elektronika', 'optrascan', 'sensa core', 'werfen', 'aus biostain', 'gc pharma', 'innoscreen', 'thermo fisher scientific', 'biokit', 'wantai', 'truenat', 'hangzhou testsea biotechnology co ltd (china)', '3d histech', 'diagenode', 'takara bio inc', 'access bio', 'd.s. pharma', 'fujifilm', 'idylla', 'others', 'zeesan', 'inbios', 'zybio', 'lifescan', 'chiwell', 'nuclear laser medicine', 'kehua', 'quibasa', 'lyher', 'genrui biotech', 'oxoid', 'ustar', 'fastrack diagnostics', 'biochem (lang mai)', 'diatron', 'master diagnostica', 'bhat biotech', 'homebrew', 'turk lab', 'kingcar', 'aldrich', 'j mitra', 'medgenome', 'biocare', 'mitsubishi', 'sanwa', 'mizuho', 'alltest biotech', 'histoline', 'check', 'tecan', 'weswox', 'urit', 'pathisto', 'erma inc.', 'oxford nanopore', 'genomica', 'liferiver', 'beijing genesee biotech', 'acon diagnostics', 'siemens', 'one', 'rapid', 'nova', 'pentra', 'diasorin', 'technogenetics', 'pusheng', 'duksan', 'leadman', 'kyowa', 'autobio', 'aus diagnostics', 'tosoh', 'maixin', 'greiner bio', 'wako', 'capitalbio', 'biohit healthcare (hefei) co ltd (china)', 'jeol', 'osang', 'biosystems', 'jiangsu well biotech', 'ziobio', 'handok', 'immuno concepts', 'transasia', 'render biotech', 'pacific biosciences', 'genmark', 'arkray', 'xinchuang', 'eurospital', 'acon labs', 'sd biosensor', 'thermo fisher', 'genedx', 'altona diagnostics', 'vwr', 'integrated dna technologies', 'sacace', 'bioptik technology', 'illumina', 'pocd', 'privates institut für immunologie und molekulargenetik gmbh', 'aesku', 'diagast', 'test', 'bacme biotech', 'radiometer', 'tauns', 'hangzhou clongene', 'molbio', 'fokus diagnostic', 'abaxis', 'trek diagnostic', 'avantor', 'quidel', 'eiken chemical', 'wiener', 'mbl', 'yourgene', 'succeeder', 'cell marque', 'sens', 'intron', 'abcam', 'ortho clinical diagnostics', 'diatech pharmacogenetics', 'invitae', 'sakura', 'terumo', 'cepheid', 'uritest', 'canon', 'sichuan maccura', 'asan', 'sigma', 'diagnostic automation / cortez diagnostics (dacd)', 'omron', 'dakewe', 'abdulla fouad group', 'kainos', 'orgentec', 'elitech', 'celnovte', 'berry genomics', 'primera', 'himedia', 'clinitest', 'beijing strong biotechnologies, inc', 'bioperfectu ...

# %%
import pandas as pd
extract = pd.DataFrame()
for player in collector.keys():
    if len(player) > 3:
        data = pd.DataFrame(collector[player])
        data['manufacturer'] = player.capitalize()
        extract = pd.concat([extract, data])

# %%
extract.shape
# Out:
# (22676, 11)

# %%
extract = extract.drop_duplicates()
extract.shape
# Out:
# (22676, 11)

# %%
extract.manufacturer.unique()
# Out:
# array(['Beijing wantai biological', 'Human', 'Orient gene biotech',
#        'Mgi tech', 'Bioneer', 'Grifols', 'Olympus', 'Horiba', 'Sinocare',
#        'Mindray', 'Dexcom', 'Intec', 'Relia',
#        'Assure tech. (hangzhou) co., ltd.', 'Seegene', 'Sekisui', 'Nipro',
#        'Randox', 'Dymind', 'Hamamatsu', 'Biocartis', 'Medite', 'Bioclin',
#        'Agilent', 'Leica', 'Natera', 'Lsi medience', 'Euroimmun',
#        'Becton dickinson', 'Yhlo', 'Solgent', 'Hamilton', 'Biosys',
#        'Promega', 'Bioer', 'Biotest biotech', 'Biomérieux', 'Abbott',
#        'Qiagen', 'Bioline', 'Fujirebio', 'Zhongshan', 'Hitachi', 'Otsuka',
#        'Boditech', 'Zeiss', 'Meril life', 'Sysmex', 'Edan', 'Cellavision',
#        'Taidoc', 'Tulip', 'Roche', 'Beckman coulter', 'Philips',
#        'Acon biotech', 'Surescreen', 'Merck', 'Horiba abx', 'Sansure',
#        'Healgen', 'Trinity', 'Diagon', 'Immucor', '77 elektronika',
#        'Thermo fisher scientific', 'Biokit', 'Wantai', 'Diagenode',
#        'Fujifilm', 'Others', 'Zybio', 'Lifescan', 'Oxoid', 'Diatron',
#        'Aldrich', 'Biocare', 'Sanwa', 'Mizuho', 'Alltest biotech',
#        'Check', 'Tecan', 'Urit', 'Siemens', 'Rapid', 'Nova', 'Diasorin',
#        'Technogenetics', 'Autobio', 'Tosoh', 'Greiner bio', 'Wako',
#        'Capitalbio', 'Osang', 'Biosystems', 'Genmark', 'Arkray',
#        'Eurospital', 'Sd biosensor', 'Thermo fisher',
#        'Altona diagnostics', 'Illumina', 'Aesku', 'Diagast', 'Test',
#        'Radiometer', 'Molbio', 'Abaxis', 'Trek diagnostic', 'Avantor',
#        'Quidel', 'Eiken chemical', 'Wiener', 'Yourgene', 'Cell marque',
#        'Sens', 'Intron', 'Diatech pharmacogenetics', 'Sakura', 'Terumo',
#        'Cepheid', 'Canon', 'Asan', 'Sigma', 'Omron', 'Dakewe', 'Orgentec',
#        'Elitech', 'Himedia', 'Bioperfectus', 'Sebia', 'Hologic', 'Erba',
#        'Lifotronic', 'Bionime', 'Nihon kohden', 'Motic', 'Epredia',
#        'Fukuda denshi', 'Sophia genetics', 'Bosch healthcare', 'Slee',
#        'Wondfo', 'Inova diagnostics', 'Santé', 'Dedalus ',
#        'Analyticon biotechnologies', 'Diamed',
#        'Instrumentation laboratory', 'Medica', 'Medical system',
#        'Micropoint', 'Diapath', 'Getein biotech', 'Orient gene', 'Optica',
#        'Hain lifescience', 'Biotech', 'Haemonetics', 'Tokyo boeki',
#        'Stago'], dtype=object)

# %%
extract.to_excel("GB Medical Device Register.xlsx")
