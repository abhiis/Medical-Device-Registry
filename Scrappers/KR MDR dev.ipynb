# %%
import requests

cookies = {
    'elevisor_for_j2ee_uid': '30ybak7qnfb54',
    'JSESSIONID': '8yAlo_BNCOGHAR5qJ0BpJyamqrm3YGYgnLeyAk3F.lic21',
    '_ga_XWJQF77Q4Q': 'GS1.1.1706098974.1.0.1706098974.0.0.0',
    '_ga': 'GA1.3.1871809028.1706098975',
    '_gid': 'GA1.3.1407177981.1706098975',
}

headers = {
    'Accept': 'text/html, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.9',
    'Connection': 'keep-alive',
    # 'Cookie': 'elevisor_for_j2ee_uid=30ybak7qnfb54; JSESSIONID=8yAlo_BNCOGHAR5qJ0BpJyamqrm3YGYgnLeyAk3F.lic21; _ga_XWJQF77Q4Q=GS1.1.1706098974.1.0.1706098974.0.0.0; _ga=GA1.3.1871809028.1706098975; _gid=GA1.3.1407177981.1706098975',
    'Referer': 'https://emedi.mfds.go.kr/search/data/MNU20237',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
}

params = {
    'mnftrNtnCdNm': '',
    'indtyCdNm': 'import industry',
    'tcsbizRsmptSeCdNm': '',
    'udidiCode': '',
    'rcprslryCdInptvl': '',
    'entpName': '',
    'indtyCd': '2',
    'itemName': '',
    'mdClsfNo': '',
    'typeName': '',
    'itemNoFullname': '',
    'brandName': '',
    'grade': '0',
    'query': '',
    'mnftrNtnCd': '',
    'mdentpPrmno': '',
    'tcsbizRsmptSeCd': '',
    'mnfacrNm': '',
    'cancelYn': '',
    'rcprslryTrgtYn': '',
    'traceManageTargetYn': '',
    'xprtppYn': '',
    'prdlPrmDtFrom': '',
    'prdlPrmDtTo': '',
    'pageNum': '2',
    'searchYn': 'true',
    'searchAfKey': '',
    'sort': '',
    'sortOrder': '',
    'searchOn': 'Y',
    'ean13': '',
}

response = requests.get('https://emedi.mfds.go.kr/search/data/list', params=params, cookies=cookies, headers=headers)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text)
table = soup.find('table')
import pandas as pd

pd.read_html(str(table))[0]
# Out:
#           업체명   업종            품목명     품목분류번호         모델명   제품명     품목허가번호  등급  \
# 0        한메드존  수입업   재사용가능 혈관 클램프  A44010.07  S41-252-65   NaN  수신24-114호   1
# 1  (주)피비에스코리아  수입업      재사용가능 천자침  A53040.01    MN0803RS  Omni  수신24-119호   1
# 2  (주)피비에스코리아  수입업      재사용가능 천자침  A53040.01    MN1203RL  Omni  수신24-119호   1
# 3  (주)피비에스코리아  수입업      재사용가능 천자침  A53040.01    MN1003RL  Omni  수신24-119호   1
# 4  (주)피비에스코리아  수입업      재사용가능 천자침  A53040.01    MN0803RL  Omni  수신24-119호   1
# 5  (주)피비에스코리아  수입업      재사용가능 천자침  A53040.01    MN1401RL  Omni  수신24-119호   1
# 6  (주)피비에스코리아  수입업      재사용가능 천자침  A53040.01    MN0805RS  Omni  수신24-119호   1
# 7   (주)에이치원케어  수입업  재사용가능 내시경 캐뉼러  A31010.22   WTS409300   NaN  수신24-120호   1
# 8   (주)에이치원케어  수입업  재사용가능 내시경 캐뉼러  A31010.22   WTS409304   NaN  수신24-120호   1
# 9   (주)에이치원케어  수입업  재사용가능 내시경 캐뉼러  A31010.22   WTS709300   NaN  수신24-120호   1
#
#    제조국가  치료재료코드  ...                          품목영문명  상태 업상태  \
# ...
