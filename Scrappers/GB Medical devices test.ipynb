# %%
## So we can send an search request using manufacturer names
## Let's use gateway players

# %%
import requests

cookies = {
    'ai_user': 'qDSrt7CzZfzSCEycvMP+zT|2024-01-29T20:03:58.212Z',
    'ai_session': '/HXDRDIhT9HiqX48fFXqUQ|1706558638935|1706558703583',
}

headers = {
    'authority': 'pard.mhra.gov.uk',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/json',
    # 'cookie': 'ai_user=qDSrt7CzZfzSCEycvMP+zT|2024-01-29T20:03:58.212Z; ai_session=/HXDRDIhT9HiqX48fFXqUQ|1706558638935|1706558703583',
    'origin': 'https://pard.mhra.gov.uk',
    'request-id': '|6cc42aa779a34365ba3f2d7470b2b32e.8efbfdbe8c9c45d1',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'traceparent': '00-6cc42aa779a34365ba3f2d7470b2b32e-8efbfdbe8c9c45d1-01',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

json_data = {
    'searchTerm': {
        'manufacturerName': 'abbott',
        'referenceNumber': '',
        'deviceName': '',
        'deviceType': '',
        'gmdnCode': '',
    },
}

response = requests.post('https://pard.mhra.gov.uk/searchDevicesAdvanced', cookies=cookies, headers=headers, json=json_data)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"searchTerm":{"manufacturerName":"abbott","referenceNumber":"","deviceName":"","deviceType":"","gmdnCode":""}}'
#response = requests.post('https://pard.mhra.gov.uk/searchDevicesAdvanced', cookies=cookies, headers=headers, data=data)

# %%
import json

# Check if the response is successful (optional)
if response.status_code == 200:
    # Parse the JSON content from the response
    data = response.json()

    # Now 'data' is a Python dictionary containing the parsed JSON data
    # You can access and manipulate the data as needed
    print(data)
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# [{'MAN_ORGANISATION_ID': 29703, 'DEVICE_ID': 66324, 'GMDN_CODE': 63262, 'GMDN_TERM_NAME': 'Ambulatory insulin infusion administration set', 'DEVICE_SUB_TYPE_DESC': 'Class IIb', 'IS_CUSTOM_MADE': 'No', 'IS_PERFORMANCE_STUDIES': '', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'General Medical Device', 'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'}, {'MAN_ORGANISATION_ID': 29703, 'DEVICE_ID': 66323, 'GMDN_CODE': 63810, 'GMDN_TERM_NAME': 'Ambulatory insulin infusion administration set/reservoir kit', 'DEVICE_SUB_TYPE_DESC': 'Class IIb', 'IS_CUSTOM_MADE': 'No', 'IS_PERFORMANCE_STUDIES': '', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'General Medical Device', 'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'}, {'MAN_ORGANISATION_ID': 29703, 'DEVICE_ID': 66327, 'GMDN_CODE': 63261, 'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump remote control/blood glucose analyser', 'DEVICE_SUB_TYPE_DESC': 'Class IIb', 'IS_CUSTOM_MADE': 'No', 'IS_PERFORMANCE_STUDIES': '', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'General Medical Device', 'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'}, {'MAN_ORGANISATION_ID': 29703, 'DEVICE_ID': 66322, 'GMDN_CODE': 35838, 'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump reservoir', 'DEVICE_SUB_TYPE_DESC': 'Class IIa', 'IS_CUSTOM_MADE': 'No', 'IS_PERFORMANCE_STUDIES': '', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'General Medical Device', 'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'}, {'MAN_ORGANISATION_ID': 29703, 'DEVICE_ID': 67568, 'GMDN_CODE': 64889, 'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump, electronic, non-software-dosing', 'DEVICE_SUB_TYPE_DESC': 'Class IIb', 'IS_CUSTOM_MADE': 'No', 'IS_PERFORMANCE_STUDIES': '', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'General Medical Device', 'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'}, {'MAN_ORGANISATION_ID': 29703, 'DEVICE_ID': 67569, 'GMDN_CODE': 51083, 'GMDN_TERM_NAME': 'Ambulatory insulin infusion pump/blood glucose analyser system', 'DEVICE_SUB_TYPE_DESC': 'Class IIb', 'IS_CUSTOM_MADE': 'No', 'IS_PERFORMANCE_STUDIES': '', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'General Medical Device', 'LAST_UPDATED_DATE': '2023-05-17T08:58:30.000Z'}, {'MAN_ORGANISATION_ID': 33548, 'DEVICE_ID': 135746, 'GMDN_CODE': 61305, 'GMDN_TERM_NAME': 'Assay adhesive sealing/fixation film IVD', 'DEVICE_SUB_TYPE_DESC': 'Class A', 'IS_CUSTOM_MADE': '', 'IS_PERFORMANCE_STUDIES': 'No', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device', 'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'}, {'MAN_ORGANISATION_ID': 33548, 'DEVICE_ID': 135747, 'GMDN_CODE': 62225, 'GMDN_TERM_NAME': 'Assay container IVD, single-use', 'DEVICE_SUB_TYPE_DESC': 'Class A', 'IS_CUSTOM_MADE': '', 'IS_PERFORMANCE_STUDIES': 'No', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device', 'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'}, {'MAN_ORGANISATION_ID': 33548, 'DEVICE_ID': 112983, 'GMDN_CODE': 58586, 'GMDN_TERM_NAME': 'Basic/simple nutrient broth culture medium IVD', 'DEVICE_SUB_TYPE_DESC': 'IVD General', 'IS_CUSTOM_MADE': '', 'IS_PERFORMANCE_STUDIES': 'No', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device', 'LAST_UPDATED_DATE': '2023-05-17T09:02:43.000Z'}, {'MAN_ORGANISATION_ID': 33548, 'DEVICE_ID': 135728, 'GMDN_CODE': 51716, 'GMDN_TERM_NAME': 'Beta-haemolytic Group A Streptococcus nucleic acid IVD, control', 'DEVICE_SUB_TYPE_DESC': 'Class B', 'IS_CUSTOM_MADE': '', 'IS_PERFORMANCE_STUDIES': 'No', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE_NAME': 'In Vitro Diagnostic Device', 'LAST_UPDATED_DATE': '2023-12-17T02:31:27.000Z'}, {'MAN_ORGANISATION_ID': 33548, 'DEVICE_ID': 112979, 'GMDN_CODE': 51716, 'GMDN_TERM_NAME': 'Beta-haemolytic Group A Streptococcus nucleic acid IVD, control', 'DEVICE_SUB_TYPE_DESC': 'IVD General', 'IS_CUSTOM_MADE': '', 'IS_PERFORMANCE_STUDIES': 'No', 'DEVICE_REG_STATUS_CODE': 'DREGIY', 'DEVICE_TYPE ...

# %%
len(data)
# Out:
# 127

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#      MAN_ORGANISATION_ID  DEVICE_ID  GMDN_CODE  \
# 0                  29703      66324      63262
# 1                  29703      66323      63810
# 2                  29703      66327      63261
# 3                  29703      66322      35838
# 4                  29703      67568      64889
# ..                   ...        ...        ...
# 122                33548     135718      58177
# 123                33548     112982      58177
# 124                33548     182881      49047
# 125                33548     182880      49045
# 126                41006     114391      41009
#
#                                         GMDN_TERM_NAME DEVICE_SUB_TYPE_DESC  \
# 0       Ambulatory insulin infusion administration set            Class IIb
# 1    Ambulatory insulin infusion administration set...            Class IIb
# 2    Ambulatory insulin infusion pump remote contro...            Class IIb
# 3           Ambulatory insulin infusion pump reservoir            Class IIa
# 4    Ambulatory insulin infusion pump, electronic, ...            Class IIb
# ..                                                 ...                  ...
# 122                  Urine specimen collection kit IVD              Class A
# 123                  Urine specimen collection kit IVD          IVD General
# 124          West Nile virus nucleic acid IVD, control              Class D
# 125  West Nile virus nucleic acid IVD, kit, nucleic...              Class D
# 126          X-ray film processing chemical, automatic              Class I
#
#     IS_CUSTOM_MADE IS_PERFORMANCE_STUDIES DEVICE_REG_STATUS_CODE  \
# 0               No                                        DREGIY
# 1               No                                        DREGIY
# 2               No                                        DREGIY
# 3               No                                        DREGIY
# 4               No                                        DREGIY
# ..             ...                    ...                    ...
# 122                                    No                 DREGIY
# 123                                    No                 DREGIY
# 124                                    No                 DREGIY
# 125                                    No                 DREGIY
# 126             No                                        DREGIY
#
#                DEVICE_TYPE_NAME         LAST_UPDATED_DATE
# 0        General Medical Device  2023-05-17T08:58:30.000Z
# 1        General Medical Device  2023-05-17T08:58:30.000Z
# 2        General Medical Device  2023-05-17T08:58:30.000Z
# 3        General Medical Device  2023-05-17T08:58:30.000Z
# 4        General Medical Device  2023-05-17T08:58:30.000Z
# ..                          ...                       ...
# 122  In Vitro Diagnostic Device  2023-12-17T02:31:27.000Z
# 123  In Vitro Diagnostic Device  2023-05-17T09:02:43.000Z
# 124  In Vitro Diagnostic Device  2023-12-17T02:31:27.000Z
# 125  In Vitro Diagnostic Device  2023-12-17T02:31:27.000Z
# 126      General Medical Device  2023-05-17T09:03:52.000Z
#
# [127 rows x 10 columns]
