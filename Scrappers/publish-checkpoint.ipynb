# %%
import pandas as pd
import numpy as np
import os,time, glob as g
import warnings as ws
import time
ws.filterwarnings("ignore")

# %%
#Moved files manually, renamed manually
#Consolidation
data = os.getcwd()+"\Stage"
files = g.glob(os.path.join(data,'*.xlsx'))
files
# Out:
# ['C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\anmat_ar.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\arcsa_ec.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\artg_au.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\cdsco_in.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\dmec_vn.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\eudamed.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\fda_th.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\mda_my.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\mfds_kr.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\mhra_gb.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\minsa_pn.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\mohap_ae.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\moh_ID.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\phfda.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\smdr_sg.xlsx',
#  'C:\\Users\\AbhishekSrivastava\\Desktop\\Workflow\\Python\\Dev\\Medical Devices Registry\\MDR Scripts\\Consolidation\\Stage\\usfda.xlsx']

# %%
len(files)
# Out:
# 16

# %%
holder = dict()
for file in files:
    hold = pd.read_excel(file)
    del hold['Unnamed: 0']
    country = file.split("\\")[-1].split(".")[0]
    print(country)
    print(f"Columns: {len(hold.columns)} {hold.columns}")
    holder[country] = hold
    print(hold.shape)
# Out:
# anmat_ar
# Columns: 9 Index(['index', 'end_date', 'company_', 'description', 'device', 'meta',
#        'manufacturer', 'manufacturer_country', 'start_date'],
#       dtype='object')
# (30419, 9)
# arcsa_ec
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (44560, 10)
# artg_au
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (69876, 10)
# cdsco_in
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (49383, 10)
# dmec_vn
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (115903, 10)
# eudamed
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (61063, 10)
# fda_th
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (67381, 10)
# mda_my
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (17756, 10)
# mfds_kr
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (40871, 10)
# mhra_gb
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (22676, 10)
# minsa_pn
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (7544, 10)
# mohap_ae
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (14942, 10)
# moh_ID
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (62736, 10)
# phfda
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (18862, 10)
# smdr_sg
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (981270, 10)
# usfda
# Columns: 10 Index(['index', 'device', 'company_', 'description', 'meta', 'manufacturer',
#        'manufacturer_country', 'start_date', 'end_date', 'status'],
#       dtype='object')
# (163950, 10)

# %%
countries = list(holder.keys())
counts = [len(holder[x]) for x in countries]
counts
# Out:
# [30419,
#  44560,
#  69876,
#  49383,
#  115903,
#  61063,
#  67381,
#  17756,
#  40871,
#  22676,
#  7544,
#  14942,
#  62736,
#  18862,
#  981270,
#  163950]

# %%
sum(counts)
# Out:
# 1769192

# %%
countries
# Out:
# ['anmat_ar',
#  'arcsa_ec',
#  'artg_au',
#  'cdsco_in',
#  'dmec_vn',
#  'eudamed',
#  'fda_th',
#  'mda_my',
#  'mfds_kr',
#  'mhra_gb',
#  'minsa_pn',
#  'mohap_ae',
#  'moh_ID',
#  'phfda',
#  'smdr_sg',
#  'usfda']

# %%
#Analysis
from datetime import datetime as date
sources = list(holder.keys())
collect = pd.DataFrame()
#cols_to_keep =  ['Company','Device Name','Approval Area','Intended Purpose', 'Manufacturer Address', 'Manufacturer Country','index']
for source in sources:
    print(source)
    hold = holder.get(source)
    grill = hold.copy()
    grill['Source'] = source.upper()
    grill['Updated'] = date.today()
    holder[source] = grill
# Out:
# anmat_ar
# arcsa_ec
# artg_au
# cdsco_in
# dmec_vn
# eudamed
# fda_th
# mda_my
# mfds_kr
# mhra_gb
# minsa_pn
# mohap_ae
# moh_ID
# phfda
# smdr_sg
# usfda

# %%
for source in sources:
    print(source)
    hold = holder.get(source)
    grill = hold.copy()
    
    #grill.to_excel(f"Stage\\Export\\{source}.xlsx")
# Out:
# anmat_ar
# arcsa_ec
# artg_au
# cdsco_in
# dmec_vn
# eudamed
# fda_th
# mda_my
# mfds_kr
# mhra_gb
# minsa_pn
# mohap_ae
# moh_ID
# phfda
# smdr_sg
# usfda

# %%
collector = []
for source in sources:
    print(source)
    hold = holder.get(source)
    grill = hold.copy()
    grill = grill.rename(columns = {"company_":"company"})
    grill = grill.replace("\n",",", regex=True)
    grill = grill.drop_duplicates()
    grill = grill.reset_index(drop=False)
    grill['level_0'] = grill['level_0'].astype(str)
    grill['index'] = grill['index'].fillna(grill['Source']+grill['level_0'])
    
    del grill['level_0']
    collector.append(grill)
# Out:
# anmat_ar
# arcsa_ec
# artg_au
# cdsco_in
# dmec_vn
# eudamed
# fda_th
# mda_my
# mfds_kr
# mhra_gb
# minsa_pn
# mohap_ae
# moh_ID
# phfda
# smdr_sg
# usfda

# %%
## Look above

# %%
mdr = pd.concat(collector)
#mdr = mdr.rename(columns = {"company_":"company"})

# %%
mdr.columns
# Out:
# Index(['index', 'end_date', 'company', 'description', 'device', 'meta',
#        'manufacturer', 'manufacturer_country', 'start_date', 'Source',
#        'Updated', 'status'],
#       dtype='object')

# %%
mdr['end_dates'] = pd.to_datetime(mdr['end_date'], errors='coerce')
mdr['start_dates'] = pd.to_datetime(mdr['start_date'], errors='coerce')

# %%
from dateutil import parser
# For any NaT values, attempt parsing with dateutil.parser.parse
for i, row in mdr[mdr['end_dates'].isna()].iterrows():
    try:
        mdr.at[i, 'end_dates'] = parser.parse(row['end_dates'])
    except (ValueError, TypeError):
        # Handle the case where parsing still fails (e.g., invalid date formats)
        pass

# %%
from dateutil import parser
# For any NaT values, attempt parsing with dateutil.parser.parse
for i, row in mdr[mdr['start_dates'].isna()].iterrows():
    try:
        mdr.at[i, 'start_dates'] = parser.parse(row['start_dates'])
    except (ValueError, TypeError):
        # Handle the case where parsing still fails (e.g., invalid date formats)
        pass

# %%
mdr = mdr[['index','start_dates','end_dates','device',
           'description','company','meta','manufacturer','manufacturer_country',
           'Source','Updated', 'status']]

# %%
mdr.to_csv("MDR v2 - Jan24.csv")

# %%
mdr.shape
# Out:
# (1291340, 12)

# %%
mdr
# Out:
#                 index start_dates  end_dates  \
# 0          ANMAT-AR-0         NaT 2024-01-25
# 1          ANMAT-AR-1         NaT 2024-01-25
# 2          ANMAT-AR-2         NaT 2024-01-25
# 3          ANMAT-AR-3         NaT 2024-01-25
# 4          ANMAT-AR-4         NaT 2024-01-25
# ...               ...         ...        ...
# 163945  USFDA-K234109  2024-01-26        NaT
# 163946  USFDA-K234116  2024-01-26        NaT
# 163947  USFDA-K234118  2024-01-26        NaT
# 163948  USFDA-K234127  2024-01-25        NaT
# 163949  USFDA-K234145  2024-01-26        NaT
#
#                                                    device  \
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163945                                      Ziehm Solo FD
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
#                                               description  \
# 0       Transparent I.V. dressing reinforced with chlo...
# 1                                  Biological heart valve
# 2                               Neuro-thrombectomy system
# 3                            Coronary thrombectomy system
# 4                                     Mobile X-ray system
# ...                                                   ...
# 163945           Interventional Fluoroscopic X-Ray System
# 163946                                         Bone Wedge
# 163947     Blood Pump For Ecmo, Long-Term (> 6 Hours) Use
# 163948                   Lenses, Soft Contact, Daily Wear
# 163949          Tubes, Gastrointestinal (And Accessories)
#
#                                 company  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163945               Ziehm Imaging GmbH
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                                      meta  \
# 0       Oper film ®protect CHG 7 x 8,5 cm (Ref: 003400...
# 1       Aorticos:,DDL19A; DDL21A; DDL23A; DDL25A; DDL2...
# 2       VN-6044-F3NR (NeVa IC-3 Net),VN-6035-F2NR (NeV...
# 3       EV-4030-F2RR (enVast 4.0 x 30 mm),EV-4038-F3RR...
# 4                                        JADE-32, JADE-40
# ...                                                   ...
# 163945                               Specialty: Radiology
# 163946                              Specialty: Orthopedic
# 163947                          Specialty: Cardiovascular
# 163948                              Specialty: Ophthalmic
# 163949              Specialty: Gastroenterology & Urology
#
#                            manufacturer manufacturer_country    Source  \
# 0                                     -                    -  ANMAT_AR
# 1                                     -                    -  ANMAT_AR
# 2                                     -                    -  ANMAT_AR
# 3                                     -                    -  ANMAT_AR
# 4                                     -                    -  ANMAT_AR
# ...                                 ...                  ...       ...
# 163945               Ziehm Imaging GmbH                    -     USFDA
# 163946  Nvision Biomedical Technologies                    -     USFDA
# 163947                   Abbott Medical                    -     USFDA
# 163948               CooperVision, Inc.                    -     USFDA
# 163949          Boehringer Laboratories                    -     USFDA
#
#                           Updated status
# 0      2024-02-01 19:32:33.813323    NaN
# 1      2024-02-01 19:32:33.813323    NaN
# 2      2024-02-01 19:32:33.813323    NaN
# 3      2024-02-01 19:32:33.813323    NaN
# 4      2024-02-01 19:32:33.813323    NaN
# ...                           ...    ...
# 163945 2024-02-01 19:32:34.022715      -
# 163946 2024-02-01 19:32:34.022715      -
# 163947 2024-02-01 19:32:34.022715      -
# 163948 2024-02-01 19:32:34.022715      -
# 163949 2024-02-01 19:32:34.022715      -
#
# [1291340 rows x 12 columns]

# %%
mdr[mdr['company'].isna()]
# Out:
#               index start_dates end_dates device description company meta  \
# 45794  DMEC_VN49075         NaT       NaT    NaN           -     NaN  NaN
#
#       manufacturer manufacturer_country   Source                    Updated  \
# 45794          NaN                    -  DMEC_VN 2024-02-01 19:32:33.880358
#
#       status
# 45794    NaN

# %%
mdr['company'] = mdr['company'].fillna(mdr['device'])

# %%
mdr[mdr['device'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, start_dates, end_dates, device, description, company, meta, manufacturer, manufacturer_country, Source, Updated, status]
# Index: []

# %%
mdr['device'] = mdr['device'].fillna(mdr['description'])

# %%
mdr[mdr['meta'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, start_dates, end_dates, device, description, company, meta, manufacturer, manufacturer_country, Source, Updated, status]
# Index: []

# %%
#1 mdr['meta'] = mdr['meta'].fillna(mdr['description'])
#2 mdr['meta'] = mdr['meta'].fillna(mdr['device'])

# %%
mdr[mdr['description'].isna()]
# Out:
#                              index start_dates end_dates  \
# 15874   CDCO-IN-IMP/MD/2018/000273         NaT       NaT
# 20149   CDCO-IN-IMP/MD/2021/000060         NaT       NaT
# 34786   CDCO-IN-MFG/MD/2020/000047         NaT       NaT
# 4233            MHRA-GB-4233-81502         NaT       NaT
# 4335            MHRA-GB-4335-71927         NaT       NaT
# ...                            ...         ...       ...
# 162984               USFDA-K760089         NaT       NaT
# 163043               USFDA-K760016         NaT       NaT
# 163047               USFDA-K760052         NaT       NaT
# 163058               USFDA-K760121         NaT       NaT
# 163063               USFDA-K760101         NaT       NaT
#
#                                                    device description  \
# 15874   Suture Anchor) soft-tissue fixation devices(IC...         NaN
# 20149                     Panetti) Suction Instruments(NA         NaN
# 34786   Perfusion Sets for single use)I.V INFUSION SET...         NaN
# 4233             Active implantable device control magnet         NaN
# 4335    Central nervous system electrical stimulation ...         NaN
# ...                                                   ...         ...
# 162984                          TEST, IN-VITRO DIAGNOSTIC         NaN
# 163043                           SURGICAL BLADES (BEAVER)         NaN
# 163047                                    KIT, PREP SHAVE         NaN
# 163058                                IMPULSE HEAT SEALER         NaN
# 163063             OXYGEN & RESUSCITATION (HOPE II MODEL)         NaN
#
#                                    company  \
# 15874             Stryker India Pvt. Ltd.,
# 20149   Smith & Nephew Healthcare Pvt. Ltd
# 34786     Sysko Asia Healthcares Pvt. Ltd.
# 4233                                Abbott
# 4335                                Abbott
# ...                                    ...
# 162984             HOFFMANN-LA ROCHE, INC.
# 163043                     PARKE-DAVIS CO.
# 163047                      M-C IND., INC.
# 163058                        LORVIC CORP.
# 163063               OHIO MEDICAL PRODUCTS
#
#                                                      meta  \
# 15874   Class C;The Stryker ICONiX anchors are indicat...
# 20149   Class B;Reusable surgical Panetti and Acoustic...
# 34786   Class B;Perfusion sets is used to administer B...
# 4233                            Active Implantable Device
# 4335                            Active Implantable Device
# ...                                                   ...
# 162984                          TEST, IN-VITRO DIAGNOSTIC
# 163043                           SURGICAL BLADES (BEAVER)
# 163047                                    KIT, PREP SHAVE
# 163058                                IMPULSE HEAT SEALER
# 163063             OXYGEN & RESUSCITATION (HOPE II MODEL)
#
#                    manufacturer manufacturer_country    Source  \
# 15874                         -                    -  CDSCO_IN
# 20149                         -                    -  CDSCO_IN
# 34786                         -                    -  CDSCO_IN
# 4233                     Abbott                    -   MHRA_GB
# 4335                     Abbott                    -   MHRA_GB
# ...                         ...                  ...       ...
# 162984  HOFFMANN-LA ROCHE, INC.                    -     USFDA
# 163043          PARKE-DAVIS CO.                    -     USFDA
# 163047           M-C IND., INC.                    -     USFDA
# 163058             LORVIC CORP.                    -     USFDA
# 163063    OHIO MEDICAL PRODUCTS                    -     USFDA
#
#                           Updated status
# 15874  2024-02-01 19:32:33.865837      -
# 20149  2024-02-01 19:32:33.865837      -
# 34786  2024-02-01 19:32:33.865837      -
# 4233   2024-02-01 19:32:33.907577      -
# 4335   2024-02-01 19:32:33.907577      -
# ...                           ...    ...
# 162984 2024-02-01 19:32:34.022715      -
# 163043 2024-02-01 19:32:34.022715      -
# 163047 2024-02-01 19:32:34.022715      -
# 163058 2024-02-01 19:32:34.022715      -
# 163063 2024-02-01 19:32:34.022715      -
#
# [4109 rows x 12 columns]

# %%
mdr['description'] = mdr['description'].fillna(mdr['meta'])

# %%
mdr.shape
# Out:
# (1291340, 12)

# %%
mdr.drop_duplicates()
# Out:
#                 index start_dates  end_dates  \
# 0          ANMAT-AR-0         NaT 2024-01-25
# 1          ANMAT-AR-1         NaT 2024-01-25
# 2          ANMAT-AR-2         NaT 2024-01-25
# 3          ANMAT-AR-3         NaT 2024-01-25
# 4          ANMAT-AR-4         NaT 2024-01-25
# ...               ...         ...        ...
# 163945  USFDA-K234109  2024-01-26        NaT
# 163946  USFDA-K234116  2024-01-26        NaT
# 163947  USFDA-K234118  2024-01-26        NaT
# 163948  USFDA-K234127  2024-01-25        NaT
# 163949  USFDA-K234145  2024-01-26        NaT
#
#                                                    device  \
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163945                                      Ziehm Solo FD
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
#                                               description  \
# 0       Transparent I.V. dressing reinforced with chlo...
# 1                                  Biological heart valve
# 2                               Neuro-thrombectomy system
# 3                            Coronary thrombectomy system
# 4                                     Mobile X-ray system
# ...                                                   ...
# 163945           Interventional Fluoroscopic X-Ray System
# 163946                                         Bone Wedge
# 163947     Blood Pump For Ecmo, Long-Term (> 6 Hours) Use
# 163948                   Lenses, Soft Contact, Daily Wear
# 163949          Tubes, Gastrointestinal (And Accessories)
#
#                                 company  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163945               Ziehm Imaging GmbH
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                                      meta  \
# 0       Oper film ®protect CHG 7 x 8,5 cm (Ref: 003400...
# 1       Aorticos:,DDL19A; DDL21A; DDL23A; DDL25A; DDL2...
# 2       VN-6044-F3NR (NeVa IC-3 Net),VN-6035-F2NR (NeV...
# 3       EV-4030-F2RR (enVast 4.0 x 30 mm),EV-4038-F3RR...
# 4                                        JADE-32, JADE-40
# ...                                                   ...
# 163945                               Specialty: Radiology
# 163946                              Specialty: Orthopedic
# 163947                          Specialty: Cardiovascular
# 163948                              Specialty: Ophthalmic
# 163949              Specialty: Gastroenterology & Urology
#
#                            manufacturer manufacturer_country    Source  \
# 0                                     -                    -  ANMAT_AR
# 1                                     -                    -  ANMAT_AR
# 2                                     -                    -  ANMAT_AR
# 3                                     -                    -  ANMAT_AR
# 4                                     -                    -  ANMAT_AR
# ...                                 ...                  ...       ...
# 163945               Ziehm Imaging GmbH                    -     USFDA
# 163946  Nvision Biomedical Technologies                    -     USFDA
# 163947                   Abbott Medical                    -     USFDA
# 163948               CooperVision, Inc.                    -     USFDA
# 163949          Boehringer Laboratories                    -     USFDA
#
#                           Updated status
# 0      2024-02-01 19:32:33.813323    NaN
# 1      2024-02-01 19:32:33.813323    NaN
# 2      2024-02-01 19:32:33.813323    NaN
# 3      2024-02-01 19:32:33.813323    NaN
# 4      2024-02-01 19:32:33.813323    NaN
# ...                           ...    ...
# 163945 2024-02-01 19:32:34.022715      -
# 163946 2024-02-01 19:32:34.022715      -
# 163947 2024-02-01 19:32:34.022715      -
# 163948 2024-02-01 19:32:34.022715      -
# 163949 2024-02-01 19:32:34.022715      -
#
# [1291340 rows x 12 columns]

# %%
mdr[mdr['index'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, start_dates, end_dates, device, description, company, meta, manufacturer, manufacturer_country, Source, Updated, status]
# Index: []

# %%
mdr.shape
# Out:
# (1291340, 12)

# %%
del mdr['eyes']

# %%
mdr.Source.unique()
# Out:
# array(['ANMAT_AR', 'ARCSA_EC', 'ARTG_AU', 'CDSCO_IN', 'DMEC_VN',
#        'EUDAMED', 'FDA_TH', 'MDA_MY', 'MFDS_KR', 'MHRA_GB', 'MINSA_PN',
#        'MOHAP_AE', 'MOH_ID', 'FDA_PH', 'SMDR_SG', 'USFDA'], dtype=object)

# %%
mdr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1291340 entries, 0 to 163949
# Data columns (total 12 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   index                 1291340 non-null  object
#  1   start_dates           845401 non-null   datetime64[ns]
#  2   end_dates             734148 non-null   datetime64[ns]
#  3   device                1291340 non-null  object
#  4   description           1291340 non-null  object
#  5   company               1291339 non-null  object
#  6   meta                  1291340 non-null  object
#  7   manufacturer          1289675 non-null  object
#  8   manufacturer_country  1290816 non-null  object
#  9   Source                1291340 non-null  object
#  10  Updated               1291340 non-null  datetime64[ns]
#  11  status                1241772 non-null  object
# dtypes: datetime64[ns](3), object(9)
# memory usage: 128.1+ MB

# %%
mdr.describe()
# Out:
#                     index          start_dates            end_dates  \
# count             1291340               845401               734148
# unique             579571                 6391                 4662
# top     SMDR-SG-DE0502342  2020-10-08 00:00:00  2022-11-01 00:00:00
# freq                17830                24187                17952
# first                 NaN  1991-10-10 00:00:00  2000-01-26 00:00:00
# last                  NaN  2027-10-10 00:00:00  2206-09-22 00:00:00
#
#                                                    device description  \
# count                                             1291340     1291340
# unique                                             468156      732281
# top     Globus Medical CREO® Stabilization System [Glo...           -
# freq                                                17830      128508
# first                                                 NaN         NaN
# last                                                  NaN         NaN
#
#                                                   company          meta  \
# count                                             1291339       1291340
# unique                                              88390        265218
# top     1.  Nuvasive Inc _x000D_,       [Nuvasive] 747...  TTBYT type B
# freq                                                33003         39340
# first                                                 NaN           NaN
# last                                                  NaN           NaN
#
#        manufacturer manufacturer_country   Source                     Updated  \
# count       1289675              1290816  1291340                     1291340
# unique        70411                 1325       16                          12
# top               -                    -  SMDR_SG  2024-02-01 19:32:33.977810
# freq         290161               538572   599240                      599240
# first           NaN                  NaN      NaN  2024-02-01 19:32:33.813323
# last            NaN                  NaN      NaN  2024-02-01 19:32:34.022715
#
#          status
# count   1241772
# unique       42
# top           -
# freq    1090086
# first       NaN
# last        NaN

# %%
len(mdr.columns)
# Out:
# 12

# %%
for col in mdr.columns:
    print(col)
# Out:
# index
# start_dates
# end_dates
# device
# description
# company
# meta
# manufacturer
# manufacturer_country
# Source
# Updated
# status

# %%
mdr['Source'] = mdr['Source'].str.replace("PHFDA","FDA_PH")

# %%
for source in mdr.Source.unique():
    source_df = mdr[mdr['Source'] == source]
    source_df.to_excel(f"Stage\\Export\\{source.lower()}.xlsx", index=False)

# %%
company_device = mdr[['company','device','description','meta']]
company_device
# Out:
#                                 company  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163945               Ziehm Imaging GmbH
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                                    device  \
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163945                                      Ziehm Solo FD
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
#                                               description  \
# 0       Transparent I.V. dressing reinforced with chlo...
# 1                                  Biological heart valve
# 2                               Neuro-thrombectomy system
# 3                            Coronary thrombectomy system
# 4                                     Mobile X-ray system
# ...                                                   ...
# 163945           Interventional Fluoroscopic X-Ray System
# 163946                                         Bone Wedge
# 163947     Blood Pump For Ecmo, Long-Term (> 6 Hours) Use
# 163948                   Lenses, Soft Contact, Daily Wear
# 163949          Tubes, Gastrointestinal (And Accessories)
#
#                                                      meta
# 0       Oper film ®protect CHG 7 x 8,5 cm (Ref: 003400...
# 1       Aorticos:,DDL19A; DDL21A; DDL23A; DDL25A; DDL2...
# 2       VN-6044-F3NR (NeVa IC-3 Net),VN-6035-F2NR (NeV...
# 3       EV-4030-F2RR (enVast 4.0 x 30 mm),EV-4038-F3RR...
# 4                                        JADE-32, JADE-40
# ...                                                   ...
# 163945                               Specialty: Radiology
# 163946                              Specialty: Orthopedic
# 163947                          Specialty: Cardiovascular
# 163948                              Specialty: Ophthalmic
# 163949              Specialty: Gastroenterology & Urology
#
# [1291340 rows x 4 columns]

# %%
company_device

# %%
company_product_meta = company_device[['company','device']]
company_product_meta = company_product_meta.drop_duplicates()
company_product_meta
# Out:
#                                 company  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163944                         restor3d
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                                    device
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163944      restor3d TIDAL Lumbar Interbody Fusion System
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
# [552937 rows x 2 columns]

# %%
chunk_size = 700000  
number_of_chunks = len(company_device) // chunk_size + 1  
for i in range(number_of_chunks):
    start_index = i * chunk_size
    end_index = (i + 1) * chunk_size
    df_chunk = company_device.iloc[start_index:end_index]  
  
    df_chunk.to_excel(f"Stage\\Export\\Device Watchlist {i+1}.xlsx", index=False)

# %%
number_of_chunks
# Out:
# 2

# %%
##Final

# %%
pd.merge(company_product_meta, company_device, how="left")
# Out:
#                                  company  \
# 0               DROGUERIA MARTORANI S.A.
# 1               DROGUERIA MARTORANI S.A.
# 2               DROGUERIA MARTORANI S.A.
# 3               DROGUERIA MARTORANI S.A.
# 4               DROGUERIA MARTORANI S.A.
# ...                                  ...
# 1291335                         restor3d
# 1291336  Nvision Biomedical Technologies
# 1291337                   Abbott Medical
# 1291338               CooperVision, Inc.
# 1291339          Boehringer Laboratories
#
#                                                     device  \
# 0                                                      IHT
# 1                                                      IHT
# 2                                                      IHT
# 3                                                      IHT
# 4                                                      IHT
# ...                                                    ...
# 1291335      restor3d TIDAL Lumbar Interbody Fusion System
# 1291336  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 1291337        CentriMag Acute Circulatory Support System
# 1291338  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 1291339                      ViSiGi 3D Gastric Sizing Tube
#
#                                                description  \
# 0        Transparent I.V. dressing reinforced with chlo...
# 1                        Non -sterile self -adhesive tapes
# 2                            Transparent adhesive dressing
# 3        Products for drainage and suction. Accessory a...
# 4                         Sterile self -adhesive dressings
# ...                                                    ...
# 1291335  Intervertebral Fusion Device With Bone Graft, ...
# 1291336                                         Bone Wedge
# 1291337     Blood Pump For Ecmo, Long-Term (> 6 Hours) Use
# 1291338                   Lenses, Soft Contact, Daily Wear
# 1291339          Tubes, Gastrointestinal (And Accessories)
#
#                                                       meta
# 0        Oper film ®protect CHG 7 x 8,5 cm (Ref: 003400...
# 1        OPE tape,OPE PAPER OPER,OPE Tape Clear,OPE Tap...
# 2                                                  #VALUE!
# 3                                           Aspirator bags
# 4                                                  #VALUE!
# ...                                                    ...
# 1291335                              Specialty: Orthopedic
# 1291336                              Specialty: Orthopedic
# 1291337                          Specialty: Cardiovascular
# 1291338                              Specialty: Ophthalmic
# 1291339              Specialty: Gastroenterology & Urology
#
# [1291340 rows x 4 columns]

# %%
empty_company = company_product_meta[company_product_meta.company.isna()]
not_empty_company = company_product_meta[company_product_meta.company.notna()]

# %%
empty_company
# Out:
#        company                                             device
# 49075      NaN                                                NaN
# 173        NaN                       IDRESPI-P1-500 (FR) - Boîtes
# 977        NaN  QuicGTM Fungus (1-3)-β-D-Glucan Lateral Flow A...
# 1138       NaN  Detection Kit for 2019-nCoV Nucleic Acid (RT-L...
# 1239       NaN    MycoSmear Fungus Fluorescence Staining Solution
# ...        ...                                                ...
# 740152     NaN           Rionet HB 37S/37T BTE Hearing Aid [Rion]
# 748693     NaN  Rocket Medical Haemorrhoidal Injection Set [Ro...
# 757380     NaN  Schulke & Mayr Perform® Disinfectant [Schulke ...
# 757381     NaN  Schulke & Mayr Octenilin® Wound Gel [Schulke &...
# 902177     NaN  SYNTHES® RFS Resorbable Fexation System [Synthes]
#
# [301 rows x 2 columns]

# %%
empty_company.merge(not_empty_company, how="left")
# Out:
#     company                                             device
# 0       NaN                                                NaN
# 1       NaN                       IDRESPI-P1-500 (FR) - Boîtes
# 2       NaN  QuicGTM Fungus (1-3)-β-D-Glucan Lateral Flow A...
# 3       NaN  Detection Kit for 2019-nCoV Nucleic Acid (RT-L...
# 4       NaN    MycoSmear Fungus Fluorescence Staining Solution
# ..      ...                                                ...
# 296     NaN           Rionet HB 37S/37T BTE Hearing Aid [Rion]
# 297     NaN  Rocket Medical Haemorrhoidal Injection Set [Ro...
# 298     NaN  Schulke & Mayr Perform® Disinfectant [Schulke ...
# 299     NaN  Schulke & Mayr Octenilin® Wound Gel [Schulke &...
# 300     NaN  SYNTHES® RFS Resorbable Fexation System [Synthes]
#
# [301 rows x 2 columns]

# %%
not_empty_company
# Out:
#                                 company  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163944                         restor3d
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                                    device
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163944      restor3d TIDAL Lumbar Interbody Fusion System
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
# [551417 rows x 2 columns]

# %%
company_product_meta.sort_values(by="company")
# Out:
#        company                                             device
# 52619            \nSansure Portable Molecular Workstation Port...
# 25092            \nQ-PLUS EVO Family Laser Systems IPL goggles...
# 25093            \nQ-PLUS EVO Family Laser Systems Goggle Prot...
# 25094            \nQ-PLUS EVO Family Laser Systems Safety gogg...
# 25553            \nScope lithotripter L 100 230V for Uretero R...
# ...        ...                                                ...
# 740152     NaN           Rionet HB 37S/37T BTE Hearing Aid [Rion]
# 748693     NaN  Rocket Medical Haemorrhoidal Injection Set [Ro...
# 757380     NaN  Schulke & Mayr Perform® Disinfectant [Schulke ...
# 757381     NaN  Schulke & Mayr Octenilin® Wound Gel [Schulke &...
# 902177     NaN  SYNTHES® RFS Resorbable Fexation System [Synthes]
#
# [551718 rows x 2 columns]

# %%
len(mdr['company'].unique())
# Out:
# 88092

# %%
manufacturer_device = mdr[['manufacturer','device']]
manufacturer_device
# Out:
#                            manufacturer  \
# 0                                     -
# 1                                     -
# 2                                     -
# 3                                     -
# 4                                     -
# ...                                 ...
# 163945               Ziehm Imaging GmbH
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                                    device
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163945                                      Ziehm Solo FD
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
# [1769192 rows x 2 columns]

# %%
del collect['Unnamed: 0']

# %%
collect.columns
# Out:
# Index(['index', 'end_date', 'company_', 'description', 'device', 'meta',
#        'manufacturer', 'manufacturer_country', 'start_date', 'Source',
#        'status'],
#       dtype='object')

# %%
collect = collect[['index','start_date', 'end_date','device', 'company_', 'description', 'meta',
       'manufacturer', 'manufacturer_country', 'Source',
       'status']]

# %%
collect
# Out:
#                 index           start_date    end_date  \
# 0          ANMAT-AR-0                    -  25-01-2024
# 1          ANMAT-AR-1                    -  25-01-2024
# 2          ANMAT-AR-2                    -  25-01-2024
# 3          ANMAT-AR-3                    -  25-01-2024
# 4          ANMAT-AR-4                    -  25-01-2024
# ...               ...                  ...         ...
# 163945  USFDA-K234109  2024-01-26 00:00:00           -
# 163946  USFDA-K234116  2024-01-26 00:00:00           -
# 163947  USFDA-K234118  2024-01-26 00:00:00           -
# 163948  USFDA-K234127  2024-01-25 00:00:00           -
# 163949  USFDA-K234145  2024-01-26 00:00:00           -
#
#                                                    device  \
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163945                                      Ziehm Solo FD
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
#                                company_  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163945               Ziehm Imaging GmbH
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                               description  \
# 0       Transparent I.V. dressing reinforced with chlo...
# 1                                  Biological heart valve
# 2                               Neuro-thrombectomy system
# 3                            Coronary thrombectomy system
# 4                                     Mobile X-ray system
# ...                                                   ...
# 163945           Interventional Fluoroscopic X-Ray System
# 163946                                         Bone Wedge
# 163947     Blood Pump For Ecmo, Long-Term (> 6 Hours) Use
# 163948                   Lenses, Soft Contact, Daily Wear
# 163949          Tubes, Gastrointestinal (And Accessories)
#
#                                                      meta  \
# 0       Oper film ®protect CHG 7 x 8,5 cm (Ref: 003400...
# 1       Aorticos:\nDDL19A; DDL21A; DDL23A; DDL25A; DDL...
# 2       VN-6044-F3NR (NeVa IC-3 Net)\nVN-6035-F2NR (Ne...
# 3       EV-4030-F2RR (enVast 4.0 x 30 mm)\nEV-4038-F3R...
# 4                                        JADE-32, JADE-40
# ...                                                   ...
# 163945                               Specialty: Radiology
# 163946                              Specialty: Orthopedic
# 163947                          Specialty: Cardiovascular
# 163948                              Specialty: Ophthalmic
# 163949              Specialty: Gastroenterology & Urology
#
#                            manufacturer manufacturer_country    Source status
# 0                                     -                    -  ANMAT_AR    NaN
# 1                                     -                    -  ANMAT_AR    NaN
# 2                                     -                    -  ANMAT_AR    NaN
# 3                                     -                    -  ANMAT_AR    NaN
# 4                                     -                    -  ANMAT_AR    NaN
# ...                                 ...                  ...       ...    ...
# 163945               Ziehm Imaging GmbH                    -  USFDA_US    NaN
# 163946  Nvision Biomedical Technologies                    -  USFDA_US    NaN
# 163947                   Abbott Medical                    -  USFDA_US    NaN
# 163948               CooperVision, Inc.                    -  USFDA_US    NaN
# 163949          Boehringer Laboratories                    -  USFDA_US    NaN
#
# [1771393 rows x 11 columns]

# %%
collect = collect.rename(columns = {"company_":"company"})

# %%
collect.to_csv("Stage\\MDRv2 Consolidated.csv")

# %%
collect
# Out:
#                 index           start_date    end_date  \
# 0          ANMAT-AR-0                    -  25-01-2024
# 1          ANMAT-AR-1                    -  25-01-2024
# 2          ANMAT-AR-2                    -  25-01-2024
# 3          ANMAT-AR-3                    -  25-01-2024
# 4          ANMAT-AR-4                    -  25-01-2024
# ...               ...                  ...         ...
# 163945  USFDA-K234109  2024-01-26 00:00:00           -
# 163946  USFDA-K234116  2024-01-26 00:00:00           -
# 163947  USFDA-K234118  2024-01-26 00:00:00           -
# 163948  USFDA-K234127  2024-01-25 00:00:00           -
# 163949  USFDA-K234145  2024-01-26 00:00:00           -
#
#                                                    device  \
# 0                                                     IHT
# 1                                                 Measure
# 2                                                 Neva No
# 3                                                  enVast
# 4                                             I'm shaking
# ...                                                   ...
# 163945                                      Ziehm Solo FD
# 163946  Trigon Trigon HA Stand-Alone Wedge Fixation Sy...
# 163947        CentriMag Acute Circulatory Support System
# 163948  Clariti 1 day Multifocal (somofilcon A) Soft (...
# 163949                      ViSiGi 3D Gastric Sizing Tube
#
#                                 company  \
# 0              DROGUERIA MARTORANI S.A.
# 1                             TESIS SRL
# 2                         UNIFARMA S.A.
# 3                         UNIFARMA S.A.
# 4                          DIGIMED S.A.
# ...                                 ...
# 163945               Ziehm Imaging GmbH
# 163946  Nvision Biomedical Technologies
# 163947                   Abbott Medical
# 163948               CooperVision, Inc.
# 163949          Boehringer Laboratories
#
#                                               description  \
# 0       Transparent I.V. dressing reinforced with chlo...
# 1                                  Biological heart valve
# 2                               Neuro-thrombectomy system
# 3                            Coronary thrombectomy system
# 4                                     Mobile X-ray system
# ...                                                   ...
# 163945           Interventional Fluoroscopic X-Ray System
# 163946                                         Bone Wedge
# 163947     Blood Pump For Ecmo, Long-Term (> 6 Hours) Use
# 163948                   Lenses, Soft Contact, Daily Wear
# 163949          Tubes, Gastrointestinal (And Accessories)
#
#                                                      meta  \
# 0       Oper film ®protect CHG 7 x 8,5 cm (Ref: 003400...
# 1       Aorticos:\nDDL19A; DDL21A; DDL23A; DDL25A; DDL...
# 2       VN-6044-F3NR (NeVa IC-3 Net)\nVN-6035-F2NR (Ne...
# 3       EV-4030-F2RR (enVast 4.0 x 30 mm)\nEV-4038-F3R...
# 4                                        JADE-32, JADE-40
# ...                                                   ...
# 163945                               Specialty: Radiology
# 163946                              Specialty: Orthopedic
# 163947                          Specialty: Cardiovascular
# 163948                              Specialty: Ophthalmic
# 163949              Specialty: Gastroenterology & Urology
#
#                            manufacturer manufacturer_country    Source status
# 0                                     -                    -  ANMAT_AR    NaN
# 1                                     -                    -  ANMAT_AR    NaN
# 2                                     -                    -  ANMAT_AR    NaN
# 3                                     -                    -  ANMAT_AR    NaN
# 4                                     -                    -  ANMAT_AR    NaN
# ...                                 ...                  ...       ...    ...
# 163945               Ziehm Imaging GmbH                    -  USFDA_US    NaN
# 163946  Nvision Biomedical Technologies                    -  USFDA_US    NaN
# 163947                   Abbott Medical                    -  USFDA_US    NaN
# 163948               CooperVision, Inc.                    -  USFDA_US    NaN
# 163949          Boehringer Laboratories                    -  USFDA_US    NaN
#
# [1771393 rows x 11 columns]

# %%
cdsco_in.to_excel("Stage\\cdsco_in.xlsx")

# %%
collect.columns
# Out:
# Index(['Company', 'Device Name', 'Approval Area', 'Intended Purpose',
#        'Manufacturer Address', 'Manufacturer Country', 'index', 'Source'],
#       dtype='object')

# %%
collect.rename(columns = {'Device Name':'Product','Intended Purpose':'Description'}, inplace=True)

# %%
import pandas as pd
import numpy as np
import os,time, glob as g
import warnings as ws
import time
ws.filterwarnings("ignore")


data = os.getcwd()+"\\Data\\Wave 2"
files = g.glob(os.path.join(data,'*.xlsx'))
files

holder = dict()
for file in files:
    
    hold = pd.read_excel(file)
    country = file.split("\\")[-1].split(".")[0]
    print(country)
    print(f"Columns: {len(hold.columns)} {hold.columns}")
    holder[country] = hold
    print(hold.shape)
    
indo = holder['df_catalog']
indo.rename(columns = {'Company':'Not_req','Brand':'Company'}, inplace=True)
indo['Description'] = indo['Company'] + " "+indo['Product']
sg = holder['SG_MDR']
sg.rename(columns = {'Model_list':'Product','Registrant_list':'Company'}, inplace=True)
sg['Description'] = sg['Device_Name'] + " " + sg['Description_list']
# Out:
# df_catalog
# Columns: 5 Index(['Product', 'Price', 'Company', 'Brand', 'Function'], dtype='object')
# (53628, 5)
# SG_MDR
# Columns: 10 Index(['Device_Name', 'Description_list', 'Medical_Specialty_Area',
#        'Medical_Device_Class', 'Device_Registration', 'Registration_Date',
#        'Device_System', 'Product_Owner', 'Registrant_list', 'Model_list'],
#       dtype='object')
# (77064, 10)

# %%
grill = [indo, sg]
collect = pd.concat([collect,indo, sg])

# %%
hold = collect.copy()
collect.shape
# Out:
# (508366, 19)

# %%
collect.drop_duplicates(inplace=True)

# %%
collect.shape
# Out:
# (430369, 19)

# %%
collect.columns
# Out:
# Index(['Company', 'Product', 'Approval Area', 'Description',
#        'Manufacturer Address', 'Manufacturer Country', 'index', 'Source',
#        'Price', 'Not_req', 'Function', 'Device_Name', 'Description_list',
#        'Medical_Specialty_Area', 'Medical_Device_Class', 'Device_Registration',
#        'Registration_Date', 'Device_System', 'Product_Owner'],
#       dtype='object')

# %%
#chunk = collect['Company','Product']
X = collect[['Product', 'Description']]
y = collect['Company']

# %%
# !pip install transformers[sentencepiece]

# %%
collect.head(4)
# Out:
#                       Company  \
# 0         Tsunami Medical SRL
# 1  Unimax Medical Systems Inc
# 2           Medwin France SAS
# 3         Elekta Solutions AB
#
#                                              Product    Approval Area  \
# 0  Bone-screw internal spinal fixation system, no...  Medical Devices
# 1                       Antifog solution, endoscopic  Medical Devices
# 2  Pilot TLS - Central venous catheter navigation...  Medical Devices
# 3      Radionuclide system, therapeutic, teletherapy  Medical Devices
#
#                                          Description  \
# 0  The Ventotene Spinal System is intended for po...
# 1  Anti-Fog Solution is intended to be used to pr...
# 2  A portable system intended to process and disp...
# 3  Leksell Gamma Knife® is a teletherapy device i...
#
#                                 Manufacturer Address Manufacturer Country  \
# 0                Via Emilio Giorgi 27, Modena, 41124                Italy
# 1  8F-2 No 127 Lane 235 Pao Chiao Road, Xindian D...               Taiwan
# 2       9 allée de la Vigne Grande, Les Aires, 34600               France
# 3   Kungstensgatan 18 Box 7593, Stockholm, SE-103 93               Sweden
#
#     index Source Price Not_req Function Device_Name Description_list  \
# 0  397231   ARTG   NaN     NaN      NaN         NaN              NaN
# 1  397292   ARTG   NaN     NaN      NaN         NaN              NaN
# 2  397310   ARTG   NaN     NaN      NaN         NaN              NaN
# 3  397291   ARTG   NaN     NaN      NaN         NaN              NaN
#
#   Medical_Specialty_Area Medical_Device_Class Device_Registration  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
#
#   Registration_Date Device_System Product_Owner
# 0               NaN           NaN           NaN
# 1               NaN           NaN           NaN
# 2               NaN           NaN           NaN
# 3               NaN           NaN           NaN

# %%
data = collect[['Company','Product','Description']]
data_chunk = data.iloc[:50000]
data_chunk.head(1)
# Out:
#                Company                                            Product  \
# 0  Tsunami Medical SRL  Bone-screw internal spinal fixation system, no...
#
#                                          Description
# 0  The Ventotene Spinal System is intended for po...

# %%
collect.to_excel("MDR_consoldiated_05-06-2023.xlsx")
data.to_csv("labelled_data.csv")

# %%
data = pd.read_csv("labelled_data.csv")
del data["Unnamed: 0"]

# %%
data.description.isna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 430364    False
# 430365    False
# 430366    False
# 430367    False
# 430368    False
# Name: description, Length: 430369, dtype: bool

# %%
cols = data.columns
for col in cols:
    data[col] = data[col].astype(str)

# %%
from transformers import pipeline
ner = pipeline("ner", grouped_entities=True)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (…)lve/main/config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, AdamW
from torch.utils.data import TensorDataset, DataLoader

# Load the labeled dataset with company, product, and description columns
labeled_data = data.copy()

# Filter out rows with empty descriptions
labeled_data = labeled_data.dropna(subset=['description'])

# Split the labeled dataset into training and validation sets
train_data, val_data = train_test_split(labeled_data, test_size=0.2, random_state=42)

# Define the tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=2)

# Tokenize the input descriptions for the training and validation sets
train_tokens = tokenizer.batch_encode_plus(
    train_data['description'].tolist(),
    truncation=True,
    padding=True,
    return_tensors='pt'
)
val_tokens = tokenizer.batch_encode_plus(
    val_data['description'].tolist(),
    truncation=True,
    padding=True,
    return_tensors='pt'
)

# Convert the tokenized data to tensors
train_inputs = train_tokens['input_ids']
train_masks = train_tokens['attention_mask']
train_labels = torch.tensor(train_data[['company', 'product']].values)

val_inputs = val_tokens['input_ids']
val_masks = val_tokens['attention_mask']
val_labels = torch.tensor(val_data[['company', 'product']].values)

# Create TensorDatasets and DataLoaders
train_dataset = TensorDataset(train_inputs, train_masks, train_labels)
val_dataset = TensorDataset(val_inputs, val_masks, val_labels)

batch_size = 16
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size)

# Set up the optimizer and training loop
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
optimizer = AdamW(model.parameters(), lr=2e-5)

epochs = 5
for epoch in range(epochs):
    model.train()
    total_loss = 0
    
    for batch in train_dataloader:
        input_ids = batch[0].to(device)
        attention_mask = batch[1].to(device)
        labels = batch[2].to(device)
        
        optimizer.zero_grad()
        
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()
        
        loss.backward()
        optimizer.step()
    
    avg_train_loss = total_loss / len(train_dataloader)
    print('Epoch:', epoch+1, 'Training Loss:', avg_train_loss)
    
    model.eval()
    val_loss = 0
    predictions = []
    
    for batch in val_dataloader:
        input_ids = batch[0].to(device)
        attention_mask = batch[1].to(device)
        labels = batch[2].to(device)
        
        with torch.no_grad():
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        
        loss = outputs.loss
        val_loss += loss.item()
        
        logits = outputs.logits
        predictions.extend(logits.argmax(dim=1).tolist())
    
    avg_val_loss = val_loss / len(val_dataloader)
    accuracy = (torch.tensor(predictions) == val_labels).sum().item() / len(val_labels)
    print('Epoch:', epoch+1, 'Validation Loss:', avg_val_loss, 'Validation Accuracy:', accuracy)
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.bias', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 37>()
#      35 train_inputs = train_tokens['input_ids']
#      36 train_masks = train_tokens['attention_mask']
# ---> 37 train_labels = torch.tensor(train_data[['company', 'product']].values)
#      39 val_inputs = val_tokens['input_ids']
#      40 val_masks = val_tokens['attention_mask']
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %%
collect = collect.fillna("-")

# %%
collect.to_csv('MDR Tableau input.csv')
