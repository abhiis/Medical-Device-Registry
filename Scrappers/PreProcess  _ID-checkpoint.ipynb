# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\IT'
os.chdir(source)
file = "elenco_dm_tutti_csv_formato_opendata_UltimaVersione.csv"
delimiter = ';'

# %%
payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
payload.shape
# Out:
# C:\Users\AbhishekSrivastava\AppData\Local\Temp\ipykernel_19384\2915228804.py:1: DtypeWarning: Columns (9,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
# (1902028, 16)

# %%
cols = payload.columns
cols_en = [translate_to_en(x) for x in cols]
cols_en
# Out:
# ['TYPE',
#  'PROGRESSIVE_DM_ASS',
#  'FIRST_PUBLICATION_DATE',
#  'DM_REFERENCE',
#  'SIMILAR_DM_GROUP',
#  'REPERTORY REGISTRATION',
#  'START_VALIDITY',
#  'END_VALIDITY',
#  'MANUFACTURER ASSEMBLER',
#  'TAX ID CODE',
#  'PARTITA_IVA_VATNUMBER',
#  'CODE_CATALOGUE_FABBR_ASS',
#  'TRADING NAME',
#  'CND CLASSIFICATION',
#  'DESCRIPTION CND',
#  'TRADE_END DATE']

# %%
payload.columns = cols_en

# %%
grill = payload.sample(10)
grill
# Out:
#          TYPE  PROGRESSIVE_DM_ASS FIRST_PUBLICATION_DATE  DM_REFERENCE  \
# 1504467     1             2129346             2021-06-23           NaN
# 1862028     1             2524373             2024-01-12           NaN
# 1819730     1             2479968             2023-09-21           NaN
# 444218      1              645706             2012-10-31           NaN
# 626888      1             1199469             2014-08-16           NaN
# 463305      1              732653             2013-01-26           NaN
# 629310      1             1202058             2014-08-28           NaN
# 501826      1              875114             2013-06-27           NaN
# 1030665     1             1620895             2017-10-20           NaN
# 667140      1             1241649             2014-12-10           NaN
#
#          SIMILAR_DM_GROUP REPERTORY REGISTRATION START_VALIDITY END_VALIDITY  \
# 1504467          132602.0                      S     2021-06-23   9999-12-31
# 1862028          160911.0                      S     2024-01-12   9999-12-31
# 1819730          157544.0                      S     2023-11-30   9999-12-31
# 444218                NaN                      S     2012-10-31   9999-12-31
# 626888            60087.0                      S     2014-08-16   9999-12-31
# 463305                NaN                      S     2015-04-13   9999-12-31
# 629310                NaN                      S     2014-08-28   9999-12-31
# 501826            48271.0                      S     2013-06-27   9999-12-31
# 1030665               NaN                      S     2017-10-20   9999-12-31
# 667140            62987.0                      N     2014-12-10   9999-12-31
#
#                       MANUFACTURER ASSEMBLER  TAX ID CODE  \
# 1504467            MICROPORT ORTHOPEDICS INC          NaN
# 1862028                   SMITH & NEPHEW INC          NaN
# 1819730                 LIMACORPORATE S.P.A.  01427710304
# 444218                                  CFPM          NaN
# 626888                  DENTAL MORELLI LTDA.          NaN
# 463305                 MEDICAL DEVICE S.R.L.  04546220825
# 629310                    RESPONSE ORTHO LLC          NaN
# 501826                       CITIEFFE S.R.L.  00574250379
# 1030665  TOSHIBA MEDICAL SYSTEMS CORPORATION          NaN
# 667140         BIOTYPE IMPLANT SYSTEM S.R.L.  03318470923
#
#         PARTITA_IVA_VATNUMBER CODE_CATALOGUE_FABBR_ASS  \
# 1504467                   NaN                 E6300005
# 1862028                   NaN                 71806026
# 1819730           01427710304              9095.10.552
# 444218            83340747476                  0117547
# 626888                    NaN                48.31.009
# 463305                    NaN              MD 01 02241
# 629310                    NaN              50-1012-XXX
# 501826            00516271202                 DF201020
# 1030665                   NaN                 TSX-303B
# 667140            03318470923                     ID12
#
#                                               TRADING NAME CND CLASSIFICATION  \
# 1504467  EVOLUTION¿ REV OPT DISTAL FEM 5 DEG VALGUS BUS...              L0999
# 1862028    VITE CORTICALE AUTOFILETTANTE TESTA LOW PROFILE          P09120601
# 1819730                  TRIAL HEAD TAPER 12/14 DIA.28MM M          V06010101
# 444218                           CLINIX ENDO PREP SOLUTION              Q0199
# 626888   ORTHODONTIC BAND 33 RU/LU WITH TUBES 20.10.611...            Q010402
# 463305   KIT INTRODUZIONE ECOGENICO SELDINGER PER CATET...              C0503
# 629310                                 DUAL HOLE FULL RING          P09120499
# 501826        DOLPHIX - MORSETTO CON VITE OSSEA D.6X160 MM          P09120499
# 1030665                                  AQUILION PRIME SP          Z11030606
# 667140                  VERTICAL NECK IMPIANTO 3.7 X 12 MM            P010201
#
#                                            DESCRIPTION CND TRADE_END DATE
# 1504467      STRUMENTARIO PER CHIRURGIA ORTOPEDICA - ALTRO            NaN
# 1862028                                  VITI DA CORTICALE            NaN
# 1819730            DISPOSITIVI DI PROVA PER PROTESI D'ANCA            NaN
# 444218                DISPOSITIVI PER ODONTOIATRIA - ALTRI            NaN
# 626888                                BANDE PER ORTODONZIA     2020-09-22
# 463305   INTRODUTTORI PEEL-AWAY PER APPARATO CARDIOCIRC...            NaN
# 629310          FISSATORI ESTERNI PER OSTEOSINTESI - ALTRI            NaN
# 501826          FISSATORI ESTERNI PER OSTEOSINTESI - ALTRI            NaN
# 1030665  TOMOGRAFI ASSIALI COMPUTERIZZATI - SUPERIORE O...            NaN
# 667140                                    IMPIANTI DENTALI            NaN

# %%
cols_i_want = ['START_VALIDITY',
'TRADE_END DATE',
 'MANUFACTURER ASSEMBLER','TRADING NAME','DESCRIPTION CND']

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#         START_VALIDITY TRADE_END DATE  \
# 0           2013-06-25            NaN
# 1           2007-07-06     2010-03-16
# 2           2021-12-31            NaN
# 3           2007-09-14            NaN
# 6           2021-12-31            NaN
# ...                ...            ...
# 1902023     2024-01-27            NaN
# 1902024     2024-01-27            NaN
# 1902025     2024-01-27            NaN
# 1902026     2024-01-27            NaN
# 1902027     2024-01-27            NaN
#
#                            MANUFACTURER ASSEMBLER  \
# 0                                    ID&CO S.R.L.
# 1        JOHNSON & JOHNSON MEDICAL HOLDING S.P.A.
# 2                                 BUERKI INNO MED
# 3                                     ACTIMEX SRL
# 6                                 BUERKI INNO MED
# ...                                           ...
# 1902023                          PAUL HARTMANN AG
# 1902024                          PAUL HARTMANN AG
# 1902025                          PAUL HARTMANN AG
# 1902026                       TAUMEDIPLAST S.R.L.
# 1902027                       TAUMEDIPLAST S.R.L.
#
#                                               TRADING NAME  \
# 0                                  PENNARELLI DERMOGRAFICI
# 1                                                VACUDRAIN
# 2        CANNULE IRRIGAZIONE/ASPIRAZIONE PER TECNICA BI...
# 3                                RINOCICLINA SPRAY  NASALE
# 6        CANNULE IRRIGAZIONE ASPIRAZIONE COASSIALI PLUR...
# ...                                                    ...
# 1902023                            COMBISET PER RADIOLOGIA
# 1902024                              COMBISET PER UROLOGIA
# 1902025                   COMBISET PER CHIRURGIA VASCOLARE
# 1902026  I-WASH STAT 250, STAZIONE PER LAVAGGIO OCULARE...
# 1902027  EWS, EYE WASH STATION IN ORANGE ABS BOX COMBISTAR
#
#                                            DESCRIPTION CND
# 0                                     MATITE DERMOGRAFICHE
# 1                  SISTEMI DI DRENAGGIO PERCUTANEO - ALTRI
# 2        CANNULE MONOUSO PER ASPIRAZIONE/IRRIGAZIONE IN...
# 3                         DISPOSITIVI NASOFARINGEI - ALTRI
# 6                    STRUMENTARIO PER OFTALMOLOGIA - ALTRO
# ...                                                    ...
# 1902023                                                NaN
# 1902024                                                NaN
# 1902025                                                NaN
# 1902026                                                NaN
# 1902027                                                NaN
#
# [1433017 rows x 5 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (1433017, 5)

# %%
len(grill['MANUFACTURER ASSEMBLER'].unique())
# Out:
# 22407

# %%
len(grill[''].unique())
# Out:
# 1236200

# %%
len(grill['DESCRIPTION CND'].unique())
# Out:
# 6910

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text
def prep_translate(df, col):
    cached_en = {}
    unique_vals = df[col].unique()
    print("API Calls: ", len(unique_vals))
    for val in tqdm(unique_vals):
        cached_en[val] = translate_to_en(val)
    return cached_en


def update_cache(val):
    translation = translate_to_en(val)
    cached_en[val] = translation
    return val, translation

# %%
cached_en = prep_translate(grill, 'MANUFACTURER ASSEMBLER')
# Out:
# API Calls:  22407

# %%
cached_en2 = prep_translate(grill, 'TRADING NAME')
cached_en3 = prep_translate(grill, 'DESCRIPTION CND')

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 chunks = split_dataframe(grill, 1000)
#
# NameError: name 'split_dataframe' is not defined

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
