# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\BR'
os.chdir(source)
file = "TA_PRODUTO_SAUDE_SITE.csv"
delimiter = ';'

# %%
payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
payload.shape
# Out:
# (97258, 12)

# %%
cols = payload.columns
cols_en = [translate_to_en(x) for x in cols]
cols_en
# Out:
# ['REGISTRATION NUMBER REGISTRATION',
#  'PROCESS_NUMBER',
#  'TECHNICAL_NAME',
#  'RISK_CLASS',
#  'COMMERCIAL NAME',
#  'CNPJ_DETENTOR_REGISTRO_CADASTRO',
#  'REGISTRATION HOLDER REGISTRATION',
#  'MANUFACTURER_NAME',
#  'FABRIC_COUNTRY_NAME',
#  'DT_PUB_REGISTRO_CADASTRO',
#  'VALIDITY REGISTRATION REGISTRATION',
#  'DT_ATUALIZACAO_DADO']

# %%
payload.columns = cols_en

# %%
grill = payload.sample(10)
grill
# Out:
#        REGISTRATION NUMBER REGISTRATION     PROCESS_NUMBER  \
# 75861                      8.119927e+10  25351603084201905
# 14783                      8.166905e+10  25351090058202111
# 46491                      1.033066e+10  25351344563201703
# 96909                      1.040157e+10  25351974431201687
# 597                        1.006839e+10    250000171889761
# 44138                      8.013486e+10  25351329144201619
# 77048                      8.010415e+10  25351615322201462
# 41087                      8.160566e+10  25351306270201991
# 51409                      1.034135e+10  25351388158201162
# 78973                      1.040541e+10  25351634005202033
#
#                                           TECHNICAL_NAME RISK_CLASS  \
# 75861                 Resina Composta  Fotopolimerizável         II
# 14783                              Vestimenta Hospitalar          I
# 46491                               Vestimenta Cirurgica          I
# 96909                        Componentes Para Ortodontia         II
# 597                                              Equipos         II
# 44138  IMUNOHEMATOLOGIA - RH-HR, KELL, KIDD, DUFFY - ...         IV
# 77048                           Micro Motor Odontologico         II
# 41087  CONJUNTO DE VESTIMENTA CIRÚRGICA, CAMPO CIRÚRGICO          I
# 51409                             ENDOPRÓTESE (VASCULAR)        III
# 78973       Software de Planej. de Trat. P/ Radioterapia        III
#
#                                          COMMERCIAL NAME  \
# 75861                                     ESTELITE COLOR
# 14783                               Macacão de Segurança
# 46491          Avental Cirúrgico Reforçado Descarpack II
# 96909                          BIO STOP DE POLICARBONATO
# 597    EQUIPO DE BOMBA DE INFUSÃO PARA ADMINISTRAÇÃO ...
# 44138                               Anti-D IgG Mono-Type
# 77048                           MICRO MOTOR ODONTOLÓGICO
# 41087                CAMPO CIRÚRGICO ESTÉRIL DESCARTÁVEL
# 51409  WALLSTENT ILÍACO COM SISTEMA INTRODUTOR UNISTE...
# 78973     Sistema de Gerenciamento para Tratamento Ethos
#
#        CNPJ_DETENTOR_REGISTRO_CADASTRO  \
# 75861                   17910389000105
# 14783                    6318416000139
# 46491                    1057428000133
# 96909                   58528639000124
# 597                     49351786000180
# 44138                    2513899000171
# 77048                    3440703000129
# 41087                   27608037000153
# 51409                    1513946000114
# 78973                    3009915000156
#
#                         REGISTRATION HOLDER REGISTRATION  \
# 75861                                 PHS DO BRASIL LTDA
# 14783  SUPER SAFETY INDUSTRIA, COMERCIO E IMPORTACAO ...
# 46491             DESCARPACK DESCARTAVEIS DO BRASIL LTDA
# 96909           TECNIDENT EQUIPAMENTOS ORTODONTICOS LTDA
# 597                               BAXTER HOSPITALAR LTDA
# 44138                                GRIFOLS BRASIL LTDA
# 77048               EASY EQUIPAMENTOS ODONTOLOGICOS LTDA
# 41087  DEJAMARO INDUSTRIA E COMERCIO DE PRODUTOS MEDI...
# 51409                   BOSTON SCIENTIFIC DO BRASIL LTDA
# 78973                 VARIAN MEDICAL SYSTEMS BRASIL LTDA
#
#                                        MANUFACTURER_NAME  \
# 75861                        TOKUYAMA DENTAL CORPORATION
# 14783                           SUPER SAFETY PARAGUAY SA
# 46491                   FUSHI PROTECTIVE PRODUCTS CO LTD
# 96909           TECNIDENT EQUIPAMENTOS ORTODONTICOS LTDA
# 597                               Baxter Healthcare S.A.
# 44138                                                NaN
# 77048               EASY EQUIPAMENTOS ODONTOLOGICOS LTDA
# 41087  DEJAMARO INDUSTRIA E COMERCIO DE PRODUTOS MEDI...
# 51409                          BOSTON SCIENTIFIC LIMITED
# 78973                       VARIAN MEDICAL SYSTEMS, INC.
#
#              FABRIC_COUNTRY_NAME DT_PUB_REGISTRO_CADASTRO  \
# 75861                      JAPÃO               11/11/2019
# 14783                   PARAGUAI               26/08/2021
# 46491   CHINA, REPÚBLICA POPULAR               14/08/2017
# 96909                     BRASIL               18/04/2016
# 597                        SUÍÇA               12/09/1997
# 44138                        NaN               10/07/2017
# 77048                     BRASIL               12/01/2015
# 41087                     BRASIL               13/06/2019
# 51409                    IRLANDA               19/12/2011
# 78973  ESTADOS UNIDOS DA AMÉRICA               21/12/2020
#
#       VALIDITY REGISTRATION REGISTRATION  DT_ATUALIZACAO_DADO
# 75861                            VIGENTE  09/20/2022 19:00:01
# 14783                            VIGENTE  09/20/2022 19:00:01
# 46491                            VIGENTE  09/20/2022 19:00:01
# 96909                            VIGENTE  09/20/2022 19:00:01
# 597                              VIGENTE  09/20/2022 19:00:01
# 44138                         10/07/2027  09/20/2022 19:00:01
# 77048                            VIGENTE  09/20/2022 19:00:01
# 41087                            VIGENTE  09/20/2022 19:00:01
# 51409                         19/12/2026  09/20/2022 19:00:01
# 78973                         21/12/2030  09/20/2022 19:00:01

# %%
cols_i_want = ['DT_PUB_REGISTRO_CADASTRO',
'VALIDITY REGISTRATION REGISTRATION','REGISTRATION HOLDER REGISTRATION',
 'MANUFACTURER_NAME','COMMERCIAL NAME','TECHNICAL_NAME']

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#       DT_PUB_REGISTRO_CADASTRO VALIDITY REGISTRATION REGISTRATION  \
# 0                   09/05/2000                            VIGENTE
# 1                   29/02/1996                            VIGENTE
# 2                   26/05/2000                         26/05/2025
# 3                   26/05/2000                         26/05/2025
# 4                   11/03/1999                         01/03/2024
# ...                        ...                                ...
# 97253               05/09/2016                            VIGENTE
# 97254               01/10/2020                            VIGENTE
# 97255               28/05/1999                            VIGENTE
# 97256               25/08/1994                            VIGENTE
# 97257               04/08/1994                         01/08/2024
#
#                         REGISTRATION HOLDER REGISTRATION  \
# 0           HANDLE COMERCIO DE EQUIPAMENTOS MEDICOS LTDA
# 1           LABORLAB PRODUTOS PARA LABORATÓRIOS LTDA EPP
# 2                                 BLAU FARMACÊUTICA S.A.
# 3                                 BLAU FARMACÊUTICA S.A.
# 4      BIOMEDICAL EQUIPAMENTOS E PRODUTOS MÉDICO-CIRÚ...
# ...                                                  ...
# 97253                           LUMIRADX HEALTHCARE LTDA
# 97254             NS PRODUTOS E SISTEMAS DE HIGIENE LTDA
# 97255                    SS WHITE ARTIGOS DENTARIOS LTDA
# 97256               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
# 97257               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
#
#                                        MANUFACTURER_NAME  \
# 0                                      COOK INCORPORATED
# 1           LABORLAB PRODUTOS PARA LABORATÓRIOS LTDA EPP
# 2                                                    NaN
# 3                                 SURETEX LTD HEALTHCARE
# 4      BIOMEDICAL EQUIPAMENTOS E PRODUTOS MÉDICO-CIRÚ...
# ...                                                  ...
# 97253                         MICROPOINT BIOSCIENCE, INC
# 97254             NS PRODUTOS E SISTEMAS DE HIGIENE LTDA
# 97255                                                NaN
# 97256               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
# 97257               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
#
#                                          COMMERCIAL NAME  \
# 0         AGULHA PARA PUNÇÃO COM ACESSO PERCUTÂNEA RENAL
# 1                            PROTAL METODO COLORIMETRICO
# 2                                          PRESERV EXTRA
# 3                                          PRESERV EXTRA
# 4                                    CATETER DUPLO LUMEN
# ...                                                  ...
# 97253                        Cartucho de teste mLabs PCT
# 97254                                     Sete Sensações
# 97255  CAVITINE - FORRADOR DE CAVIDADES E VERNIZ PARA...
# 97256                              ALBUMINA BOVINA A 22%
# 97257  SORO ANTI-HUMANO (SORO ANTI-HUMANO POLIESPECIF...
#
#                                           TECHNICAL_NAME
# 0                                                Agulhas
# 1                                         PROTEÍNA TOTAL
# 2                               Preservativos Masculinos
# 3                               Preservativos Masculinos
# 4                                              Cateteres
# ...                                                  ...
# 97253                                PROCALCITONINA PCT
# 97254                                Lubrificante Intimo
# 97255                     Agente de Obturacao Provisoria
# 97256        IMUNOHEMATOLOGIA - REAGENTES COMPLEMENTARES
# 97257  IMUNOHEMATOLOGIA - RH-HR, KELL, KIDD, DUFFY - ...
#
# [96783 rows x 6 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (97258, 6)

# %%
len(grill['MANUFACTURER_NAME'].unique())
# Out:
# 11054

# %%
len(grill['COMMERCIAL NAME'].unique())
# Out:
# 76801

# %%
len(grill['TECHNICAL_NAME'].unique())
# Out:
# 2439

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text
def prep_translate(df, col):
    cached_en = {}
    unique_vals = df[col].unique()
    print("API Calls: ", len(unique_vals))
    for val in tqdm(unique_vals):
        cached_en[val] = translate_to_en(val)
    return cached_en


def update_cache(val):
    translation = translate_to_en(val)
    cached_en[val] = translation
    return val, translation

# %%
cached_en = prep_translate(grill, 'MANUFACTURER_NAME')
# Out:
# API Calls:  11054
#   6%|████▌                                                                         | 649/11054 [02:23<38:46,  4.47it/s]

# %%
cached_en2 = prep_translate(grill, 'TRADING NAME')
cached_en3 = prep_translate(grill, 'DESCRIPTION CND')

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 chunks = split_dataframe(grill, 1000)
#
# NameError: name 'split_dataframe' is not defined

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
