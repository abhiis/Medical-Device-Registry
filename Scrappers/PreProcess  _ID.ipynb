# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\ID'
os.chdir(source)
file = "ID Medical Device Register.xlsx"

# %%
payload = pd.read_excel(file)
payload.shape
# Out:
# (62736, 10)

# %%
cols = payload.columns
cols_en = [translate_to_en(x) for x in cols]
cols_en
# Out:
# ['Registration No.',
#  'Product/Device',
#  'Device Description',
#  'Category 1',
#  'Category 2',
#  'Category 3',
#  'Types',
#  'Local Registering Entity',
#  'Manufacturers',
#  'Unnamed: 9']

# %%
payload.columns = cols_en

# %%
grill = payload.sample(10)
grill
# Out:
#                                         Registration No.  \
# 54242  AKD 21603022455\nTerbit: 27-10-2021\nExpired: ...
# 35130  AKL 10402020585\nTerbit: 21-02-2020\nExpired: ...
# 18320  AKL 11501122366\nTerbit: 26-04-2021\nExpired: ...
# 27029  AKL 20403410075\nTerbit: 10-10-2020\nExpired: ...
# 50461  AKL 20305811005\nTerbit: 21-02-2018\nExpired: ...
# 61687  AKD 10903810368\nTerbit: 03-05-2018\nExpired: ...
# 36659  AKL 10102714064\nTerbit: 20-12-2019\nExpired: ...
# 24004  AKL 11403027677\nTerbit: 10-12-2020\nExpired: ...
# 45339  AKL 21302910474\nTerbit: 04-02-2019\nExpired: ...
# 9058   AKL 20306210031\nTerbit: 15-11-2021\nExpired: ...
#
#                                           Product/Device  \
# 54242  G-SHIELD Coverall\nPeralatan Bedah\nSurgical a...
# 35130  AMICO Compressed Gas Manifold\nPeralatan Anest...
# 18320  Q-MED X-RAY GRIDS\nPeralatan Radiologi Diagnos...
# 27029  SLE Adaptive Nasal CPAP Therapy System\nPerala...
# 50461  EUROIMMUN IIFT : ANA Mosaic 1A EUROPattern\nSi...
# 61687  AKINDO Folding Scoop Stretcher\nPeralatan Ruma...
# 36659  POINTE 180 II Chemistry Analyzer\nPeralatan La...
# 24004  APOTEK GENERIK Cooling Gel Sheet\nPeralatan Ke...
# 45339  ZENER Spinal System (1)\nPeralatan Ortopedi Pr...
# 9058   TOSOH ST AIA-PACK PSA II CALIBRATOR SET\nSiste...
#
#                                Device Description  \
# 54242                           G-SHIELD Coverall
# 35130               AMICO Compressed Gas Manifold
# 18320                           Q-MED X-RAY GRIDS
# 27029      SLE Adaptive Nasal CPAP Therapy System
# 50461  EUROIMMUN IIFT : ANA Mosaic 1A EUROPattern
# 61687              AKINDO Folding Scoop Stretcher
# 36659            POINTE 180 II Chemistry Analyzer
# 24004            APOTEK GENERIK Cooling Gel Sheet
# 45339                     ZENER Spinal System (1)
# 9058      TOSOH ST AIA-PACK PSA II CALIBRATOR SET
#
#                                               Category 1  \
# 54242                                    Peralatan Bedah
# 35130                      Peralatan Anestesi Pemantauan
# 18320                     Peralatan Radiologi Diagnostik
# 27029                       Peralatan Anestesi Terapetik
# 50461                            Sistem Tes Imunologikal
# 61687  Peralatan Rumah Sakit Umum dan Perorangan Lainnya
# 36659                      Peralatan Laboratorium Klinik
# 24004                Peralatan Kesehatan Fisik Terapetik
# 45339                       Peralatan Ortopedi Prostetik
# 9058               Sistem Tes Imunologikal Antigen Tumor
#
#                                               Category 2  \
# 54242                                  Surgical apparel.
# 35130                                Pressure regulator.
# 18320                                 Radiographic grid.
# 27029                   Noncontinuous ventilator (IPPB).
# 50461  Immunoglobulins A, G, M, D, and E immunologica...
# 61687                            Hand-carried stretcher.
# 36659  Colorimeter, photometer, or spectrophotometer ...
# 24004                                         Cold pack.
# 45339                        Pedicle screw spinal system
# 9058   Tumor-associated antigen immunological test sy...
#
#                         Category 3  \
# 54242  Non Elektromedik Non Steril
# 35130  Non Elektromedik Non Steril
# 18320  Non Elektromedik Non Steril
# 27029     Elektromedik Non Radiasi
# 50461           Invitro Diagnostik
# 61687  Non Elektromedik Non Steril
# 36659           Invitro Diagnostik
# 24004  Non Elektromedik Non Steril
# 45339  Non Elektromedik Non Steril
# 9058            Invitro Diagnostik
#
#                                                    Types  \
# 54242              All size\nKelas : 2\nKelas Resiko : B
# 35130             Terlampir\nKelas : 1\nKelas Resiko : A
# 18320             Terlampir\nKelas : 1\nKelas Resiko : A
# 27029    SLE 1000/Terlampir\nKelas : 2\nKelas Resiko : C
# 50461  Ref. No FC 1512-1003-1, FC 1512-1005-1, FC 151...
# 61687  AK 260 / Panjang Maksimum 205 cm, Panjang Mini...
# 36659  180 II Chemistry Analyzer\nKelas : 1\nKelas Re...
# 24004         Anak dan Bayi\nKelas : 1\nKelas Resiko : A
# 45339             Terlampir\nKelas : 2\nKelas Resiko : C
# 9058       Ref. No. 0025312\nKelas : 2\nKelas Resiko : C
#
#                                 Local Registering Entity  \
# 54242        GISTEX GARMEN INDONESIA\nJln. Braga No. 106
# 35130  PT. GLOBAL MEDIKA ENJINIRING\nRUKO CITRALAKE S...
# 18320  SRI INTAN PERKASA\nRUKO HARAPAN INDAH BLOK EN/...
# 27029  PT. IDS MEDICAL SYSTEMS INDONESIA\nGedung Wism...
# 50461  PT. INTI MAKMUR MEDITAMA\nJL. SULTAN ISKANDAR ...
# 61687  PT. ANUGRAH KARYA INDONESIA\nKp. Cibitung RT. ...
# 36659  PT. SEGARA HUSADA MANDIRI\nJl. Pegambiran No. 31A
# 24004  PT. MANDIRI NUGRAHA AJITUNGGAL\nJl. Mangga Dua...
# 45339  PT. ADHIRA MEDIKA PERSADA INTERNASIONAL\nRuko ...
# 9058            KARINDO ALKESTRON\nJL. TOMANG RAYA NO.17
#
#                                            Manufacturers Unnamed: 9
# 54242             PT. GISTEX GARMEN INDONESIA\nIndonesia        NaN
# 35130                          AMICO CORPORATION\nCanada        NaN
# 18320  SHANDONG DOUBLE EAGLE MEDICAL DEVICE CO., LTD....        NaN
# 27029                       SLE LIMITED.\nUnited Kingdom        NaN
# 50461  EUROIMMUN MEDIZINISCHE LABORDIAGNOSTIKA AG\nGe...        NaN
# 61687             PT. ANUGRAH KARYA INDONESIA\nIndonesia        NaN
# 36659  POINTE SCIENTIFIC, INC.\nUnited States\nMelalu...        NaN
# 24004  JINHUA JINGDI MEDICAL SUPPLIES CO., LTD.\nChin...        NaN
# 45339  CHANGZHOU WASTON MEDICAL APPLIANCE CO., LTD.\n...        NaN
# 9058   TOSOH AIA INC.\nJapan\nUntuk\nTOSOH CORPORATIO...        NaN

# %%
cols_i_want = ['START_VALIDITY',
'TRADE_END DATE',
 'MANUFACTURER ASSEMBLER','TRADING NAME','DESCRIPTION CND']

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#         START_VALIDITY TRADE_END DATE  \
# 0           2013-06-25            NaN
# 1           2007-07-06     2010-03-16
# 2           2021-12-31            NaN
# 3           2007-09-14            NaN
# 6           2021-12-31            NaN
# ...                ...            ...
# 1902023     2024-01-27            NaN
# 1902024     2024-01-27            NaN
# 1902025     2024-01-27            NaN
# 1902026     2024-01-27            NaN
# 1902027     2024-01-27            NaN
#
#                            MANUFACTURER ASSEMBLER  \
# 0                                    ID&CO S.R.L.
# 1        JOHNSON & JOHNSON MEDICAL HOLDING S.P.A.
# 2                                 BUERKI INNO MED
# 3                                     ACTIMEX SRL
# 6                                 BUERKI INNO MED
# ...                                           ...
# 1902023                          PAUL HARTMANN AG
# 1902024                          PAUL HARTMANN AG
# 1902025                          PAUL HARTMANN AG
# 1902026                       TAUMEDIPLAST S.R.L.
# 1902027                       TAUMEDIPLAST S.R.L.
#
#                                               TRADING NAME  \
# 0                                  PENNARELLI DERMOGRAFICI
# 1                                                VACUDRAIN
# 2        CANNULE IRRIGAZIONE/ASPIRAZIONE PER TECNICA BI...
# 3                                RINOCICLINA SPRAY  NASALE
# 6        CANNULE IRRIGAZIONE ASPIRAZIONE COASSIALI PLUR...
# ...                                                    ...
# 1902023                            COMBISET PER RADIOLOGIA
# 1902024                              COMBISET PER UROLOGIA
# 1902025                   COMBISET PER CHIRURGIA VASCOLARE
# 1902026  I-WASH STAT 250, STAZIONE PER LAVAGGIO OCULARE...
# 1902027  EWS, EYE WASH STATION IN ORANGE ABS BOX COMBISTAR
#
#                                            DESCRIPTION CND
# 0                                     MATITE DERMOGRAFICHE
# 1                  SISTEMI DI DRENAGGIO PERCUTANEO - ALTRI
# 2        CANNULE MONOUSO PER ASPIRAZIONE/IRRIGAZIONE IN...
# 3                         DISPOSITIVI NASOFARINGEI - ALTRI
# 6                    STRUMENTARIO PER OFTALMOLOGIA - ALTRO
# ...                                                    ...
# 1902023                                                NaN
# 1902024                                                NaN
# 1902025                                                NaN
# 1902026                                                NaN
# 1902027                                                NaN
#
# [1433017 rows x 5 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (1433017, 5)

# %%
len(grill['MANUFACTURER ASSEMBLER'].unique())
# Out:
# 22407

# %%
len(grill[''].unique())
# Out:
# 1236200

# %%
len(grill['DESCRIPTION CND'].unique())
# Out:
# 6910

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text
def prep_translate(df, col):
    cached_en = {}
    unique_vals = df[col].unique()
    print("API Calls: ", len(unique_vals))
    for val in tqdm(unique_vals):
        cached_en[val] = translate_to_en(val)
    return cached_en


def update_cache(val):
    translation = translate_to_en(val)
    cached_en[val] = translation
    return val, translation

# %%
cached_en = prep_translate(grill, 'MANUFACTURER ASSEMBLER')
# Out:
# API Calls:  22407

# %%
cached_en2 = prep_translate(grill, 'TRADING NAME')
cached_en3 = prep_translate(grill, 'DESCRIPTION CND')

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 chunks = split_dataframe(grill, 1000)
#
# NameError: name 'split_dataframe' is not defined

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
