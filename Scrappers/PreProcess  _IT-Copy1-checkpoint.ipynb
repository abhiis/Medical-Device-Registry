# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\IT'
os.chdir(source)
file = "elenco_dm_tutti_csv_formato_opendata_UltimaVersione.csv"
delimiter = ';'

# %%
payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
payload.shape
# Out:
# C:\Users\AbhishekSrivastava\AppData\Local\Temp\ipykernel_17472\2915228804.py:1: DtypeWarning: Columns (9,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   payload = pd.read_csv(file, delimiter=delimiter, encoding="latin")
# (1902028, 16)

# %%
cols = payload.columns
cols_en = [translate_to_en(x) for x in cols]
cols_en
# Out:
# ['TYPE',
#  'PROGRESSIVE_DM_ASS',
#  'FIRST_PUBLICATION_DATE',
#  'DM_REFERENCE',
#  'SIMILAR_DM_GROUP',
#  'REPERTORY REGISTRATION',
#  'START_VALIDITY',
#  'END_VALIDITY',
#  'MANUFACTURER ASSEMBLER',
#  'TAX ID CODE',
#  'PARTITA_IVA_VATNUMBER',
#  'CODE_CATALOGUE_FABBR_ASS',
#  'TRADING NAME',
#  'CND CLASSIFICATION',
#  'DESCRIPTION CND',
#  'TRADE_END DATE']

# %%
payload.columns = cols_en

# %%
grill = payload.sample(10)
grill
# Out:
#          TYPE  PROGRESSIVE_DM_ASS FIRST_PUBLICATION_DATE  DM_REFERENCE  \
# 958071      1             1546725             2017-04-11           NaN
# 854888      1             1436408             2016-07-14           NaN
# 447696      1              661059             2012-11-16           NaN
# 1797184     1             2455005             2023-07-25           NaN
# 891950      1             1477802             2016-10-08           NaN
# 1057846     1             1648909             2017-12-13           NaN
# 1578593     1             2210832             2022-02-17           NaN
# 30291       1               39326             2009-05-15           NaN
# 187765      1              209950             2009-05-26           NaN
# 1886480     2              124143             2019-02-27           NaN
#
#          SIMILAR_DM_GROUP REPERTORY REGISTRATION START_VALIDITY END_VALIDITY  \
# 958071            85407.0                      S     2017-04-11   9999-12-31
# 854888            77599.0                      N     2016-07-14   9999-12-31
# 447696            42824.0                      S     2012-11-16   9999-12-31
# 1797184          155829.0                      N     2023-07-25   9999-12-31
# 891950            80107.0                      S     2016-10-08   9999-12-31
# 1057846          129328.0                      S     2021-04-22   9999-12-31
# 1578593          139073.0                      N     2022-02-17   9999-12-31
# 30291               927.0                      S     2009-05-15   9999-12-31
# 187765            14661.0                      N     2009-05-26   9999-12-31
# 1886480               NaN                      N     2019-02-27   9999-12-31
#
#                                  MANUFACTURER ASSEMBLER  TAX ID CODE  \
# 958071                                      AESCULAP AG          NaN
# 854888   SANYMED S.A.S. DI VERNA VINCENZO E VERNA ELVIO  00408900686
# 447696                         KARL STORZ GMBH & CO. KG          NaN
# 1797184                                        ANTHOGYR          NaN
# 891950                                 AQ IMPLANTS GMBH          NaN
# 1057846                                MEDGAL SP. ZO.O.          NaN
# 1578593                                   DISPOTECH SRL  00672170149
# 30291                    PAJUNK GMBH MEDIZINTECHNOLOGIE          NaN
# 187765                      VITAMED MEDIZINTECHNIK GMBH          NaN
# 1886480                       APPLIED MEDICAL EUROPE BV          NaN
#
#         PARTITA_IVA_VATNUMBER CODE_CATALOGUE_FABBR_ASS  \
# 958071              812160059                   NK773K
# 854888            00408900686                 1LBUS035
# 447696            DE142931059                  26072BS
# 1797184           25605620442                  XT64060
# 891950            DE273954344                 60046017
# 1057846            5423227877               4-01-02-20
# 1578593           00672170149          SP400DISPOEST24
# 30291               000000000               1292-43-16
# 187765              235227278              90135-0F-XX
# 1886480          815780382B01                990003366
#
#                                               TRADING NAME CND CLASSIFICATION  \
# 958071              ISODUR TESTA DI PROTESI 12/14 40MM XXL      P090804050202
# 854888                          COLESTEROLO HDL DIRETTO LR          W01010215
# 447696                   KARL STORZ OPTICAL BIOPSY FORCEPS              L1299
# 1797184                        AXIOM IMPLANT X3 ¿6.4 x 6.5          P01020101
# 891950       REVISIO¿ RTM cone adapter, TiNb - Gr. 3-7 10¡          P09088003
# 1057846  Viti corticali autofilettanti Ã¿ 3,5 mm L=20 m...          P09120699
# 1578593          GHIACCIO SPRAY DISPO ICE 400ML CONF. 24PZ              M9001
# 30291                          GRASPING FORCEPS; CLAW-TYPE              L1899
# 187765   MINI CONTAINER PER STERILIZZAZIONE COPERCHIO N...          Z12011385
# 1886480                                KIT COLECISTI 3 BIS                NaN
#
#                                            DESCRIPTION CND TRADE_END DATE
# 958071   TESTE FEMORALI IN MATERIALE METALLICO PER PROT...            NaN
# 854888     COLESTEROLO HDL (LIPOPROTEINE AD ALTA DENSITA')            NaN
# 447696   STRUMENTARIO PLURIUSO PER CHIRURGIA MINI-INVAS...     2017-12-31
# 1797184                                   IMPIANTI DENTALI            NaN
# 891950      SPAZIATORI O DISTANZIATORI PER PROTESI DI ANCA            NaN
# 1057846  VITI PER OSTEOSINTESI E SINTESI TENDINEO-LEGAM...            NaN
# 1578593           DISPOSITIVI CRIOTERAPICI E TERMOTERAPICI            NaN
# 30291    STRUMENTARIO PLURIUSO PER ELETTROCHIRURGIA - A...            NaN
# 187765   STRUMENTAZIONE PER LAVAGGIO, DISINFEZIONE E ST...            NaN
# 1886480                                                NaN            NaN

# %%
cols_i_want = ['START_VALIDITY',
'TRADE_END DATE',
 'MANUFACTURER ASSEMBLER','TRADING NAME','DESCRIPTION CND']

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#         START_VALIDITY TRADE_END DATE  \
# 0           2013-06-25            NaN
# 1           2007-07-06     2010-03-16
# 2           2021-12-31            NaN
# 3           2007-09-14            NaN
# 6           2021-12-31            NaN
# ...                ...            ...
# 1902023     2024-01-27            NaN
# 1902024     2024-01-27            NaN
# 1902025     2024-01-27            NaN
# 1902026     2024-01-27            NaN
# 1902027     2024-01-27            NaN
#
#                            MANUFACTURER ASSEMBLER  \
# 0                                    ID&CO S.R.L.
# 1        JOHNSON & JOHNSON MEDICAL HOLDING S.P.A.
# 2                                 BUERKI INNO MED
# 3                                     ACTIMEX SRL
# 6                                 BUERKI INNO MED
# ...                                           ...
# 1902023                          PAUL HARTMANN AG
# 1902024                          PAUL HARTMANN AG
# 1902025                          PAUL HARTMANN AG
# 1902026                       TAUMEDIPLAST S.R.L.
# 1902027                       TAUMEDIPLAST S.R.L.
#
#                                               TRADING NAME  \
# 0                                  PENNARELLI DERMOGRAFICI
# 1                                                VACUDRAIN
# 2        CANNULE IRRIGAZIONE/ASPIRAZIONE PER TECNICA BI...
# 3                                RINOCICLINA SPRAY  NASALE
# 6        CANNULE IRRIGAZIONE ASPIRAZIONE COASSIALI PLUR...
# ...                                                    ...
# 1902023                            COMBISET PER RADIOLOGIA
# 1902024                              COMBISET PER UROLOGIA
# 1902025                   COMBISET PER CHIRURGIA VASCOLARE
# 1902026  I-WASH STAT 250, STAZIONE PER LAVAGGIO OCULARE...
# 1902027  EWS, EYE WASH STATION IN ORANGE ABS BOX COMBISTAR
#
#                                            DESCRIPTION CND
# 0                                     MATITE DERMOGRAFICHE
# 1                  SISTEMI DI DRENAGGIO PERCUTANEO - ALTRI
# 2        CANNULE MONOUSO PER ASPIRAZIONE/IRRIGAZIONE IN...
# 3                         DISPOSITIVI NASOFARINGEI - ALTRI
# 6                    STRUMENTARIO PER OFTALMOLOGIA - ALTRO
# ...                                                    ...
# 1902023                                                NaN
# 1902024                                                NaN
# 1902025                                                NaN
# 1902026                                                NaN
# 1902027                                                NaN
#
# [1433017 rows x 5 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (1433017, 5)

# %%
len(grill['MANUFACTURER ASSEMBLER'].unique())
# Out:
# 22407

# %%
len(grill['TRADING NAME'].unique())
# Out:
# 1236200

# %%
len(grill['DESCRIPTION CND'].unique())
# Out:
# 6910

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text
def prep_translate(df, col):
    cached_en = {}
    unique_vals = df[col].unique()
    print("API Calls: ", len(unique_vals))
    for val in tqdm(unique_vals):
        cached_en[val] = translate_to_en(val)
    return cached_en


def update_cache(val):
    translation = translate_to_en(val)
    cached_en[val] = translation
    return val, translation

# %%
cached_en = prep_translate(grill, 'MANUFACTURER ASSEMBLER')
# Out:
# API Calls:  22407
#   5%|████                                                                       | 1232/22407 [04:07<1:13:33,  4.80it/s]

# %%
cached_en2 = prep_translate(grill, 'TRADING NAME')
cached_en3 = prep_translate(grill, 'DESCRIPTION CND')

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 chunks = split_dataframe(grill, 1000)
#
# NameError: name 'split_dataframe' is not defined

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
