# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = "MDRv2 Datasets"
file = "\\ARTG 1991 - 02 -01-2024.xlsx"

# %%
payload = pd.read_excel(source+file)
payload.shape
# Out:
# (69876, 20)

# %%
payload.columns
# Out:
# Index(['ARTG ID', 'Sponsor Name', 'Company', 'GMDN (Code-Text)', 'Class',
#        'ARTG Category', 'Good Name', 'Therapeutic Type', 'Device Name',
#        'Approval Area', 'Conditions', 'Product Type', 'Start Date',
#        'Effective Date', 'Functional Description', 'Intended Purpose',
#        'Variant Information', 'Specific Conditions', 'Manufacturer Address',
#        'Manufacturer Country'],
#       dtype='object')

# %%
grill = payload.sample(10)
grill = grill.rename(columns = {'Device Name':'device','Company':'manufacturer',
                                'Sponsor Name':'company','Start Date':'start_date'})
grill['description'] = grill['Good Name']
grill['meta'] = grill['Intended Purpose'] + ";"+ grill['Functional Description']
grill['manufacturer'] =
# Out:
#        ARTG ID                                            Company  \
# 31872   261594              Meditech Systems Asia Pacific Pty Ltd
# 11451   337851                          B Braun Australia Pty Ltd
# 55107   139038                         Fujifilm Australia Pty Ltd
# 1429    390413                             Bard Australia Pty Ltd
# 56875   130381                           Becton Dickinson Pty Ltd
# 26000   288501  Johnson & Johnson Medical Pty Ltd t/a DePuy Sy...
# 49544   169906                       Ebos Group Australia Pty Ltd
# 5488    371756                        Advanced Biomedical Pty Ltd
# 4815    374984                                    HOSPECO PTY LTD
# 50474   164578                                  Orthology Pty Ltd
#
#                                       Manufacturer  \
# 31872                         Meditech Systems Ltd
# 11451             Intermedt Medizin & Technik GmbH
# 55107                         Fujifilm Corporation
# 1429                  Bard Peripheral Vascular Inc
# 56875                               J Sollner GmbH
# 26000                              Depuy (Ireland)
# 49544                        Eschmann Holdings Ltd
# 5488                TeDan Surgical Innovations LLC
# 4815   Lyncmed Medical Technology (Beijing) Co Ltd
# 50474                         Ortho Technology Inc
#
#                                         GMDN (Code-Text)      Class  \
# 31872    36306 - Cannula, nasal, carbon dioxide sampling    Class I
# 11451           36342 - Haemodialysis system fluid mixer  Class IIb
# 55107              35462 - Laryngoscope, flexible, video  Class IIa
# 1429       62076 - Intraosseous-access handpiece, biopsy  Class IIa
# 56875             44036 - Adaptor, catheter, intravenous  Class IIa
# 26000                                  48066 - Knee stem  Class IIb
# 49544                           12347 - Light, <specify>    Class I
# 5488   45182 - Retractor, general-purpose, self-retai...    Class I
# 4815   47176 - Vinyl examination/treatment glove, non...    Class I
# 50474                35812 - Explorer, dental, hand-held    Class I
#
#       ARTG Category                                          Good Name  \
# 31872       General  Meditech Systems Asia Pacific Pty Ltd - Cannul...
# 11451       General  B Braun Australia Pty Ltd - ECOMix - Haemodial...
# 55107       General  Fujifilm Australia Pty Ltd - Fujinon Electroni...
# 1429        General  Bard Australia Pty Ltd - Intraosseous-access h...
# 56875       General  Becton Dickinson Pty Ltd - Adaptor, catheter, ...
# 26000       General  Johnson & Johnson Medical Pty Ltd t/a DePuy Sy...
# 49544       General    Ebos Group Australia Pty Ltd - Light, <specify>
# 5488        General  Advanced Biomedical Pty Ltd - Retractor, gener...
# 4815        General  HOSPECO PTY LTD - Vinyl examination/treatment ...
# 50474       General    Orthology Pty Ltd - Explorer, dental, hand-held
#
#       Therapeutic Type                                             Device  \
# 31872   Medical Device            Cannula, nasal, carbon dioxide sampling
# 11451   Medical Device          ECOMix - Haemodialysis system fluid mixer
# 55107   Medical Device  Fujinon Electronic Video Endoscopy System - La...
# 1429    Medical Device              Intraosseous-access handpiece, biopsy
# 56875   Medical Device                     Adaptor, catheter, intravenous
# 26000   Medical Device                                          Knee stem
# 49544   Medical Device                                   Light, <specify>
# 5488    Medical Device         Retractor, general-purpose, self-retaining
# 4815    Medical Device    Vinyl examination/treatment glove, non-powdered
# 50474   Medical Device                        Explorer, dental, hand-held
#
#          Approval Area                                         Conditions  \
# 31872  Medical Devices  - The inclusion of the kind of device in the A...
# 11451  Medical Devices  - The inclusion of the kind of device in the A...
# 55107  Medical Devices  - The inclusion of the kind of device in the A...
# 1429   Medical Devices  - The inclusion of the kind of device in the A...
# 56875  Medical Devices  - The inclusion of the kind of device in the A...
# 26000  Medical Devices  - The inclusion of the kind of device in the A...
# 49544  Medical Devices  - The inclusion of the kind of device in the A...
# 5488   Medical Devices  - The inclusion of the kind of device in the A...
# 4815   Medical Devices  - The inclusion of the kind of device in the A...
# 50474  Medical Devices  - The inclusion of the kind of device in the A...
#
#                 Product Type Start Date Effective Date Functional Description  \
# 31872  Single Device Product 2015-10-21     2015-10-21                    NaN
# 11451  Medical device system 2020-06-15     2020-06-15                    NaN
# 55107  Medical device system 2007-05-21     2007-05-21                    NaN
# 1429   Single Device Product 2022-06-15     2022-06-15                    NaN
# 56875  Single Device Product 2006-08-17     2006-08-17                    NaN
# 26000  Single Device Product 2017-05-02     2017-05-02                    NaN
# 49544  Single Device Product 2010-03-16     2010-03-16                    NaN
# 5488   Single Device Product 2021-07-28     2021-07-28                    NaN
# 4815   Single Device Product 2021-09-21     2021-09-21                    NaN
# 50474  Single Device Product 2009-08-25     2009-08-25                    NaN
#
#                                         Intended Purpose Variant Information  \
# 31872  Device to allow sampling of CO2 via nasal cavi...                 NaN
# 11451             Dialysis concentrate production system                 NaN
# 55107  This is a medical Endoscope for the larynx.  I...                 NaN
# 1429   A handheld, battery-powered, reusable bone dri...                 NaN
# 56875       Used to secure good IV catheter connections.                 NaN
# 26000  A device intended to provide additional stabil...                 NaN
# 49544  A light that is used in connection with the pa...                 NaN
# 5488   A self-locking instrument used to temporarily ...                 NaN
# 4815   Single use disposable patient examination Viny...                 NaN
# 50474  A hand-held dental instrument with a working e...                 NaN
#
#       Specific Conditions                               Manufacturer Address  \
# 31872                 NaN  Shrublands Estate Sherstock Shaftesbury Dorset...
# 11451                 NaN     Gewerbestrasse Sued 13, Ostrhaudefehn, D-26842
# 55107                 NaN  26-30 Nishiazabu 2 Chome, MINATO KU TOKYO, 106...
# 1429                  NaN             1625 West 3rd Street, Tempe, AZ, 85281
# 56875                 NaN  Industriestrasse 28, D-94469 Deggendorf, GERMA...
# 26000                 NaN                  Loughbeg Ringaskiddy, COUNTY CORK
# 49544                 NaN          Peter Road, Lancing, West Sussex, BN158TJ
# 5488                  NaN  12615 W Airport Boulevard Suite 200, Sugar Lan...
# 4815                  NaN  Room 119 No 1111 South Huihe Road, Chaoyang Di...
# 50474                 NaN  17401 Commerce Park Boulevard, Tampa, Florida,...
#
#            Manufacturer Country
# 31872            United Kingdom
# 11451                   Germany
# 55107                     Japan
# 1429   United States Of America
# 56875                   Germany
# 26000                   Ireland
# 49544            United Kingdom
# 5488   United States Of America
# 4815                      China
# 50474  United States Of America

# %%
cols_i_want = ['DT_PUB_REGISTRO_CADASTRO',
'VALIDITY REGISTRATION REGISTRATION','REGISTRATION HOLDER REGISTRATION',
 'MANUFACTURER_NAME','COMMERCIAL NAME','TECHNICAL_NAME']

# %%
grill = payload[cols_i_want]

# %%
grill.drop_duplicates()
# Out:
#       DT_PUB_REGISTRO_CADASTRO VALIDITY REGISTRATION REGISTRATION  \
# 0                   09/05/2000                            VIGENTE
# 1                   29/02/1996                            VIGENTE
# 2                   26/05/2000                         26/05/2025
# 3                   26/05/2000                         26/05/2025
# 4                   11/03/1999                         01/03/2024
# ...                        ...                                ...
# 97253               05/09/2016                            VIGENTE
# 97254               01/10/2020                            VIGENTE
# 97255               28/05/1999                            VIGENTE
# 97256               25/08/1994                            VIGENTE
# 97257               04/08/1994                         01/08/2024
#
#                         REGISTRATION HOLDER REGISTRATION  \
# 0           HANDLE COMERCIO DE EQUIPAMENTOS MEDICOS LTDA
# 1           LABORLAB PRODUTOS PARA LABORATÓRIOS LTDA EPP
# 2                                 BLAU FARMACÊUTICA S.A.
# 3                                 BLAU FARMACÊUTICA S.A.
# 4      BIOMEDICAL EQUIPAMENTOS E PRODUTOS MÉDICO-CIRÚ...
# ...                                                  ...
# 97253                           LUMIRADX HEALTHCARE LTDA
# 97254             NS PRODUTOS E SISTEMAS DE HIGIENE LTDA
# 97255                    SS WHITE ARTIGOS DENTARIOS LTDA
# 97256               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
# 97257               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
#
#                                        MANUFACTURER_NAME  \
# 0                                      COOK INCORPORATED
# 1           LABORLAB PRODUTOS PARA LABORATÓRIOS LTDA EPP
# 2                                                    NaN
# 3                                 SURETEX LTD HEALTHCARE
# 4      BIOMEDICAL EQUIPAMENTOS E PRODUTOS MÉDICO-CIRÚ...
# ...                                                  ...
# 97253                         MICROPOINT BIOSCIENCE, INC
# 97254             NS PRODUTOS E SISTEMAS DE HIGIENE LTDA
# 97255                                                NaN
# 97256               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
# 97257               PROTHEMO PRODUTOS HEMOTERAPICOS LTDA
#
#                                          COMMERCIAL NAME  \
# 0         AGULHA PARA PUNÇÃO COM ACESSO PERCUTÂNEA RENAL
# 1                            PROTAL METODO COLORIMETRICO
# 2                                          PRESERV EXTRA
# 3                                          PRESERV EXTRA
# 4                                    CATETER DUPLO LUMEN
# ...                                                  ...
# 97253                        Cartucho de teste mLabs PCT
# 97254                                     Sete Sensações
# 97255  CAVITINE - FORRADOR DE CAVIDADES E VERNIZ PARA...
# 97256                              ALBUMINA BOVINA A 22%
# 97257  SORO ANTI-HUMANO (SORO ANTI-HUMANO POLIESPECIF...
#
#                                           TECHNICAL_NAME
# 0                                                Agulhas
# 1                                         PROTEÍNA TOTAL
# 2                               Preservativos Masculinos
# 3                               Preservativos Masculinos
# 4                                              Cateteres
# ...                                                  ...
# 97253                                PROCALCITONINA PCT
# 97254                                Lubrificante Intimo
# 97255                     Agente de Obturacao Provisoria
# 97256        IMUNOHEMATOLOGIA - REAGENTES COMPLEMENTARES
# 97257  IMUNOHEMATOLOGIA - RH-HR, KELL, KIDD, DUFFY - ...
#
# [96783 rows x 6 columns]

# %%
grill = grill.drop_duplicates()

# %%
grill.shape
# Out:
# (97258, 6)

# %%
len(grill['MANUFACTURER_NAME'].unique())
# Out:
# 11054

# %%
len(grill['COMMERCIAL NAME'].unique())
# Out:
# 76801

# %%
len(grill['TECHNICAL_NAME'].unique())
# Out:
# 2439

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text
def prep_translate(df, col):
    cached_en = {}
    unique_vals = df[col].unique()
    print("API Calls: ", len(unique_vals))
    for val in tqdm(unique_vals):
        cached_en[val] = translate_to_en(val)
    return cached_en


def update_cache(val):
    translation = translate_to_en(val)
    cached_en[val] = translation
    return val, translation

# %%
cached_en = prep_translate(grill, 'MANUFACTURER_NAME')
# Out:
# API Calls:  11054
#   6%|████▌                                                                         | 649/11054 [02:23<38:46,  4.47it/s]

# %%
cached_en2 = prep_translate(grill, 'TRADING NAME')
cached_en3 = prep_translate(grill, 'DESCRIPTION CND')

# %%
chunks = split_dataframe(grill, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 chunks = split_dataframe(grill, 1000)
#
# NameError: name 'split_dataframe' is not defined

# %%
for chunk in chunks:
    print(chunk.shape)
# Out:
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (1000, 10)
# (560, 10)

# %%
chunks[0].head(2)
# Out:
#    product_brand                product_holder country_holder_product  \
# 0  APOGEE SYSTEM  American Medical Systems Inc     [US] UNITED STATES
# 4        MONARC   American Medical Systems Inc     [US] UNITED STATES
#
#               manufacturer_name manufacturer_country manufacturer_address  \
# 0  American Medical Systems Inc   [US] UNITED STATES      10700 Bren Rd W
# 4  American Medical Systems Inc   [US] UNITED STATES    10700 Bren Rd W\n
#
#   certificate_issue_date certificate_valid_date  \
# 0             2009-03-12             2024-03-12
# 4             2009-03-12             2024-03-12
#
#                                 generic_product_name  \
# 0                            APOGEE  (APOGEE SYSTEM)
# 4  MONARC (MONARC SUBFASCIAL HAMMOCK INCONTINENCI...
#
#                                                 usos
# 0  Reparacion de la cupulavaginal y del prolapso ...
# 4                             Incontinencia urinaria

# %%
## Translate one by one

# %%
cols_to_translate = ['product_brand', 'product_holder', 'country_holder_product',
       'manufacturer_name', 'manufacturer_country', 'manufacturer_address',
       'generic_product_name', 'usos']
cols_to_translate
# Out:
# ['product_brand',
#  'product_holder',
#  'country_holder_product',
#  'manufacturer_name',
#  'manufacturer_country',
#  'manufacturer_address',
#  'generic_product_name',
#  'usos']

# %%
from googletrans import Translator
translator = Translator()
from functools import lru_cache

@lru_cache(maxsize=None)
def translate_to_en(text):
    if pd.notna(text) and isinstance(text, str):
        translated_text = translator.translate(str(text), dest='en').text
        return translated_text
    else:
        return text

# %%
len(chunks[0]['product_brand'].unique())
# Out:
# 243

# %%
len(chunks[0]['certificate_issue_date'].unique())
# Out:
# 140

# %%
translated_chunks = []

# %%
cols_to_translate
# Out:
# (['product_brand',
#   'product_holder',
#   'country_holder_product',
#   'manufacturer_name',
#   'manufacturer_country',
#   'manufacturer_address',
#   'generic_product_name',
#   'usos'],)

# %%
import time

# %%
for i, chunk in enumerate(chunks):
        print(f"Translating chunk: {i}")
        _s = time.time()
        translated_chunk = chunk.copy()
        for col in cols_to_translate:
            print(col)
            translated_chunk[col] = translated_chunk[col].map(lambda x: translate_to_en(x))
        translated_chunks.append(translated_chunk)
        _e = time.time()
        print(f"Time Elasped: {round(_e - _s, 2)} seconds.")
# Out:
# Translating chunk: 0
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 537.25 seconds.
# Translating chunk: 1
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 485.51 seconds.
# Translating chunk: 2
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.66 seconds.
# Translating chunk: 3
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 570.66 seconds.
# Translating chunk: 4
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 519.77 seconds.
# Translating chunk: 5
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 628.22 seconds.
# Translating chunk: 6
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 545.24 seconds.
# Translating chunk: 7
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 610.38 seconds.
# Translating chunk: 8
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 384.83 seconds.
# Translating chunk: 9
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 441.46 seconds.
# Translating chunk: 10
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 466.82 seconds.
# Translating chunk: 11
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 455.24 seconds.
# Translating chunk: 12
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 500.31 seconds.
# Translating chunk: 13
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 413.72 seconds.
# Translating chunk: 14
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 501.69 seconds.
# Translating chunk: 15
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 418.11 seconds.
# Translating chunk: 16
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.43 seconds.
# Translating chunk: 17
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 541.65 seconds.
# Translating chunk: 18
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 402.66 seconds.
# Translating chunk: 19
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.6 seconds.
# Translating chunk: 20
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 480.69 seconds.
# Translating chunk: 21
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 499.77 seconds.
# Translating chunk: 22
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 440.54 seconds.
# Translating chunk: 23
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 461.76 seconds.
# Translating chunk: 24
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 462.75 seconds.
# Translating chunk: 25
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 369.66 seconds.
# Translating chunk: 26
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 429.13 seconds.
# Translating chunk: 27
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.63 seconds.
# Translating chunk: 28
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 346.34 seconds.
# Translating chunk: 29
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 486.59 seconds.
# Translating chunk: 30
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 349.49 seconds.
# Translating chunk: 31
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.71 seconds.
# Translating chunk: 32
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 397.16 seconds.
# Translating chunk: 33
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 505.6 seconds.
# Translating chunk: 34
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.8 seconds.
# Translating chunk: 35
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 400.42 seconds.
# Translating chunk: 36
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 422.27 seconds.
# Translating chunk: 37
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 401.45 seconds.
# Translating chunk: 38
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 515.95 seconds.
# Translating chunk: 39
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 388.26 seconds.
# Translating chunk: 40
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 404.25 seconds.
# Translating chunk: 41
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 367.5 seconds.
# Translating chunk: 42
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 406.11 seconds.
# Translating chunk: 43
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 353.36 seconds.
# Translating chunk: 44
# product_brand
# product_holder
# country_holder_product
# manufacturer_name
# manufacturer_country
# manufacturer_address
# generic_product_name
# usos
# Time Elasped: 249.05 seconds.

# %%
len(translated_chunks)
# Out:
# 45

# %%
ec = pd.concat(translated_chunks)
ec.to_excel("EC MDR.xlsx")
