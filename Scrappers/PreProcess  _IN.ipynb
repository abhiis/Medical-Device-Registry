# %%
import pandas as pd, numpy as np
import os
from glob import glob as g

# %%
def split_dataframe(df, length):
    # List to hold the split DataFrames
    split_dfs = []
    
    # Calculate the number of splits needed
    num_splits = len(df) // length + (1 if len(df) % length != 0 else 0)
    
    for i in range(num_splits):
        # Calculate start and end indices for the current split
        start_idx = i * length
        end_idx = start_idx + length
        
        # Slice the DataFrame and add it to the list
        split_dfs.append(df.iloc[start_idx:end_idx])
    print(f"Created {len(split_dfs)} chunks.")
    return split_dfs

# %%
## set source 
source = r'C:\Users\AbhishekSrivastava\Desktop\Workflow\Python\Dev\Medical Devices Registry\MDR Scripts\CDSCO IN'
file = "\CDSCO_IN - Approved Medical Devices 4Jan24.xlsx"

# %%
payload = pd.read_excel(source+file)
payload.shape
# Out:
# (10954, 7)

# %%
payload['S. No.'].unique()
# Out:
# array([    1,     2,     3, ..., 10952, 10953, 10954], dtype=int64)

# %%
cols = payload.columns
# cols_en = [translate_to_en(x) for x in cols]
# cols_en
cols
# Out:
# Index(['Unnamed: 0', 'S. No.', 'License Number', 'License Holder Name',
#        'Device Name(Brand Name)-Intended Use', 'Approving Authority',
#        'Device Class'],
#       dtype='object')

# %%
grill = payload.sample(3)
grill
# Out:
#       Unnamed: 0  S. No.       License Number  \
# 3185          85    3186   IMP/MD/2019/000182
# 787           87     788  IMP/IVD/2020/000097
# 529           29     530  IMP/IVD/2019/000376
#
#                                     License Holder Name  \
# 3185                  Johnson & Johnson Private Limited
# 787            ANALYTICAL AUTOMATION ( INDIA) PVT. LTD.
# 529   Beckman Coulter India Private Limited Hisaria ...
#
#                    Device Name(Brand Name)-Intended Use Approving Authority  \
# 3185  Endoscopic Applicator(SURGICEL Endoscopic Appl...               CDSCO
# 787   Cleaner(HC500 Cleaner, HC300 Cleaner)-Cleaner ...               CDSCO
# 529   Access PCT (Reagent Pack)(Access PCT (Reagent ...               CDSCO
#
#      Device Class
# 3185      Class B
# 787       Class B
# 529       Class B

# %%
# Regular expression pattern to extract Device Name, Brand Name, and Intended Use
pattern = r'(.+?)\((.+?)\)-(.+),'

# %%
(.+?)\((.+?)\)-(.+?)

# %%
chunk = payload[['S. No.','Device Name(Brand Name)-Intended Use']]
chunk
# Out:
#        S. No.               Device Name(Brand Name)-Intended Use
# 0           1  Urethral Catheter(GPC Urethral Catheter)-It is...
# 1           2  Natural Rubber Latex Male Condoms(ULINZI - For...
# 2           3  25-OH VITAMIN D ELISA-The Product is intended ...
# 3           4  ENZYMATIC ASSAY FOR THE QUANTITATIVE DETERMINA...
# 4           5  Surgical Suture(Dynalon)-Use in general soft t...
# ...       ...                                                ...
# 10949   10950  HIV Gen.4 Microwell ELISA(VDx)-HIV Gen. 4 Micr...
# 10950   10951  Locking Bolts 7.5mm Cannulated (Self Tapping)(...
# 10951   10952  Total Hip Replacement System(Pl refer Accessor...
# 10952   10953  ADHESIVE DRESSING BANDAGES FABRIC(CERDAK)-Exud...
# 10953   10954  Filariasis IgG/IgM Rapid Test (TRUSTline)-The ...
#
# [10954 rows x 2 columns]

# %%
# Original pattern with capturing groups
pattern = r'(.+?)\((.+?)\)-(.+?)(?=(\.,|$))'

# Modified pattern for splitting - use non-capturing groups (?:...) for parts you don't want to remove
split_pattern = r'(?:.+?\(.+?\)-.+?'
collect = []
for idx, row in chunk.iterrows():
    
    products = row['Device Name(Brand Name)-Intended Use']
    #rint("Original String:", products)
    
    # Find all matches
    matches = re.findall(pattern, products)
    #rint("Matches:", matches)
    #rint(len(matches))
    for match in matches:
        new_row = []
        device_name = match[0]
        brand_name = match[1]
        use = match[2]
        new_row.append(row['S. No.'])
        new_row.append(device_name)
        new_row.append(brand_name)
        new_row.append(use)
        collect.append(new_row)
        
        
    #rint("$$$$$$$$$$$$$$$$$$$$$$$$$")

# %%
export = pd.DataFrame(collect)
export.columns = ['S. No.','Device Name','Brand Name','Use']
export
# Out:
#        S. No.                                        Device Name  \
# 0           1                                  Urethral Catheter
# 1           1  .,Chest/Thoracic Drainage Catheter-It is used ...
# 2           1                                .,IV Flow Regulator
# 3           1                                  .,IV Infusion Set
# 4           1                              .,Yankaur Suction Set
# ...       ...                                                ...
# 49378   10951                                      .,Shaft Screw
# 49379   10951                   .,DCS Barrel Double Angled Plate
# 49380   10952                       Total Hip Replacement System
# 49381   10953                  ADHESIVE DRESSING BANDAGES FABRIC
# 49382   10954                     Filariasis IgG/IgM Rapid Test
#
#                                    Brand Name  \
# 0                       GPC Urethral Catheter
# 1                  GPC Foley Balloon Catheter
# 2                       GPC IV Flow Regulator
# 3                         GPC IV Infusion Set
# 4                     GPC Yankaur Suction Set
# ...                                       ...
# 49378                         GPC Shaft Screw
# 49379      GPC DCS Barrel Double Angled Plate
# 49380  Pl refer Accessories/Component section
# 49381                                  CERDAK
# 49382                               TRUSTline
#
#                                                      Use
# 0      It is used for urine drainage,Suction Catheter...
# 1      It is a urinary tract catheter used for short ...
# 2      It is used to deliver accurate volume of IV fl...
# 3      The Infusion Sets are used only for gravity fe...
# 4      It is used for removal of secretion and blood ...
# ...                                                  ...
# 49378  Used for attachment of implants to bone, bone ...
# 49379  Used to immobilize fractured segments,DHS Barr...
# 49380  Total hip arthroplasty is intended to provide ...
# 49381  Exudate Absorption Wound dressing, Bacteroio s...
# 49382  The TRUSTline Filariasis IgG/IgM Rapid Test is...
#
# [49383 rows x 4 columns]

# %%
export['Device Name'] = export['Device Name'].map(lambda x: x.replace(".,", ""))

# %%
export['Brand Name'] = export['Brand Name'].map(lambda x: x.replace(".,", ""))

# %%
export['Use'] = export['Use'].map(lambda x: x.replace(".,", ""))

# %%
export
# Out:
#        S. No.                                        Device Name  \
# 0           1                                  Urethral Catheter
# 1           1  Chest/Thoracic Drainage Catheter-It is used fo...
# 2           1                                  IV Flow Regulator
# 3           1                                    IV Infusion Set
# 4           1                                Yankaur Suction Set
# ...       ...                                                ...
# 49378   10951                                        Shaft Screw
# 49379   10951                     DCS Barrel Double Angled Plate
# 49380   10952                       Total Hip Replacement System
# 49381   10953                  ADHESIVE DRESSING BANDAGES FABRIC
# 49382   10954                     Filariasis IgG/IgM Rapid Test
#
#                                    Brand Name  \
# 0                       GPC Urethral Catheter
# 1                  GPC Foley Balloon Catheter
# 2                       GPC IV Flow Regulator
# 3                         GPC IV Infusion Set
# 4                     GPC Yankaur Suction Set
# ...                                       ...
# 49378                         GPC Shaft Screw
# 49379      GPC DCS Barrel Double Angled Plate
# 49380  Pl refer Accessories/Component section
# 49381                                  CERDAK
# 49382                               TRUSTline
#
#                                                      Use
# 0      It is used for urine drainage,Suction Catheter...
# 1      It is a urinary tract catheter used for short ...
# 2      It is used to deliver accurate volume of IV fl...
# 3      The Infusion Sets are used only for gravity fe...
# 4      It is used for removal of secretion and blood ...
# ...                                                  ...
# 49378  Used for attachment of implants to bone, bone ...
# 49379  Used to immobilize fractured segments,DHS Barr...
# 49380  Total hip arthroplasty is intended to provide ...
# 49381  Exudate Absorption Wound dressing, Bacteroio s...
# 49382  The TRUSTline Filariasis IgG/IgM Rapid Test is...
#
# [49383 rows x 4 columns]

# %%
del payload['Unnamed: 0']
payload
# Out:
#        S. No. License Number  \
# 0           1    02/SCof2018
# 1           2     03-13-0966
# 2           3           0499
# 3           4           0623
# 4           5       13/28/17
# ...       ...            ...
# 10949   10950    S0079/15/MB
# 10950   10951     SC/02/2018
# 10951   10952     TN00002456
# 10952   10953     TN00002473
# 10953   10954     TN00003795
#
#                                      License Holder Name  \
# 0                                    GPC Medical Limited
# 1                                 TTK Healthcare Limited
# 2      QUALPRO DIAGNOSTICS A DIVISION OF TULIP DIAGNO...
# 3      CORAL CLINICAL SYSTEMS A DIVISION OF TULIP DIA...
# 4                       Dynamic Techno Medicals Pvt. Ltd
# ...                                                  ...
# 10949               VANGUARD DIAGNOSTICS PRIVATE LIMITED
# 10950                                GPC Medical Limited
# 10951            TTK HEALTHCARE LIMITED (ORTHO DIVISION)
# 10952                          CARBORUNDUM UNIVERSAL LTD
# 10953                        Athenese-Dx Private Limited
#
#                     Device Name(Brand Name)-Intended Use  \
# 0      Urethral Catheter(GPC Urethral Catheter)-It is...
# 1      Natural Rubber Latex Male Condoms(ULINZI - For...
# 2      25-OH VITAMIN D ELISA-The Product is intended ...
# 3      ENZYMATIC ASSAY FOR THE QUANTITATIVE DETERMINA...
# 4      Surgical Suture(Dynalon)-Use in general soft t...
# ...                                                  ...
# 10949  HIV Gen.4 Microwell ELISA(VDx)-HIV Gen. 4 Micr...
# 10950  Locking Bolts 7.5mm Cannulated (Self Tapping)(...
# 10951  Total Hip Replacement System(Pl refer Accessor...
# 10952  ADHESIVE DRESSING BANDAGES FABRIC(CERDAK)-Exud...
# 10953  Filariasis IgG/IgM Rapid Test (TRUSTline)-The ...
#
#                                      Approving Authority Device Class
# 0                                          Uttar Pradesh      Class B
# 1      Central Drug Standard Control Organisation, So...      Class C
# 2                                                    Goa      Class B
# 3                                                    Goa      Class B
# 4      Central Drug Standard Control Organisation, So...      Class C
# ...                                                  ...          ...
# 10949                       CDSCO -North Zone, Ghaziabad      Class D
# 10950                       CDSCO -North Zone, Ghaziabad      Class C
# 10951  Central Drug Standard Control Organisation, So...      Class C
# 10952  Central Drug Standard Control Organisation, So...      Class C
# 10953                                         Tamil Nadu      Class B
#
# [10954 rows x 6 columns]

# %%
cdsco_in = payload.merge(export)
cdsco_in
# Out:
#        S. No. License Number                      License Holder Name  \
# 0           1    02/SCof2018                      GPC Medical Limited
# 1           1    02/SCof2018                      GPC Medical Limited
# 2           1    02/SCof2018                      GPC Medical Limited
# 3           1    02/SCof2018                      GPC Medical Limited
# 4           1    02/SCof2018                      GPC Medical Limited
# ...       ...            ...                                      ...
# 49378   10951     SC/02/2018                      GPC Medical Limited
# 49379   10951     SC/02/2018                      GPC Medical Limited
# 49380   10952     TN00002456  TTK HEALTHCARE LIMITED (ORTHO DIVISION)
# 49381   10953     TN00002473                CARBORUNDUM UNIVERSAL LTD
# 49382   10954     TN00003795              Athenese-Dx Private Limited
#
#                     Device Name(Brand Name)-Intended Use  \
# 0      Urethral Catheter(GPC Urethral Catheter)-It is...
# 1      Urethral Catheter(GPC Urethral Catheter)-It is...
# 2      Urethral Catheter(GPC Urethral Catheter)-It is...
# 3      Urethral Catheter(GPC Urethral Catheter)-It is...
# 4      Urethral Catheter(GPC Urethral Catheter)-It is...
# ...                                                  ...
# 49378  Locking Bolts 7.5mm Cannulated (Self Tapping)(...
# 49379  Locking Bolts 7.5mm Cannulated (Self Tapping)(...
# 49380  Total Hip Replacement System(Pl refer Accessor...
# 49381  ADHESIVE DRESSING BANDAGES FABRIC(CERDAK)-Exud...
# 49382  Filariasis IgG/IgM Rapid Test (TRUSTline)-The ...
#
#                                      Approving Authority Device Class  \
# 0                                          Uttar Pradesh      Class B
# 1                                          Uttar Pradesh      Class B
# 2                                          Uttar Pradesh      Class B
# 3                                          Uttar Pradesh      Class B
# 4                                          Uttar Pradesh      Class B
# ...                                                  ...          ...
# 49378                       CDSCO -North Zone, Ghaziabad      Class C
# 49379                       CDSCO -North Zone, Ghaziabad      Class C
# 49380  Central Drug Standard Control Organisation, So...      Class C
# 49381  Central Drug Standard Control Organisation, So...      Class C
# 49382                                         Tamil Nadu      Class B
#
#                                              Device Name  \
# 0                                      Urethral Catheter
# 1      Chest/Thoracic Drainage Catheter-It is used fo...
# 2                                      IV Flow Regulator
# 3                                        IV Infusion Set
# 4                                    Yankaur Suction Set
# ...                                                  ...
# 49378                                        Shaft Screw
# 49379                     DCS Barrel Double Angled Plate
# 49380                       Total Hip Replacement System
# 49381                  ADHESIVE DRESSING BANDAGES FABRIC
# 49382                     Filariasis IgG/IgM Rapid Test
#
#                                    Brand Name  \
# 0                       GPC Urethral Catheter
# 1                  GPC Foley Balloon Catheter
# 2                       GPC IV Flow Regulator
# 3                         GPC IV Infusion Set
# 4                     GPC Yankaur Suction Set
# ...                                       ...
# 49378                         GPC Shaft Screw
# 49379      GPC DCS Barrel Double Angled Plate
# 49380  Pl refer Accessories/Component section
# 49381                                  CERDAK
# 49382                               TRUSTline
#
#                                                      Use
# 0      It is used for urine drainage,Suction Catheter...
# 1      It is a urinary tract catheter used for short ...
# 2      It is used to deliver accurate volume of IV fl...
# 3      The Infusion Sets are used only for gravity fe...
# 4      It is used for removal of secretion and blood ...
# ...                                                  ...
# 49378  Used for attachment of implants to bone, bone ...
# 49379  Used to immobilize fractured segments,DHS Barr...
# 49380  Total hip arthroplasty is intended to provide ...
# 49381  Exudate Absorption Wound dressing, Bacteroio s...
# 49382  The TRUSTline Filariasis IgG/IgM Rapid Test is...
#
# [49383 rows x 9 columns]

# %%
cdsco_in.to_excel("CDSCO IN.xlsx")

# %%
# Extract the components into new columns
grill[['Device Name', 'Brand Name', 'Intended Use']] = grill['Device Name(Brand Name)-Intended Use'].str.extract(pattern)

# %%
grill
# Out:
#        Unnamed: 0  S. No.      License Number  \
# 4124           24    4125  IMP/MD/2020/000507
# 10803           3   10804  MFG/MD/2023/000986
# 10227          27   10228  MFG/MD/2023/000499
#
#                             License Holder Name  \
# 4124         Mani Medical India Private Limited
# 10803      SURGILIFE MEDICAL DEVICES PVT. LTD.,
# 10227  XCELLANCE MEDICAL TECHNOLOGIES PVT. LTD.
#
#                     Device Name(Brand Name)-Intended Use  Approving Authority  \
# 4124   Disposable Skin Stapler(Manipler)-To be used f...                CDSCO
# 10803  COTTON GRUDGES,GAUZE & BANDAGES(LIFEMED, SMDPL...  East Delhi Division
# 10227  Suction and Irrigation Pump(Shalya Aquaflow)-S...       Kokan Division
#
#       Device Class                      Device Name       Brand Name  \
# 4124       Class B          Disposable Skin Stapler         Manipler
# 10803      Class B  COTTON GRUDGES,GAUZE & BANDAGES   LIFEMED, SMDPL
# 10227      Class B      Suction and Irrigation Pump  Shalya Aquaflow
#
#                                             Intended Use
# 4124   To be used for skin suture in general surgery ...
# 10803  A strip of fabric used especially to cover, dr...
# 10227  Shalya Aquaflow Suction Irrigation Pump is use...

# %%
import re
# Step 1: Split the column values into separate rows
# Split by comma and stack the result to create a new row for each entry
s = grill['Device Name(Brand Name)-Intended Use'].str.split(',\s*', expand=True).stack().reset_index(level=1, drop=True)

# Create a new DataFrame from the stacked Series
df_expanded = pd.DataFrame(s, columns=['Expanded'])

# Step 2: Extract Device Name, Brand Name, and Intended Use into new columns
pattern = r'\'?(.+?)\((.+?)\)-(.+?)\'?'
df_final = df_expanded['Expanded'].str.extract(pattern, flags=re.IGNORECASE)
df_final.columns = ['Device Name', 'Brand Name', 'Intended Use']

print(df_final)
# Out:
#                         Device Name       Brand Name Intended Use
# 4124        Disposable Skin Stapler         Manipler            T
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10227   Suction and Irrigation Pump  Shalya Aquaflow            S
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227               CO2 Insufflator   Shalya Endojet            C
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227  Medical Ceiling Supply Units     Shalya Orbit            F
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN

# %%
df_final
# Out:
#                         Device Name       Brand Name Intended Use
# 4124        Disposable Skin Stapler         Manipler            T
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10803                           NaN              NaN          NaN
# 10227   Suction and Irrigation Pump  Shalya Aquaflow            S
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227               CO2 Insufflator   Shalya Endojet            C
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227  Medical Ceiling Supply Units     Shalya Orbit            F
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN
# 10227                           NaN              NaN          NaN

# %%
grill.to_excel("Grill IN.xlsx")
